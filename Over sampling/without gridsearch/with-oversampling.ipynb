# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold, cross_val_predict
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, BaggingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Assuming the last column is the target variable
target_column = df.columns[-1]

# Remove leading and trailing spaces from the target column
df[target_column] = df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = df.drop(columns=[target_column])
y = df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(), categorical_columns),
        ('passthrough', 'passthrough', [X.columns[0], X.columns[1]])
    ],
    remainder='drop'
)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Apply RandomOverSampler for random oversampling
random_oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = random_oversampler.fit_resample(X, y)

# Hyperparameter tuning for each classifier
param_grids = {
    'RandomForestClassifier': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'SVC': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf', 'poly'],
        'gamma': ['scale', 'auto']
    },
    'MLPClassifier': {
        'hidden_layer_sizes': [(50,), (100, 50), (100, 50, 20)],
        'max_iter': [200, 500, 1000],
        'alpha': [0.0001, 0.001, 0.01]
    },
    'DecisionTreeClassifier': {
        'max_depth': [None, 5, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'LogisticRegression': {
        'C': [0.1, 1, 10],
        'max_iter': [50, 100, 200]
    },
    'GaussianNB': {},  # No hyperparameters to tune
    'KNeighborsClassifier': {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance']
    },
    'AdaBoostClassifier': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.1, 0.5, 1]
    },
    'GradientBoostingClassifier': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [3, 5, 10]
    },
    'XGBClassifier': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [3, 5, 10]
    },
    'LGBMClassifier': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [3, 5, 10]
    },
    'CatBoostClassifier': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [3, 5, 10]
    },
    'ExtraTreesClassifier': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 5, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'BaggingClassifier': {
        'n_estimators': [50, 100, 200],
        'max_samples': [0.5, 0.7, 1.0],
        'max_features': [0.5, 0.7, 1.0]
    }
}

# Create pipelines for each classifier
classifiers = {
    'RandomForestClassifier': make_pipeline(preprocessor, RandomForestClassifier(random_state=42)),
    'SVC': make_pipeline(preprocessor, StandardScaler(), SVC(random_state=42)),
    'MLPClassifier': make_pipeline(preprocessor, StandardScaler(), MLPClassifier(random_state=42)),
    'DecisionTreeClassifier': make_pipeline(preprocessor, DecisionTreeClassifier(random_state=42)),
    'LogisticRegression': make_pipeline(preprocessor, StandardScaler(), LogisticRegression(random_state=42)),
    'GaussianNB': make_pipeline(preprocessor, GaussianNB()),
    'KNeighborsClassifier': make_pipeline(preprocessor, StandardScaler(), KNeighborsClassifier()),
    'AdaBoostClassifier': make_pipeline(preprocessor, AdaBoostClassifier(random_state=42)),
    'GradientBoostingClassifier': make_pipeline(preprocessor, GradientBoostingClassifier(random_state=42)),
    'XGBClassifier': make_pipeline(preprocessor, XGBClassifier(random_state=42)),
    'LGBMClassifier': make_pipeline(preprocessor, LGBMClassifier(random_state=42)),
    'CatBoostClassifier': make_pipeline(preprocessor, CatBoostClassifier(random_state=42, verbose=False)),
    'ExtraTreesClassifier': make_pipeline(preprocessor, ExtraTreesClassifier(random_state=42)),
    'BaggingClassifier': make_pipeline(preprocessor, BaggingClassifier(random_state=42))
}

# Perform K-fold cross-validation and generate classification report
def kfold_cross_validation(X, y, classifiers, k=10):
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
    for name, classifier in classifiers.items():
        print(f"Evaluating {name}...")
        scores = cross_val_score(classifier, X, y, cv=kf, scoring='accuracy')
        print(f"Accuracy: {scores.mean():.2f} (+/- {scores.std() * 2:.2f})")
        predictions = cross_val_predict(classifier, X, y, cv=kf)
        report = classification_report(y, predictions)
        print(f"Classification Report:\n{report}\n{'='*40}\n")

# Perform K-fold cross-validation
kfold_cross_validation(X_resampled, y_resampled, classifiers)
# Out:
# Evaluating RandomForestClassifier...
# Accuracy: 0.85 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       369
#            1       0.86      0.83      0.85       369
#
#     accuracy                           0.85       738
#    macro avg       0.85      0.85      0.85       738
# weighted avg       0.85      0.85      0.85       738
#
# ========================================
#
# Evaluating SVC...
# Accuracy: 0.80 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       369
#            1       0.78      0.84      0.81       369
#
#     accuracy                           0.80       738
#    macro avg       0.80      0.80      0.80       738
# weighted avg       0.80      0.80      0.80       738
#
# ========================================
#
# Evaluating MLPClassifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy: 0.83 (+/- 0.08)
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       369
#            1       0.84      0.82      0.83       369
#
#     accuracy                           0.83       738
#    macro avg       0.83      0.83      0.83       738
# weighted avg       0.83      0.83      0.83       738
#
# ========================================
#
# Evaluating DecisionTreeClassifier...
# Accuracy: 0.82 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       369
#            1       0.85      0.79      0.82       369
#
#     accuracy                           0.82       738
#    macro avg       0.83      0.82      0.82       738
# weighted avg       0.83      0.82      0.82       738
#
# ========================================
#
# Evaluating LogisticRegression...
# Accuracy: 0.80 (+/- 0.08)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       369
#            1       0.77      0.85      0.81       369
#
#     accuracy                           0.80       738
#    macro avg       0.80      0.80      0.80       738
# weighted avg       0.80      0.80      0.80       738
#
# ========================================
#
# Evaluating GaussianNB...
# Accuracy: 0.74 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.60      0.70       369
#            1       0.69      0.87      0.77       369
#
#     accuracy                           0.74       738
#    macro avg       0.76      0.74      0.73       738
# weighted avg       0.76      0.74      0.73       738
#
# ========================================
#
# Evaluating KNeighborsClassifier...
# Accuracy: 0.73 (+/- 0.10)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73       369
#            1       0.72      0.77      0.74       369
#
#     accuracy                           0.73       738
#    macro avg       0.74      0.73      0.73       738
# weighted avg       0.74      0.73      0.73       738
#
# ========================================
#
# Evaluating AdaBoostClassifier...
# Accuracy: 0.84 (+/- 0.08)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       369
#            1       0.83      0.86      0.85       369
#
#     accuracy                           0.84       738
#    macro avg       0.84      0.84      0.84       738
# weighted avg       0.84      0.84      0.84       738
#
# ========================================
#
# Evaluating GradientBoostingClassifier...
# Accuracy: 0.85 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84       369
#            1       0.83      0.87      0.85       369
#
#     accuracy                           0.85       738
#    macro avg       0.85      0.85      0.85       738
# weighted avg       0.85      0.85      0.85       738
#
# ========================================
#
# Evaluating XGBClassifier...
# Accuracy: 0.86 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       369
#            1       0.86      0.85      0.86       369
#
#     accuracy                           0.86       738
#    macro avg       0.86      0.86      0.86       738
# weighted avg       0.86      0.86      0.86       738
#
# ========================================
#
# Evaluating LGBMClassifier...
# Accuracy: 0.85 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       369
#            1       0.85      0.84      0.85       369
#
#     accuracy                           0.85       738
#    macro avg       0.85      0.85      0.85       738
# weighted avg       0.85      0.85      0.85       738
#
# ========================================
#
# Evaluating CatBoostClassifier...
# Accuracy: 0.86 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       369
#            1       0.86      0.87      0.86       369
#
#     accuracy                           0.86       738
#    macro avg       0.86      0.86      0.86       738
# weighted avg       0.86      0.86      0.86       738
#
# ========================================
#
# Evaluating ExtraTreesClassifier...
# Accuracy: 0.83 (+/- 0.08)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       369
#            1       0.82      0.83      0.83       369
#
#     accuracy                           0.83       738
#    macro avg       0.83      0.83      0.83       738
# weighted avg       0.83      0.83      0.83       738
#
# ========================================
#
# Evaluating BaggingClassifier...
# Accuracy: 0.84 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       369
#            1       0.86      0.80      0.83       369
#
#     accuracy                           0.84       738
#    macro avg       0.84      0.84      0.84       738
# weighted avg       0.84      0.84      0.84       738
#
# ========================================

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from matplotlib.backends.backend_pdf import PdfPages

# Perform K-fold cross-validation and generate classification report along with confusion matrix
def kfold_cross_validation(X, y, classifiers, k=10):
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
    for name, classifier in classifiers.items():
        print(f"Evaluating {name}...")
        # Perform cross-validation
        scores = cross_val_score(classifier, X, y, cv=kf, scoring='accuracy')
        print(f"Accuracy: {scores.mean():.2f} (+/- {scores.std() * 2:.2f})")
        predictions = cross_val_predict(classifier, X, y, cv=kf)
        report = classification_report(y, predictions)
        print(f"Classification Report:\n{report}\n{'='*40}\n")
        # Generate confusion matrix
        conf_mat = confusion_matrix(y, predictions)
        # Plot confusion matrix using Seaborn
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_mat, annot=True, fmt='d', cmap='inferno', xticklabels=le.classes_, yticklabels=le.classes_)
        plt.title(f'Confusion Matrix for {name}')
        plt.xlabel('Predicted Label')
        plt.ylabel('True Label')
        # Save plot to PDF file with bbox_inches='tight'
        with PdfPages(f'{name}_confusion_matrix.pdf') as pdf:
            pdf.savefig(bbox_inches='tight')
            plt.close()

# Perform K-fold cross-validation with confusion matrix visualization and save plots to PDF
kfold_cross_validation(X_resampled, y_resampled, classifiers)
# Out:
# Evaluating RandomForestClassifier...
# Accuracy: 0.85 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       369
#            1       0.86      0.83      0.85       369
#
#     accuracy                           0.85       738
#    macro avg       0.85      0.85      0.85       738
# weighted avg       0.85      0.85      0.85       738
#
# ========================================
#
# Evaluating SVC...
# Accuracy: 0.80 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       369
#            1       0.78      0.84      0.81       369
#
#     accuracy                           0.80       738
#    macro avg       0.80      0.80      0.80       738
# weighted avg       0.80      0.80      0.80       738
#
# ========================================
#
# Evaluating MLPClassifier...
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy: 0.83 (+/- 0.08)
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       369
#            1       0.84      0.82      0.83       369
#
#     accuracy                           0.83       738
#    macro avg       0.83      0.83      0.83       738
# weighted avg       0.83      0.83      0.83       738
#
# ========================================
#
# Evaluating DecisionTreeClassifier...
# Accuracy: 0.82 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       369
#            1       0.85      0.79      0.82       369
#
#     accuracy                           0.82       738
#    macro avg       0.83      0.82      0.82       738
# weighted avg       0.83      0.82      0.82       738
#
# ========================================
#
# Evaluating LogisticRegression...
# Accuracy: 0.80 (+/- 0.08)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79       369
#            1       0.77      0.85      0.81       369
#
#     accuracy                           0.80       738
#    macro avg       0.80      0.80      0.80       738
# weighted avg       0.80      0.80      0.80       738
#
# ========================================
#
# Evaluating GaussianNB...
# Accuracy: 0.74 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.60      0.70       369
#            1       0.69      0.87      0.77       369
#
#     accuracy                           0.74       738
#    macro avg       0.76      0.74      0.73       738
# weighted avg       0.76      0.74      0.73       738
#
# ========================================
#
# Evaluating KNeighborsClassifier...
# Accuracy: 0.73 (+/- 0.10)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73       369
#            1       0.72      0.77      0.74       369
#
#     accuracy                           0.73       738
#    macro avg       0.74      0.73      0.73       738
# weighted avg       0.74      0.73      0.73       738
#
# ========================================
#
# Evaluating AdaBoostClassifier...
# Accuracy: 0.84 (+/- 0.08)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       369
#            1       0.83      0.86      0.85       369
#
#     accuracy                           0.84       738
#    macro avg       0.84      0.84      0.84       738
# weighted avg       0.84      0.84      0.84       738
#
# ========================================
#
# Evaluating GradientBoostingClassifier...
# Accuracy: 0.85 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84       369
#            1       0.83      0.87      0.85       369
#
#     accuracy                           0.85       738
#    macro avg       0.85      0.85      0.85       738
# weighted avg       0.85      0.85      0.85       738
#
# ========================================
#
# Evaluating XGBClassifier...
# Accuracy: 0.86 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       369
#            1       0.86      0.85      0.86       369
#
#     accuracy                           0.86       738
#    macro avg       0.86      0.86      0.86       738
# weighted avg       0.86      0.86      0.86       738
#
# ========================================
#
# Evaluating LGBMClassifier...
# Accuracy: 0.85 (+/- 0.06)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       369
#            1       0.85      0.84      0.85       369
#
#     accuracy                           0.85       738
#    macro avg       0.85      0.85      0.85       738
# weighted avg       0.85      0.85      0.85       738
#
# ========================================
#
# Evaluating CatBoostClassifier...
# Accuracy: 0.86 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       369
#            1       0.86      0.87      0.86       369
#
#     accuracy                           0.86       738
#    macro avg       0.86      0.86      0.86       738
# weighted avg       0.86      0.86      0.86       738
#
# ========================================
#
# Evaluating ExtraTreesClassifier...
# Accuracy: 0.83 (+/- 0.08)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       369
#            1       0.82      0.83      0.83       369
#
#     accuracy                           0.83       738
#    macro avg       0.83      0.83      0.83       738
# weighted avg       0.83      0.83      0.83       738
#
# ========================================
#
# Evaluating BaggingClassifier...
# Accuracy: 0.84 (+/- 0.07)
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       369
#            1       0.86      0.80      0.83       369
#
#     accuracy                           0.84       738
#    macro avg       0.84      0.84      0.84       738
# weighted avg       0.84      0.84      0.84       738
#
# ========================================

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Function to plot ROC curve for each classifier
def plot_roc_curve(X, y, classifiers):
    plt.figure(figsize=(10, 8))
    for name, classifier in classifiers.items():
        if hasattr(classifier, "predict_proba"):  # Check if the classifier has predict_proba method
            probas = classifier.fit(X, y).predict_proba(X)
            fpr, tpr, thresholds = roc_curve(y, probas[:, 1])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.2f})')  # Increased thickness to 2
    
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Adjust the thickness of the diagonal line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("roc_curves.pdf", bbox_inches='tight')
    plt.show()

# Plot ROC curves for all classifiers
plot_roc_curve(X_resampled, y_resampled, classifiers)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
for name, classifier in classifiers.items():
    if name in ['RandomForestClassifier', 'ExtraTreesClassifier', 'GradientBoostingClassifier',
                'XGBClassifier', 'LGBMClassifier', 'CatBoostClassifier']:
        classifier.fit(X, y)
        if name == 'RandomForestClassifier':
            feature_importance = classifier.named_steps['randomforestclassifier'].feature_importances_
        elif name == 'ExtraTreesClassifier':
            feature_importance = classifier.named_steps['extratreesclassifier'].feature_importances_
        elif name == 'GradientBoostingClassifier':
            feature_importance = classifier.named_steps['gradientboostingclassifier'].feature_importances_
        elif name == 'XGBClassifier':
            feature_importance = classifier.named_steps['xgbclassifier'].feature_importances_
        elif name == 'LGBMClassifier':
            feature_importance = classifier.named_steps['lgbmclassifier'].feature_importances_
        elif name == 'CatBoostClassifier':
            feature_importance = classifier.named_steps['catboostclassifier'].feature_importances_
        
        # Create a dictionary to store feature importance with their column names
        feature_importance_dict = dict(zip(X.columns, feature_importance))
        
        # Sort features by their importance (descending order)
        sorted_feature_importance = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)
        
        print(f"Feature importance for {name} (most important to least important):")
        for column, importance in sorted_feature_importance:
            print(f"{column}: {importance}")
        print('=' * 40)
# Out:
# Feature importance for RandomForestClassifier (most important to least important):
# Did you have other bad habits like smoking/drug addiction?: 0.03215944376677043
# What was your SSC GPA?: 0.026355393618374287
# Where did you stay when preparing for the exam?: 0.025977996183066832
# How was your family's economic condition : 0.022023860540704175
# Did you involve with any type of relationship?: 0.02117809853973588
# Were there any external factors that may have affected your performance on the test (e.g., personal issues, health concerns, financial challenges)?: 0.01797349634146013
# How much time did you spend on social media/other activities while preparing for the exam?: 0.016996917601297824
# Were you involved in politics while preparing for the exam?: 0.012085721953272009
# What was your HSC GPA?: 0.011545907309322812
# How was the educational status of your family?: 0.011258130935059486
# The average duration of study in a single day during admission preparation-: 0.010424698053801888
# Did you stay with your family while preparing for the exam?: 0.010359204668795285
# What area was your college in?: 0.009477197915141148
# What area was your school in?: 0.00934215880254438
# ========================================
# Feature importance for GradientBoostingClassifier (most important to least important):
# Did you have other bad habits like smoking/drug addiction?: 0.018883354533396332
# The average duration of study in a single day during admission preparation-: 0.01824300249211134
# How was your family's economic condition : 0.018023048595040524
# What was your SSC GPA?: 0.015216180045687103
# Did you stay with your family while preparing for the exam?: 0.012305781173483937
# What area was your college in?: 0.011729224723095634
# Were you involved in politics while preparing for the exam?: 0.006291454142871982
# What area was your school in?: 0.005198352129266163
# Where did you stay when preparing for the exam?: 0.003339477356213584
# Were there any external factors that may have affected your performance on the test (e.g., personal issues, health concerns, financial challenges)?: 0.0030580299201971944
# How was the educational status of your family?: 0.0023916122979510688
# How much time did you spend on social media/other activities while preparing for the exam?: 0.0017105920417265048
# What was your HSC GPA?: 0.0016800305372464096
# Did you involve with any type of relationship?: 0.000687459747744226
# ========================================
# Feature importance for XGBClassifier (most important to least important):
# Did you have other bad habits like smoking/drug addiction?: 0.04593062028288841
# The average duration of study in a single day during admission preparation-: 0.04544290900230408
# What area was your college in?: 0.040264565497636795
# How was your family's economic condition : 0.03852222114801407
# How much time did you spend on social media/other activities while preparing for the exam?: 0.027637667953968048
# How was the educational status of your family?: 0.027509797364473343
# What was your SSC GPA?: 0.024259790778160095
# Did you involve with any type of relationship?: 0.02214530110359192
# Did you stay with your family while preparing for the exam?: 0.021639518439769745
# What was your HSC GPA?: 0.020770123228430748
# Where did you stay when preparing for the exam?: 0.01871982216835022
# Were there any external factors that may have affected your performance on the test (e.g., personal issues, health concerns, financial challenges)?: 0.017886491492390633
# Were you involved in politics while preparing for the exam?: 0.0
# What area was your school in?: 0.0
# ========================================
# Feature importance for LGBMClassifier (most important to least important):
# Where did you stay when preparing for the exam?: 143
# What was your SSC GPA?: 120
# Did you involve with any type of relationship?: 100
# How was your family's economic condition : 93
# Did you have other bad habits like smoking/drug addiction?: 70
# How much time did you spend on social media/other activities while preparing for the exam?: 48
# How was the educational status of your family?: 46
# Were there any external factors that may have affected your performance on the test (e.g., personal issues, health concerns, financial challenges)?: 34
# Did you stay with your family while preparing for the exam?: 33
# The average duration of study in a single day during admission preparation-: 27
# Were you involved in politics while preparing for the exam?: 15
# What was your HSC GPA?: 7
# What area was your college in?: 0
# What area was your school in?: 0
# ========================================
# Feature importance for CatBoostClassifier (most important to least important):
# What was your SSC GPA?: 5.274028348788977
# Did you have other bad habits like smoking/drug addiction?: 4.516131817359573
# How was your family's economic condition : 3.8534504875138107
# Where did you stay when preparing for the exam?: 2.5800860613415852
# Did you involve with any type of relationship?: 2.081836141944965
# The average duration of study in a single day during admission preparation-: 1.355367585791024
# How much time did you spend on social media/other activities while preparing for the exam?: 1.29479484172138
# Were there any external factors that may have affected your performance on the test (e.g., personal issues, health concerns, financial challenges)?: 1.2703831364204363
# What was your HSC GPA?: 1.2300452219605884
# Were you involved in politics while preparing for the exam?: 1.1366712536614196
# Did you stay with your family while preparing for the exam?: 1.0678337069863069
# How was the educational status of your family?: 1.0284942013017926
# What area was your college in?: 0.587942431561304
# What area was your school in?: 0.5326231492923462
# ========================================
# Feature importance for ExtraTreesClassifier (most important to least important):
# Did you have other bad habits like smoking/drug addiction?: 0.0411191612819963
# What was your SSC GPA?: 0.026444539389520957
# Where did you stay when preparing for the exam?: 0.026078577535394176
# Did you involve with any type of relationship?: 0.025400079239215233
# Were there any external factors that may have affected your performance on the test (e.g., personal issues, health concerns, financial challenges)?: 0.021812849378617032
# How was your family's economic condition : 0.02108891275822101
# How much time did you spend on social media/other activities while preparing for the exam?: 0.020111921081035253
# Did you stay with your family while preparing for the exam?: 0.015029485290948812
# How was the educational status of your family?: 0.014917270932427083
# Were you involved in politics while preparing for the exam?: 0.013916868816927165
# The average duration of study in a single day during admission preparation-: 0.013372975429465467
# What was your HSC GPA?: 0.012298435536813437
# What area was your college in?: 0.01175946946855257
# What area was your school in?: 0.010455067820205362
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Oversample both Public University and Private University to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a more complex ANN model with Dropout and BatchNormalization
ann_model = Sequential()
ann_model.add(Dense(units=512, activation='relu', input_dim=X_train_scaled.shape[1]))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.5))
ann_model.add(Dense(units=256, activation='relu'))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.4))
ann_model.add(Dense(units=128, activation='relu'))
ann_model.add(Dropout(0.3))
ann_model.add(Dense(units=64, activation='relu'))
ann_model.add(Dropout(0.2))
ann_model.add(Dense(units=1, activation='sigmoid'))

# Implement learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,
    decay_steps=1000,
    decay_rate=0.9
)
ann_model.compile(optimizer=Adam(learning_rate=lr_schedule), loss='binary_crossentropy', metrics=['accuracy'])

# Train the ANN model and get history
history = ann_model.fit(X_train_scaled, y_train, epochs=70, batch_size=16, validation_data=(X_test_scaled, y_test))


# Visualize accuracy and loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Accuracy (Training)')
plt.plot(history.history['val_accuracy'], label='Accuracy (Validation)')
plt.plot(history.history['loss'], label='Loss (Training)')
plt.plot(history.history['val_loss'], label='Loss (Validation)')
plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("train_ann.pdf", bbox_inches='tight')  # Save the confusion matrix as a PDF with tight bounding box
plt.show()


# Predictions using the ANN
y_pred_ann = (ann_model.predict(X_test_scaled) > 0.5).astype("int32").flatten()

# Evaluate the ANN
print('For ANN:')
print('Accuracy:', accuracy_score(y_test, y_pred_ann))
print('Classification Report:')
print(classification_report(y_test, y_pred_ann))

# Plot confusion matrix
class_labels = ['private university', 'public university']
conf_matrix_ann = confusion_matrix(y_test, y_pred_ann)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_ann, annot=True, fmt='d', cmap='inferno', cbar=False)
plt.title('Confusion Matrix (ANN)')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(ticks=[0.5, 1.5], labels=class_labels)
plt.yticks(ticks=[0.5, 1.5], labels=class_labels)
plt.tight_layout()
plt.savefig("confusion_matrix_ann.pdf", bbox_inches='tight')  # Save the confusion matrix as a PDF with tight bounding box
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Epoch 1/70
# 91/91 [==============================] - 8s 10ms/step - loss: 0.6967 - accuracy: 0.6181 - val_loss: 0.6017 - val_accuracy: 0.7624
# Epoch 2/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.5658 - accuracy: 0.7072 - val_loss: 0.5132 - val_accuracy: 0.8122
# Epoch 3/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.4888 - accuracy: 0.7673 - val_loss: 0.4326 - val_accuracy: 0.8398
# Epoch 4/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.4476 - accuracy: 0.7997 - val_loss: 0.3773 - val_accuracy: 0.8674
# Epoch 5/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.4064 - accuracy: 0.8122 - val_loss: 0.3457 - val_accuracy: 0.8564
# Epoch 6/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.4064 - accuracy: 0.8177 - val_loss: 0.3293 - val_accuracy: 0.8564
# Epoch 7/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3924 - accuracy: 0.8301 - val_loss: 0.3176 - val_accuracy: 0.8619
# Epoch 8/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3528 - accuracy: 0.8515 - val_loss: 0.3074 - val_accuracy: 0.8674
# Epoch 9/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3482 - accuracy: 0.8494 - val_loss: 0.3050 - val_accuracy: 0.8674
# Epoch 10/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3346 - accuracy: 0.8488 - val_loss: 0.2983 - val_accuracy: 0.8729
# Epoch 11/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3356 - accuracy: 0.8598 - val_loss: 0.2905 - val_accuracy: 0.8702
# Epoch 12/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3185 - accuracy: 0.8743 - val_loss: 0.2881 - val_accuracy: 0.8646
# Epoch 13/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3276 - accuracy: 0.8702 - val_loss: 0.2842 - val_accuracy: 0.8646
# Epoch 14/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2973 - accuracy: 0.8667 - val_loss: 0.2804 - val_accuracy: 0.8646
# Epoch 15/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.3037 - accuracy: 0.8722 - val_loss: 0.2777 - val_accuracy: 0.8646
# Epoch 16/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2845 - accuracy: 0.8854 - val_loss: 0.2736 - val_accuracy: 0.8702
# Epoch 17/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2852 - accuracy: 0.8888 - val_loss: 0.2684 - val_accuracy: 0.8840
# Epoch 18/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2736 - accuracy: 0.8847 - val_loss: 0.2668 - val_accuracy: 0.8867
# Epoch 19/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2721 - accuracy: 0.8971 - val_loss: 0.2688 - val_accuracy: 0.8895
# Epoch 20/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2628 - accuracy: 0.8978 - val_loss: 0.2713 - val_accuracy: 0.8840
# Epoch 21/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2733 - accuracy: 0.8867 - val_loss: 0.2683 - val_accuracy: 0.8840
# Epoch 22/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2486 - accuracy: 0.8978 - val_loss: 0.2690 - val_accuracy: 0.8812
# Epoch 23/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2464 - accuracy: 0.9061 - val_loss: 0.2650 - val_accuracy: 0.8895
# Epoch 24/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2625 - accuracy: 0.8957 - val_loss: 0.2623 - val_accuracy: 0.8895
# Epoch 25/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2860 - accuracy: 0.8888 - val_loss: 0.2581 - val_accuracy: 0.8867
# Epoch 26/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2639 - accuracy: 0.8902 - val_loss: 0.2579 - val_accuracy: 0.8840
# Epoch 27/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2352 - accuracy: 0.9109 - val_loss: 0.2559 - val_accuracy: 0.8867
# Epoch 28/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2551 - accuracy: 0.9081 - val_loss: 0.2550 - val_accuracy: 0.8867
# Epoch 29/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2452 - accuracy: 0.9061 - val_loss: 0.2545 - val_accuracy: 0.8895
# Epoch 30/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2385 - accuracy: 0.9040 - val_loss: 0.2574 - val_accuracy: 0.8867
# Epoch 31/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2363 - accuracy: 0.9012 - val_loss: 0.2525 - val_accuracy: 0.8950
# Epoch 32/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2344 - accuracy: 0.8985 - val_loss: 0.2566 - val_accuracy: 0.8895
# Epoch 33/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2438 - accuracy: 0.9047 - val_loss: 0.2550 - val_accuracy: 0.8950
# Epoch 34/70
# 91/91 [==============================] - 1s 8ms/step - loss: 0.2340 - accuracy: 0.9095 - val_loss: 0.2531 - val_accuracy: 0.8950
# Epoch 35/70
# 91/91 [==============================] - 1s 8ms/step - loss: 0.2136 - accuracy: 0.9130 - val_loss: 0.2529 - val_accuracy: 0.8978
# Epoch 36/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2214 - accuracy: 0.9081 - val_loss: 0.2532 - val_accuracy: 0.9006
# Epoch 37/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2146 - accuracy: 0.9151 - val_loss: 0.2521 - val_accuracy: 0.8950
# Epoch 38/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2197 - accuracy: 0.9095 - val_loss: 0.2490 - val_accuracy: 0.9061
# Epoch 39/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2018 - accuracy: 0.9130 - val_loss: 0.2483 - val_accuracy: 0.9088
# Epoch 40/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2092 - accuracy: 0.9102 - val_loss: 0.2489 - val_accuracy: 0.9033
# Epoch 41/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2272 - accuracy: 0.9130 - val_loss: 0.2463 - val_accuracy: 0.9006
# Epoch 42/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1955 - accuracy: 0.9157 - val_loss: 0.2449 - val_accuracy: 0.9006
# Epoch 43/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2015 - accuracy: 0.9144 - val_loss: 0.2482 - val_accuracy: 0.8978
# Epoch 44/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2029 - accuracy: 0.9144 - val_loss: 0.2474 - val_accuracy: 0.9006
# Epoch 45/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2036 - accuracy: 0.9220 - val_loss: 0.2499 - val_accuracy: 0.9006
# Epoch 46/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2065 - accuracy: 0.9206 - val_loss: 0.2497 - val_accuracy: 0.9006
# Epoch 47/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1900 - accuracy: 0.9240 - val_loss: 0.2506 - val_accuracy: 0.9006
# Epoch 48/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1850 - accuracy: 0.9199 - val_loss: 0.2437 - val_accuracy: 0.9061
# Epoch 49/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1893 - accuracy: 0.9220 - val_loss: 0.2417 - val_accuracy: 0.9061
# Epoch 50/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1796 - accuracy: 0.9302 - val_loss: 0.2435 - val_accuracy: 0.9061
# Epoch 51/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2051 - accuracy: 0.9289 - val_loss: 0.2462 - val_accuracy: 0.9088
# Epoch 52/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1905 - accuracy: 0.9289 - val_loss: 0.2446 - val_accuracy: 0.9061
# Epoch 53/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1821 - accuracy: 0.9323 - val_loss: 0.2417 - val_accuracy: 0.9061
# Epoch 54/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1785 - accuracy: 0.9275 - val_loss: 0.2444 - val_accuracy: 0.9061
# Epoch 55/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1882 - accuracy: 0.9302 - val_loss: 0.2437 - val_accuracy: 0.9061
# Epoch 56/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1894 - accuracy: 0.9240 - val_loss: 0.2481 - val_accuracy: 0.9061
# Epoch 57/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.2081 - accuracy: 0.9213 - val_loss: 0.2461 - val_accuracy: 0.9061
# Epoch 58/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1691 - accuracy: 0.9344 - val_loss: 0.2433 - val_accuracy: 0.9061
# Epoch 59/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1805 - accuracy: 0.9330 - val_loss: 0.2455 - val_accuracy: 0.9061
# Epoch 60/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1750 - accuracy: 0.9233 - val_loss: 0.2461 - val_accuracy: 0.9061
# Epoch 61/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1770 - accuracy: 0.9302 - val_loss: 0.2446 - val_accuracy: 0.9061
# Epoch 62/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1788 - accuracy: 0.9302 - val_loss: 0.2453 - val_accuracy: 0.9061
# Epoch 63/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1738 - accuracy: 0.9289 - val_loss: 0.2438 - val_accuracy: 0.9088
# Epoch 64/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1938 - accuracy: 0.9275 - val_loss: 0.2432 - val_accuracy: 0.9061
# Epoch 65/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1856 - accuracy: 0.9233 - val_loss: 0.2433 - val_accuracy: 0.9116
# Epoch 66/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1722 - accuracy: 0.9344 - val_loss: 0.2402 - val_accuracy: 0.9116
# Epoch 67/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1707 - accuracy: 0.9351 - val_loss: 0.2400 - val_accuracy: 0.9116
# Epoch 68/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1696 - accuracy: 0.9372 - val_loss: 0.2406 - val_accuracy: 0.9116
# Epoch 69/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1648 - accuracy: 0.9399 - val_loss: 0.2391 - val_accuracy: 0.9144
# Epoch 70/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1735 - accuracy: 0.9344 - val_loss: 0.2368 - val_accuracy: 0.9144
# 12/12 [==============================] - 0s 2ms/step
# For ANN:
# Accuracy: 0.914364640883978
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90       151
#            1       0.92      0.93      0.93       211
#
#     accuracy                           0.91       362
#    macro avg       0.91      0.91      0.91       362
# weighted avg       0.91      0.91      0.91       362
