# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import RandomOverSampler

# Define the file path
file_path = "/kaggle/input/undergrad/Undergraduate.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Assuming the last column is the target variable
target_column = df.columns[-1]

# Remove leading and trailing spaces from the target column
df[target_column] = df[target_column].str.strip()

# Print count of samples for each class before oversampling
print("Count of samples for each class before oversampling:")
print(df['Name of your current institution? '].value_counts())

# Separate features (X) and target variable (y)
X = df.drop(columns=[target_column])
y = df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Oversample Private University to match the number of instances of Public University
oversample_ratio = df[df['Name of your current institution? '] == 'Public University'].shape[0] // df[df['Name of your current institution? '] == 'Private University'].shape[0]
ros = RandomOverSampler(sampling_strategy=oversample_ratio, random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_encoded, y)

# Print count of samples for each class after oversampling
print("\nCount of samples for each class after oversampling:")
print(pd.Series(le.inverse_transform(y_resampled)).value_counts())

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Artificial Neural Network (ANN) Classifier
ann_classifier = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=42)
ann_classifier.fit(X_train_scaled, y_train)
ann_predictions = ann_classifier.predict(X_test_scaled)

# Machine Learning Classifiers
classifiers = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'SVM': SVC(random_state=42)
}

for name, classifier in classifiers.items():
    classifier.fit(X_train_scaled, y_train)
    predictions = classifier.predict(X_test_scaled)
    
    # Evaluate the classifier
    accuracy = accuracy_score(y_test, predictions)
    report = classification_report(y_test, predictions, target_names=le.classes_)  # Set target names using label encoder classes_
    
    print(f"Classifier: {name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Classification Report:\n{report}\n{'='*40}")
# Out:
# Count of samples for each class before oversampling:
# Public University     369
# Private University    226
# Name: Name of your current institution? , dtype: int64
#
# Count of samples for each class after oversampling:
# Public University     369
# Private University    369
# dtype: int64
# Classifier: Random Forest
# Accuracy: 0.77
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.75      0.77      0.76        69
#  Public University       0.79      0.77      0.78        79
#
#           accuracy                           0.77       148
#          macro avg       0.77      0.77      0.77       148
#       weighted avg       0.77      0.77      0.77       148
#
# ========================================
# Classifier: SVM
# Accuracy: 0.79
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.75      0.77        69
#  Public University       0.79      0.82      0.81        79
#
#           accuracy                           0.79       148
#          macro avg       0.79      0.79      0.79       148
#       weighted avg       0.79      0.79      0.79       148
#
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from imblearn.over_sampling import RandomOverSampler

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Remove leading and trailing spaces from the target column
target_column = 'Name of your current institution? '
df[target_column] = df[target_column].str.strip()

# Oversample the minority class to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Map numerical labels back to class names
class_names = le.classes_

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Hyperparameter tuning for RandomForestClassifier
param_grid_rf = {
    'randomforestclassifier__n_estimators': [50, 100, 200],
    'randomforestclassifier__max_depth': [None, 10, 20],
    'randomforestclassifier__min_samples_split': [2, 5, 10],
    'randomforestclassifier__min_samples_leaf': [1, 2, 4]
}

# Create a pipeline for preprocessing and RandomForestClassifier
pipeline_rf = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    RandomForestClassifier(random_state=42)
)

grid_search_rf = GridSearchCV(pipeline_rf, param_grid_rf, cv=5, scoring='accuracy')
grid_search_rf.fit(X_train, y_train)

# Get the best parameters
best_params_rf = grid_search_rf.best_params_
print(f"Best Parameters for RandomForestClassifier: {best_params_rf}")

# Evaluate the RandomForestClassifier with the best parameters
best_rf_classifier = grid_search_rf.best_estimator_
best_rf_predictions = best_rf_classifier.predict(X_test)
best_rf_accuracy = accuracy_score(y_test, best_rf_predictions)
best_rf_report = classification_report(y_test, best_rf_predictions, target_names=class_names)

print("Random Forest Classifier:")
print(f"Accuracy: {best_rf_accuracy:.2f}")
print(f"Classification Report:\n{best_rf_report}\n{'='*40}")
# Out:
# Best Parameters for RandomForestClassifier: {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__min_samples_leaf': 1, 'randomforestclassifier__min_samples_split': 2, 'randomforestclassifier__n_estimators': 50}
# Random Forest Classifier:
# Accuracy: 0.79
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.77      0.77        69
#  Public University       0.80      0.81      0.81        79
#
#           accuracy                           0.79       148
#          macro avg       0.79      0.79      0.79       148
#       weighted avg       0.79      0.79      0.79       148
#
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from imblearn.over_sampling import RandomOverSampler

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Assuming the last column is the target variable
target_column = 'Name of your current institution? '

# Remove leading and trailing spaces from the target column
df[target_column] = df[target_column].str.strip()

# Oversample both Public University and Private University to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Hyperparameter tuning for classifiers
param_grids = {
    'SVM': {
        'svc__C': [0.1, 1, 10],
        'svc__kernel': ['linear', 'rbf', 'poly'],
        'svc__gamma': ['scale', 'auto']
    },
    'MLPClassifier': {
        'mlpclassifier__hidden_layer_sizes': [(50,), (100, 50), (100, 50, 20)],
        'mlpclassifier__max_iter': [200, 500, 1000],
        'mlpclassifier__alpha': [0.0001, 0.001, 0.01]
    },
    'Decision Tree': {
        'decisiontreeclassifier__max_depth': [None, 5, 10, 20],
        'decisiontreeclassifier__min_samples_split': [2, 5, 10],
        'decisiontreeclassifier__min_samples_leaf': [1, 2, 4]
    },
    'Logistic Regression': {
        'logisticregression__C': [0.1, 1, 10],
        'logisticregression__max_iter': [50, 100, 200]
    },
    'GaussianNB': {},  # No hyperparameters to tune
    'K-Nearest Neighbors': {
        'kneighborsclassifier__n_neighbors': [3, 5, 7],
        'kneighborsclassifier__weights': ['uniform', 'distance']
    },
    'AdaBoost': {
        'adaboostclassifier__n_estimators': [50, 100, 200],
        'adaboostclassifier__learning_rate': [0.1, 0.5, 1]
    },
    'Gradient Boosting': {
        'gradientboostingclassifier__n_estimators': [50, 100, 200],
        'gradientboostingclassifier__learning_rate': [0.01, 0.1, 0.5],
        'gradientboostingclassifier__max_depth': [3, 5, 10]
    }
}

# Create pipelines for each classifier
pipelines = {
    'SVM': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), SVC(random_state=42)),
    'MLPClassifier': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), MLPClassifier(random_state=42)),
    'Decision Tree': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), DecisionTreeClassifier(random_state=42)),
    'Logistic Regression': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), LogisticRegression(random_state=42)),
    'GaussianNB': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), GaussianNB()),
    'K-Nearest Neighbors': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), KNeighborsClassifier()),
    'AdaBoost': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), AdaBoostClassifier(random_state=42)),
    'Gradient Boosting': make_pipeline(SimpleImputer(strategy='mean'), StandardScaler(), GradientBoostingClassifier(random_state=42))
}

# Loop through classifiers
for name, pipeline in pipelines.items():
    param_grid = param_grids.get(name, {})
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)

    # Get the best parameters
    best_params = grid_search.best_params_

    # Evaluate the classifier with the best parameters
    best_classifier = grid_search.best_estimator_
    best_predictions = best_classifier.predict(X_test)
    best_accuracy = accuracy_score(y_test, best_predictions)
    class_names = le.classes_
    y_test_names = le.inverse_transform(y_test)
    best_predictions_names = le.inverse_transform(best_predictions)

    best_report = classification_report(y_test_names, best_predictions_names, target_names=class_names)

    print(f"{name} Classifier:")
    print(f"Best Parameters: {best_params}")
    print(f"Accuracy: {best_accuracy:.2f}")
    print(f"Classification Report:\n{best_report}\n{'='*40}")
# Out:
# SVM Classifier:
# Best Parameters: {'svc__C': 10, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# Accuracy: 0.78
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.71      0.75        69
#  Public University       0.77      0.84      0.80        79
#
#           accuracy                           0.78       148
#          macro avg       0.78      0.77      0.77       148
#       weighted avg       0.78      0.78      0.78       148
#
# ========================================
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier Classifier:
# Best Parameters: {'mlpclassifier__alpha': 0.0001, 'mlpclassifier__hidden_layer_sizes': (100, 50), 'mlpclassifier__max_iter': 500}
# Accuracy: 0.76
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.73      0.75      0.74        69
#  Public University       0.78      0.76      0.77        79
#
#           accuracy                           0.76       148
#          macro avg       0.76      0.76      0.76       148
#       weighted avg       0.76      0.76      0.76       148
#
# ========================================
# Decision Tree Classifier:
# Best Parameters: {'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__min_samples_leaf': 4, 'decisiontreeclassifier__min_samples_split': 2}
# Accuracy: 0.78
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.74      0.76        69
#  Public University       0.78      0.82      0.80        79
#
#           accuracy                           0.78       148
#          macro avg       0.78      0.78      0.78       148
#       weighted avg       0.78      0.78      0.78       148
#
# ========================================
# Logistic Regression Classifier:
# Best Parameters: {'logisticregression__C': 1, 'logisticregression__max_iter': 50}
# Accuracy: 0.81
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.83      0.75      0.79        69
#  Public University       0.80      0.86      0.83        79
#
#           accuracy                           0.81       148
#          macro avg       0.81      0.81      0.81       148
#       weighted avg       0.81      0.81      0.81       148
#
# ========================================
# GaussianNB Classifier:
# Best Parameters: {}
# Accuracy: 0.72
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.76      0.59      0.67        69
#  Public University       0.70      0.84      0.76        79
#
#           accuracy                           0.72       148
#          macro avg       0.73      0.71      0.71       148
#       weighted avg       0.73      0.72      0.72       148
#
# ========================================
# K-Nearest Neighbors Classifier:
# Best Parameters: {'kneighborsclassifier__n_neighbors': 5, 'kneighborsclassifier__weights': 'distance'}
# Accuracy: 0.75
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.74      0.72      0.73        69
#  Public University       0.76      0.77      0.77        79
#
#           accuracy                           0.75       148
#          macro avg       0.75      0.75      0.75       148
#       weighted avg       0.75      0.75      0.75       148
#
# ========================================
# AdaBoost Classifier:
# Best Parameters: {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.86      0.72      0.79        69
#  Public University       0.79      0.90      0.84        79
#
#           accuracy                           0.82       148
#          macro avg       0.83      0.81      0.81       148
#       weighted avg       0.82      0.82      0.82       148
#
# ========================================
# Gradient Boosting Classifier:
# Best Parameters: {'gradientboostingclassifier__learning_rate': 0.1, 'gradientboostingclassifier__max_depth': 3, 'gradientboostingclassifier__n_estimators': 200}
# Accuracy: 0.80
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.77      0.79        69
#  Public University       0.80      0.84      0.82        79
#
#           accuracy                           0.80       148
#          macro avg       0.80      0.80      0.80       148
#       weighted avg       0.80      0.80      0.80       148
#
# ========================================

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier

# ... (previous code remains unchanged)

# Hyperparameter tuning for XGBClassifier
param_grid_xgb = {
    'xgbclassifier__n_estimators': [50, 100, 200],
    'xgbclassifier__learning_rate': [0.01, 0.1, 0.5],
    'xgbclassifier__max_depth': [3, 5, 10]
}

# Hyperparameter tuning for LGBMClassifier
param_grid_lgbm = {
    'lgbmclassifier__n_estimators': [50, 100, 200],
    'lgbmclassifier__learning_rate': [0.01, 0.1, 0.5],
    'lgbmclassifier__max_depth': [3, 5, 10]
}

# Hyperparameter tuning for CatBoostClassifier
param_grid_catboost = {
    'catboostclassifier__n_estimators': [50, 100, 200],
    'catboostclassifier__learning_rate': [0.01, 0.1, 0.5],
    'catboostclassifier__max_depth': [3, 5, 10]
}

# Hyperparameter tuning for ExtraTreesClassifier
param_grid_extra_trees = {
    'extratreesclassifier__n_estimators': [50, 100, 200],
    'extratreesclassifier__max_depth': [None, 5, 10, 20],
    'extratreesclassifier__min_samples_split': [2, 5, 10],
    'extratreesclassifier__min_samples_leaf': [1, 2, 4]
}

# Hyperparameter tuning for BaggingClassifier
param_grid_bagging = {
    'baggingclassifier__n_estimators': [50, 100, 200],
    'baggingclassifier__max_samples': [0.5, 0.7, 1.0],
    'baggingclassifier__max_features': [0.5, 0.7, 1.0]
}

# Create pipelines for each classifier

pipeline_xgb = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    XGBClassifier(random_state=42)
)

pipeline_lgbm = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    LGBMClassifier(random_state=42)
)

pipeline_catboost = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    CatBoostClassifier(random_state=42)
)

pipeline_extra_trees = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    ExtraTreesClassifier(random_state=42)
)

pipeline_bagging = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    BaggingClassifier(random_state=42)
)

# Create dictionaries for additional classifiers and their respective hyperparameter grids
additional_classifiers = {
    'XGBClassifier': (pipeline_xgb, param_grid_xgb),
    'LGBMClassifier': (pipeline_lgbm, param_grid_lgbm),
    'CatBoostClassifier': (pipeline_catboost, param_grid_catboost),
    'ExtraTreesClassifier': (pipeline_extra_trees, param_grid_extra_trees),
    'BaggingClassifier': (pipeline_bagging, param_grid_bagging)
}

# Combine the classifiers
all_classifiers = {**classifiers, **additional_classifiers}

# Loop through all classifiers
for name, (pipeline, param_grid) in all_classifiers.items():
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)

    # Get the best parameters
    best_params = grid_search.best_params_
    print(f"Best Parameters for {name}: {best_params}")

    # Evaluate the classifier with the best parameters
    best_classifier = grid_search.best_estimator_
    best_predictions = best_classifier.predict(X_test)
    best_accuracy = accuracy_score(y_test, best_predictions)
    # Convert numeric labels back to class names
    class_names = le.classes_
    y_test_names = le.inverse_transform(y_test)
    best_predictions_names = le.inverse_transform(best_predictions)

    best_report = classification_report(y_test_names, best_predictions_names, target_names=class_names)

    print(f"{name} Classifier:")
    print(f"Best Parameters: {best_params}")
    print(f"Accuracy: {best_accuracy:.2f}")
    print(f"Classification Report:\n{best_report}\n{'='*40}")
# Out:
# Best Parameters for SVM: {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# SVM Classifier:
# Best Parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# Accuracy: 0.78
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.71      0.75        69
#  Public University       0.77      0.84      0.80        79
#
#           accuracy                           0.78       148
#          macro avg       0.78      0.77      0.77       148
#       weighted avg       0.78      0.78      0.78       148
#
# ========================================
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters for MLPClassifier: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 20), 'max_iter': 200}
# MLPClassifier Classifier:
# Best Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 20), 'max_iter': 200}
# Accuracy: 0.76
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.75      0.74      0.74        69
#  Public University       0.78      0.78      0.78        79
#
#           accuracy                           0.76       148
#          macro avg       0.76      0.76      0.76       148
#       weighted avg       0.76      0.76      0.76       148
#
# ========================================
# Best Parameters for Decision Tree: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Decision Tree Classifier:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Accuracy: 0.78
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.74      0.76        69
#  Public University       0.78      0.82      0.80        79
#
#           accuracy                           0.78       148
#          macro avg       0.78      0.78      0.78       148
#       weighted avg       0.78      0.78      0.78       148
#
# ========================================
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Best Parameters for Logistic Regression: {'C': 10, 'max_iter': 50}
# Logistic Regression Classifier:
# Best Parameters: {'C': 10, 'max_iter': 50}
# Accuracy: 0.79
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.74      0.77        69
#  Public University       0.79      0.84      0.81        79
#
#           accuracy                           0.79       148
#          macro avg       0.79      0.79      0.79       148
#       weighted avg       0.79      0.79      0.79       148
#
# ========================================
# Best Parameters for Naive Bayes: {}
# Naive Bayes Classifier:
# Best Parameters: {}
# Accuracy: 0.72
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.76      0.59      0.67        69
#  Public University       0.70      0.84      0.76        79
#
#           accuracy                           0.72       148
#          macro avg       0.73      0.71      0.71       148
#       weighted avg       0.73      0.72      0.72       148
#
# ========================================
# Best Parameters for K-Nearest Neighbors: {'n_neighbors': 7, 'weights': 'distance'}
# K-Nearest Neighbors Classifier:
# Best Parameters: {'n_neighbors': 7, 'weights': 'distance'}
# Accuracy: 0.75
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.75      0.70      0.72        69
#  Public University       0.75      0.80      0.77        79
#
#           accuracy                           0.75       148
#          macro avg       0.75      0.75      0.75       148
#       weighted avg       0.75      0.75      0.75       148
#
# ========================================
# Best Parameters for AdaBoost: {'learning_rate': 0.1, 'n_estimators': 200}
# AdaBoost Classifier:
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 200}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.86      0.72      0.79        69
#  Public University       0.79      0.90      0.84        79
#
#           accuracy                           0.82       148
#          macro avg       0.83      0.81      0.81       148
#       weighted avg       0.82      0.82      0.82       148
#
# ========================================
# Best Parameters for Gradient Boosting: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# Gradient Boosting Classifier:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# Accuracy: 0.80
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.77      0.79        69
#  Public University       0.80      0.84      0.82        79
#
#           accuracy                           0.80       148
#          macro avg       0.80      0.80      0.80       148
#       weighted avg       0.80      0.80      0.80       148
#
# ========================================
# Best Parameters for XGBClassifier: {'xgbclassifier__learning_rate': 0.1, 'xgbclassifier__max_depth': 3, 'xgbclassifier__n_estimators': 100}
# XGBClassifier Classifier:
# Best Parameters: {'xgbclassifier__learning_rate': 0.1, 'xgbclassifier__max_depth': 3, 'xgbclassifier__n_estimators': 100}
# Accuracy: 0.79
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.74      0.77        69
#  Public University       0.79      0.84      0.81        79
#
#           accuracy                           0.79       148
#          macro avg       0.79      0.79      0.79       148
#       weighted avg       0.79      0.79      0.79       148
#
# ========================================
# Best Parameters for LGBMClassifier: {'lgbmclassifier__learning_rate': 0.1, 'lgbmclassifier__max_depth': 3, 'lgbmclassifier__n_estimators': 50}
# LGBMClassifier Classifier:
# Best Parameters: {'lgbmclassifier__learning_rate': 0.1, 'lgbmclassifier__max_depth': 3, 'lgbmclassifier__n_estimators': 50}
# Accuracy: 0.79
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.74      0.77        69
#  Public University       0.79      0.84      0.81        79
#
#           accuracy                           0.79       148
#          macro avg       0.79      0.79      0.79       148
#       weighted avg       0.79      0.79      0.79       148
#
# ========================================
# 0:	learn: 0.6868663	total: 1.01ms	remaining: 49.7ms
# 1:	learn: 0.6814005	total: 1.71ms	remaining: 40.9ms
# 2:	learn: 0.6754672	total: 2.3ms	remaining: 36.1ms
# 3:	learn: 0.6704726	total: 2.88ms	remaining: 33.2ms
# 4:	learn: 0.6644908	total: 3.79ms	remaining: 34.1ms
# 5:	learn: 0.6590977	total: 4.5ms	remaining: 33ms
# 6:	learn: 0.6538749	total: 5.12ms	remaining: 31.5ms
# 7:	learn: 0.6482692	total: 5.75ms	remaining: 30.2ms
# 8:	learn: 0.6427020	total: 6.37ms	remaining: 29ms
# 9:	learn: 0.6373453	total: 7.08ms	remaining: 28.3ms
# 10:	learn: 0.6327744	total: 7.71ms	remaining: 27.4ms
# 11:	learn: 0.6276235	total: 8.38ms	remaining: 26.5ms
# 12:	learn: 0.6223434	total: 9.01ms	remaining: 25.7ms
# 13:	learn: 0.6172591	total: 9.69ms	remaining: 24.9ms
# 14:	learn: 0.6123337	total: 10.3ms	remaining: 24.1ms
# 15:	learn: 0.6083382	total: 11ms	remaining: 23.4ms
# 16:	learn: 0.6040393	total: 11.6ms	remaining: 22.6ms
# 17:	learn: 0.5999815	total: 12.3ms	remaining: 21.8ms
# 18:	learn: 0.5958844	total: 13ms	remaining: 21.2ms
# 19:	learn: 0.5918908	total: 13.6ms	remaining: 20.4ms
# 20:	learn: 0.5878581	total: 14.3ms	remaining: 19.8ms
# 21:	learn: 0.5841433	total: 15ms	remaining: 19.1ms
# 22:	learn: 0.5799324	total: 15.6ms	remaining: 18.3ms
# 23:	learn: 0.5768598	total: 16.3ms	remaining: 17.7ms
# 24:	learn: 0.5737263	total: 17ms	remaining: 17ms
# 25:	learn: 0.5701688	total: 17.6ms	remaining: 16.3ms
# 26:	learn: 0.5662766	total: 18.3ms	remaining: 15.6ms
# 27:	learn: 0.5631488	total: 18.9ms	remaining: 14.9ms
# 28:	learn: 0.5598610	total: 19.6ms	remaining: 14.2ms
# 29:	learn: 0.5569223	total: 20.2ms	remaining: 13.5ms
# 30:	learn: 0.5535717	total: 20.8ms	remaining: 12.8ms
# 31:	learn: 0.5501706	total: 21.5ms	remaining: 12.1ms
# 32:	learn: 0.5470293	total: 22.2ms	remaining: 11.4ms
# 33:	learn: 0.5437971	total: 22.8ms	remaining: 10.7ms
# 34:	learn: 0.5402152	total: 23.5ms	remaining: 10.1ms
# 35:	learn: 0.5375595	total: 24.2ms	remaining: 9.4ms
# 36:	learn: 0.5342802	total: 24.9ms	remaining: 8.74ms
# 37:	learn: 0.5321793	total: 25.6ms	remaining: 8.08ms
# 38:	learn: 0.5290094	total: 26.3ms	remaining: 7.41ms
# 39:	learn: 0.5266388	total: 26.9ms	remaining: 6.73ms
# 40:	learn: 0.5240598	total: 27.6ms	remaining: 6.06ms
# 41:	learn: 0.5213922	total: 28.3ms	remaining: 5.39ms
# 42:	learn: 0.5190590	total: 29ms	remaining: 4.72ms
# 43:	learn: 0.5166057	total: 29.7ms	remaining: 4.05ms
# 44:	learn: 0.5139191	total: 30.4ms	remaining: 3.38ms
# 45:	learn: 0.5116424	total: 31.1ms	remaining: 2.7ms
# 46:	learn: 0.5091899	total: 31.7ms	remaining: 2.02ms
# 47:	learn: 0.5071690	total: 32.4ms	remaining: 1.35ms
# 48:	learn: 0.5049375	total: 32.9ms	remaining: 672us
# 49:	learn: 0.5031668	total: 33.5ms	remaining: 0us
# 0:	learn: 0.6872832	total: 782us	remaining: 38.3ms
# 1:	learn: 0.6827018	total: 1.49ms	remaining: 35.8ms
# 2:	learn: 0.6766752	total: 2.21ms	remaining: 34.6ms
# 3:	learn: 0.6722427	total: 2.94ms	remaining: 33.8ms
# 4:	learn: 0.6665229	total: 3.64ms	remaining: 32.8ms
# 5:	learn: 0.6615718	total: 4.28ms	remaining: 31.4ms
# 6:	learn: 0.6567447	total: 4.94ms	remaining: 30.4ms
# 7:	learn: 0.6514536	total: 5.61ms	remaining: 29.4ms
# 8:	learn: 0.6467036	total: 6.24ms	remaining: 28.4ms
# 9:	learn: 0.6430548	total: 6.94ms	remaining: 27.8ms
# 10:	learn: 0.6391431	total: 7.62ms	remaining: 27ms
# 11:	learn: 0.6344705	total: 8.3ms	remaining: 26.3ms
# 12:	learn: 0.6304817	total: 8.91ms	remaining: 25.3ms
# 13:	learn: 0.6261376	total: 9.57ms	remaining: 24.6ms
# 14:	learn: 0.6218138	total: 10.3ms	remaining: 24ms
# 15:	learn: 0.6179495	total: 10.9ms	remaining: 23.2ms
# 16:	learn: 0.6140262	total: 11.6ms	remaining: 22.5ms
# 17:	learn: 0.6101008	total: 12.3ms	remaining: 21.9ms
# 18:	learn: 0.6060107	total: 13ms	remaining: 21.3ms
# 19:	learn: 0.6027312	total: 13.7ms	remaining: 20.6ms
# 20:	learn: 0.5982573	total: 14.4ms	remaining: 19.9ms
# 21:	learn: 0.5948340	total: 15ms	remaining: 19.2ms
# 22:	learn: 0.5912495	total: 15.7ms	remaining: 18.5ms
# 23:	learn: 0.5871486	total: 16.4ms	remaining: 17.8ms
# 24:	learn: 0.5836297	total: 17.2ms	remaining: 17.2ms
# 25:	learn: 0.5803839	total: 18ms	remaining: 16.6ms
# 26:	learn: 0.5779025	total: 18.7ms	remaining: 15.9ms
# 27:	learn: 0.5752576	total: 19.3ms	remaining: 15.2ms
# 28:	learn: 0.5722689	total: 20ms	remaining: 14.4ms
# 29:	learn: 0.5694003	total: 20.6ms	remaining: 13.8ms
# 30:	learn: 0.5661677	total: 21.3ms	remaining: 13ms
# 31:	learn: 0.5630435	total: 21.9ms	remaining: 12.3ms
# 32:	learn: 0.5602255	total: 22.5ms	remaining: 11.6ms
# 33:	learn: 0.5577239	total: 23.2ms	remaining: 10.9ms
# 34:	learn: 0.5547544	total: 23.9ms	remaining: 10.3ms
# 35:	learn: 0.5520102	total: 24.6ms	remaining: 9.56ms
# 36:	learn: 0.5489734	total: 25.3ms	remaining: 8.87ms
# 37:	learn: 0.5471293	total: 25.9ms	remaining: 8.19ms
# 38:	learn: 0.5443025	total: 26.7ms	remaining: 7.52ms
# 39:	learn: 0.5424401	total: 27.4ms	remaining: 6.84ms
# 40:	learn: 0.5398319	total: 28ms	remaining: 6.14ms
# 41:	learn: 0.5370000	total: 28.7ms	remaining: 5.47ms
# 42:	learn: 0.5345255	total: 29.4ms	remaining: 4.78ms
# 43:	learn: 0.5315560	total: 30ms	remaining: 4.09ms
# 44:	learn: 0.5287882	total: 30.5ms	remaining: 3.39ms
# 45:	learn: 0.5266053	total: 31.2ms	remaining: 2.71ms
# 46:	learn: 0.5241394	total: 31.8ms	remaining: 2.03ms
# 47:	learn: 0.5223813	total: 32.5ms	remaining: 1.35ms
# 48:	learn: 0.5205104	total: 33.1ms	remaining: 676us
# 49:	learn: 0.5184741	total: 33.7ms	remaining: 0us
# 0:	learn: 0.6877262	total: 791us	remaining: 38.8ms
# 1:	learn: 0.6832276	total: 1.5ms	remaining: 35.9ms
# 2:	learn: 0.6782654	total: 2.14ms	remaining: 33.6ms
# 3:	learn: 0.6736235	total: 2.82ms	remaining: 32.4ms
# 4:	learn: 0.6691454	total: 3.63ms	remaining: 32.6ms
# 5:	learn: 0.6641829	total: 4.38ms	remaining: 32.2ms
# 6:	learn: 0.6593917	total: 5.08ms	remaining: 31.2ms
# 7:	learn: 0.6540326	total: 5.76ms	remaining: 30.2ms
# 8:	learn: 0.6493661	total: 6.44ms	remaining: 29.3ms
# 9:	learn: 0.6453184	total: 7.18ms	remaining: 28.7ms
# 10:	learn: 0.6414618	total: 7.84ms	remaining: 27.8ms
# 11:	learn: 0.6369986	total: 8.45ms	remaining: 26.7ms
# 12:	learn: 0.6323054	total: 9.09ms	remaining: 25.9ms
# 13:	learn: 0.6278022	total: 9.75ms	remaining: 25.1ms
# 14:	learn: 0.6236969	total: 10.4ms	remaining: 24.3ms
# 15:	learn: 0.6206827	total: 11.1ms	remaining: 23.7ms
# 16:	learn: 0.6172778	total: 11.8ms	remaining: 22.9ms
# 17:	learn: 0.6126759	total: 12.5ms	remaining: 22.3ms
# 18:	learn: 0.6089489	total: 13.2ms	remaining: 21.6ms
# 19:	learn: 0.6055756	total: 14ms	remaining: 20.9ms
# 20:	learn: 0.6019607	total: 14.6ms	remaining: 20.2ms
# 21:	learn: 0.5984403	total: 15.3ms	remaining: 19.5ms
# 22:	learn: 0.5946468	total: 16.1ms	remaining: 18.8ms
# 23:	learn: 0.5917996	total: 16.7ms	remaining: 18.1ms
# 24:	learn: 0.5888555	total: 17.4ms	remaining: 17.4ms
# 25:	learn: 0.5856440	total: 18ms	remaining: 16.6ms
# 26:	learn: 0.5818312	total: 18.7ms	remaining: 15.9ms
# 27:	learn: 0.5781538	total: 19.4ms	remaining: 15.2ms
# 28:	learn: 0.5748420	total: 20.1ms	remaining: 14.5ms
# 29:	learn: 0.5716494	total: 20.8ms	remaining: 13.8ms
# 30:	learn: 0.5684561	total: 21.4ms	remaining: 13.1ms
# 31:	learn: 0.5655156	total: 22.7ms	remaining: 12.7ms
# 32:	learn: 0.5631463	total: 23.3ms	remaining: 12ms
# 33:	learn: 0.5599100	total: 24ms	remaining: 11.3ms
# 34:	learn: 0.5573076	total: 24.7ms	remaining: 10.6ms
# 35:	learn: 0.5548917	total: 25.3ms	remaining: 9.84ms
# 36:	learn: 0.5519571	total: 26ms	remaining: 9.15ms
# 37:	learn: 0.5500435	total: 26.8ms	remaining: 8.46ms
# 38:	learn: 0.5475672	total: 27.6ms	remaining: 7.77ms
# 39:	learn: 0.5454090	total: 28.3ms	remaining: 7.07ms
# 40:	learn: 0.5428375	total: 29ms	remaining: 6.36ms
# 41:	learn: 0.5407514	total: 29.7ms	remaining: 5.66ms
# 42:	learn: 0.5386578	total: 30.4ms	remaining: 4.95ms
# 43:	learn: 0.5364159	total: 31ms	remaining: 4.23ms
# 44:	learn: 0.5341746	total: 31.7ms	remaining: 3.52ms
# 45:	learn: 0.5322132	total: 32.4ms	remaining: 2.81ms
# 46:	learn: 0.5301642	total: 33ms	remaining: 2.11ms
# 47:	learn: 0.5277136	total: 33.7ms	remaining: 1.41ms
# 48:	learn: 0.5253963	total: 34.4ms	remaining: 702us
# 49:	learn: 0.5237259	total: 35.1ms	remaining: 0us
# 0:	learn: 0.6875972	total: 816us	remaining: 40ms
# 1:	learn: 0.6829733	total: 1.51ms	remaining: 36.2ms
# 2:	learn: 0.6780102	total: 2.19ms	remaining: 34.4ms
# 3:	learn: 0.6735629	total: 2.89ms	remaining: 33.2ms
# 4:	learn: 0.6691520	total: 3.53ms	remaining: 31.8ms
# 5:	learn: 0.6643747	total: 4.17ms	remaining: 30.5ms
# 6:	learn: 0.6600408	total: 4.82ms	remaining: 29.6ms
# 7:	learn: 0.6552275	total: 5.46ms	remaining: 28.6ms
# 8:	learn: 0.6508267	total: 6.06ms	remaining: 27.6ms
# 9:	learn: 0.6471666	total: 6.78ms	remaining: 27.1ms
# 10:	learn: 0.6436159	total: 7.5ms	remaining: 26.6ms
# 11:	learn: 0.6396309	total: 8.23ms	remaining: 26.1ms
# 12:	learn: 0.6353051	total: 8.94ms	remaining: 25.4ms
# 13:	learn: 0.6312182	total: 9.61ms	remaining: 24.7ms
# 14:	learn: 0.6270268	total: 10.3ms	remaining: 24.1ms
# 15:	learn: 0.6231667	total: 11.1ms	remaining: 23.5ms
# 16:	learn: 0.6193835	total: 11.7ms	remaining: 22.8ms
# 17:	learn: 0.6156262	total: 12.4ms	remaining: 22ms
# 18:	learn: 0.6121290	total: 13ms	remaining: 21.3ms
# 19:	learn: 0.6089084	total: 13.7ms	remaining: 20.6ms
# 20:	learn: 0.6056080	total: 14.4ms	remaining: 19.9ms
# 21:	learn: 0.6018944	total: 15.1ms	remaining: 19.3ms
# 22:	learn: 0.5983766	total: 15.9ms	remaining: 18.6ms
# 23:	learn: 0.5948860	total: 16.6ms	remaining: 17.9ms
# 24:	learn: 0.5922010	total: 17.3ms	remaining: 17.3ms
# 25:	learn: 0.5892553	total: 18ms	remaining: 16.6ms
# 26:	learn: 0.5858466	total: 18.7ms	remaining: 15.9ms
# 27:	learn: 0.5824550	total: 19.4ms	remaining: 15.2ms
# 28:	learn: 0.5794793	total: 20ms	remaining: 14.5ms
# 29:	learn: 0.5768859	total: 20.7ms	remaining: 13.8ms
# 30:	learn: 0.5744254	total: 21.3ms	remaining: 13.1ms
# 31:	learn: 0.5718641	total: 22.1ms	remaining: 12.4ms
# 32:	learn: 0.5693891	total: 22.8ms	remaining: 11.8ms
# 33:	learn: 0.5665992	total: 23.5ms	remaining: 11ms
# 34:	learn: 0.5639325	total: 24.1ms	remaining: 10.3ms
# 35:	learn: 0.5612750	total: 24.8ms	remaining: 9.63ms
# 36:	learn: 0.5584156	total: 25.5ms	remaining: 8.95ms
# 37:	learn: 0.5560067	total: 26.3ms	remaining: 8.31ms
# 38:	learn: 0.5533726	total: 27ms	remaining: 7.61ms
# 39:	learn: 0.5515888	total: 27.6ms	remaining: 6.91ms
# 40:	learn: 0.5491418	total: 28.3ms	remaining: 6.21ms
# 41:	learn: 0.5468768	total: 29ms	remaining: 5.52ms
# 42:	learn: 0.5447814	total: 29.6ms	remaining: 4.83ms
# 43:	learn: 0.5421690	total: 30.4ms	remaining: 4.15ms
# 44:	learn: 0.5396050	total: 31.1ms	remaining: 3.46ms
# 45:	learn: 0.5375324	total: 31.8ms	remaining: 2.77ms
# 46:	learn: 0.5354619	total: 32.5ms	remaining: 2.07ms
# 47:	learn: 0.5337436	total: 33.1ms	remaining: 1.38ms
# 48:	learn: 0.5318845	total: 33.8ms	remaining: 689us
# 49:	learn: 0.5303339	total: 34.4ms	remaining: 0us
# 0:	learn: 0.6875884	total: 751us	remaining: 36.8ms
# 1:	learn: 0.6822927	total: 1.47ms	remaining: 35.2ms
# 2:	learn: 0.6767420	total: 2.16ms	remaining: 33.9ms
# 3:	learn: 0.6716257	total: 2.9ms	remaining: 33.3ms
# 4:	learn: 0.6668915	total: 3.63ms	remaining: 32.6ms
# 5:	learn: 0.6616803	total: 4.34ms	remaining: 31.9ms
# 6:	learn: 0.6569745	total: 5.12ms	remaining: 31.4ms
# 7:	learn: 0.6517955	total: 5.75ms	remaining: 30.2ms
# 8:	learn: 0.6465375	total: 6.41ms	remaining: 29.2ms
# 9:	learn: 0.6426664	total: 7.07ms	remaining: 28.3ms
# 10:	learn: 0.6381281	total: 7.7ms	remaining: 27.3ms
# 11:	learn: 0.6336053	total: 8.33ms	remaining: 26.4ms
# 12:	learn: 0.6286553	total: 9ms	remaining: 25.6ms
# 13:	learn: 0.6236874	total: 9.67ms	remaining: 24.9ms
# 14:	learn: 0.6187991	total: 10.3ms	remaining: 24.1ms
# 15:	learn: 0.6150228	total: 11ms	remaining: 23.3ms
# 16:	learn: 0.6110111	total: 11.7ms	remaining: 22.6ms
# 17:	learn: 0.6065896	total: 12.3ms	remaining: 22ms
# 18:	learn: 0.6029137	total: 13.1ms	remaining: 21.3ms
# 19:	learn: 0.5997727	total: 13.8ms	remaining: 20.6ms
# 20:	learn: 0.5958916	total: 14.5ms	remaining: 20ms
# 21:	learn: 0.5918876	total: 15.2ms	remaining: 19.3ms
# 22:	learn: 0.5880530	total: 15.8ms	remaining: 18.6ms
# 23:	learn: 0.5845353	total: 16.6ms	remaining: 17.9ms
# 24:	learn: 0.5815035	total: 17.2ms	remaining: 17.2ms
# 25:	learn: 0.5780698	total: 17.9ms	remaining: 16.6ms
# 26:	learn: 0.5742251	total: 18.6ms	remaining: 15.9ms
# 27:	learn: 0.5705091	total: 19.3ms	remaining: 15.2ms
# 28:	learn: 0.5674702	total: 20ms	remaining: 14.5ms
# 29:	learn: 0.5644944	total: 20.6ms	remaining: 13.7ms
# 30:	learn: 0.5619685	total: 21.3ms	remaining: 13ms
# 31:	learn: 0.5590086	total: 22ms	remaining: 12.4ms
# 32:	learn: 0.5557920	total: 22.7ms	remaining: 11.7ms
# 33:	learn: 0.5526695	total: 23.3ms	remaining: 11ms
# 34:	learn: 0.5493399	total: 24ms	remaining: 10.3ms
# 35:	learn: 0.5464232	total: 24.7ms	remaining: 9.59ms
# 36:	learn: 0.5432279	total: 25.3ms	remaining: 8.9ms
# 37:	learn: 0.5412651	total: 26ms	remaining: 8.21ms
# 38:	learn: 0.5381316	total: 26.7ms	remaining: 7.52ms
# 39:	learn: 0.5359098	total: 27.2ms	remaining: 6.81ms
# 40:	learn: 0.5332752	total: 27.9ms	remaining: 6.13ms
# 41:	learn: 0.5303116	total: 28.7ms	remaining: 5.46ms
# 42:	learn: 0.5281542	total: 29.4ms	remaining: 4.78ms
# 43:	learn: 0.5252449	total: 30.1ms	remaining: 4.1ms
# 44:	learn: 0.5223108	total: 30.7ms	remaining: 3.42ms
# 45:	learn: 0.5207185	total: 31.4ms	remaining: 2.73ms
# 46:	learn: 0.5181570	total: 32ms	remaining: 2.04ms
# 47:	learn: 0.5162732	total: 32.7ms	remaining: 1.36ms
# 48:	learn: 0.5143593	total: 33.3ms	remaining: 680us
# 49:	learn: 0.5123948	total: 34ms	remaining: 0us
# 0:	learn: 0.6868663	total: 685us	remaining: 67.9ms
# 1:	learn: 0.6814005	total: 1.41ms	remaining: 68.9ms
# 2:	learn: 0.6754672	total: 2.09ms	remaining: 67.6ms
# 3:	learn: 0.6704726	total: 2.81ms	remaining: 67.5ms
# 4:	learn: 0.6644908	total: 3.49ms	remaining: 66.3ms
# 5:	learn: 0.6590977	total: 4.15ms	remaining: 65ms
# 6:	learn: 0.6538749	total: 4.81ms	remaining: 64ms
# 7:	learn: 0.6482692	total: 5.45ms	remaining: 62.7ms
# 8:	learn: 0.6427020	total: 6.11ms	remaining: 61.8ms
# 9:	learn: 0.6373453	total: 6.82ms	remaining: 61.4ms
# 10:	learn: 0.6327744	total: 7.58ms	remaining: 61.3ms
# 11:	learn: 0.6276235	total: 8.26ms	remaining: 60.6ms
# 12:	learn: 0.6223434	total: 8.97ms	remaining: 60.1ms
# 13:	learn: 0.6172591	total: 9.7ms	remaining: 59.6ms
# 14:	learn: 0.6123337	total: 10.4ms	remaining: 59.1ms
# 15:	learn: 0.6083382	total: 11.1ms	remaining: 58.5ms
# 16:	learn: 0.6040393	total: 11.8ms	remaining: 57.6ms
# 17:	learn: 0.5999815	total: 12.4ms	remaining: 56.6ms
# 18:	learn: 0.5958844	total: 13.4ms	remaining: 57.2ms
# 19:	learn: 0.5918908	total: 14.4ms	remaining: 57.5ms
# 20:	learn: 0.5878581	total: 15.1ms	remaining: 56.7ms
# 21:	learn: 0.5841433	total: 15.7ms	remaining: 55.7ms
# 22:	learn: 0.5799324	total: 16.4ms	remaining: 54.8ms
# 23:	learn: 0.5768598	total: 17.2ms	remaining: 54.4ms
# 24:	learn: 0.5737263	total: 18ms	remaining: 53.9ms
# 25:	learn: 0.5701688	total: 18.7ms	remaining: 53.2ms
# 26:	learn: 0.5662766	total: 19.4ms	remaining: 52.4ms
# 27:	learn: 0.5631488	total: 20ms	remaining: 51.4ms
# 28:	learn: 0.5598610	total: 20.7ms	remaining: 50.7ms
# 29:	learn: 0.5569223	total: 21.4ms	remaining: 49.8ms
# 30:	learn: 0.5535717	total: 22ms	remaining: 48.9ms
# 31:	learn: 0.5501706	total: 22.6ms	remaining: 48ms
# 32:	learn: 0.5470293	total: 23.3ms	remaining: 47.2ms
# 33:	learn: 0.5437971	total: 23.9ms	remaining: 46.4ms
# 34:	learn: 0.5402152	total: 24.6ms	remaining: 45.6ms
# 35:	learn: 0.5375595	total: 25.2ms	remaining: 44.8ms
# 36:	learn: 0.5342802	total: 25.8ms	remaining: 44ms
# 37:	learn: 0.5321793	total: 26.5ms	remaining: 43.2ms
# 38:	learn: 0.5290094	total: 27.1ms	remaining: 42.4ms
# 39:	learn: 0.5266388	total: 27.7ms	remaining: 41.6ms
# 40:	learn: 0.5240598	total: 28.3ms	remaining: 40.8ms
# 41:	learn: 0.5213922	total: 29ms	remaining: 40ms
# 42:	learn: 0.5190590	total: 29.7ms	remaining: 39.4ms
# 43:	learn: 0.5166057	total: 30.4ms	remaining: 38.7ms
# 44:	learn: 0.5139191	total: 31.1ms	remaining: 38ms
# 45:	learn: 0.5116424	total: 31.7ms	remaining: 37.2ms
# 46:	learn: 0.5091899	total: 32.3ms	remaining: 36.4ms
# 47:	learn: 0.5071690	total: 32.9ms	remaining: 35.7ms
# 48:	learn: 0.5049375	total: 33.7ms	remaining: 35.1ms
# 49:	learn: 0.5031668	total: 34.4ms	remaining: 34.4ms
# 50:	learn: 0.5011150	total: 35.1ms	remaining: 33.7ms
# 51:	learn: 0.4988867	total: 35.8ms	remaining: 33ms
# 52:	learn: 0.4968135	total: 36.4ms	remaining: 32.3ms
# 53:	learn: 0.4947801	total: 37ms	remaining: 31.6ms
# 54:	learn: 0.4924947	total: 37.7ms	remaining: 30.9ms
# 55:	learn: 0.4910862	total: 38.4ms	remaining: 30.2ms
# 56:	learn: 0.4888462	total: 39.1ms	remaining: 29.5ms
# 57:	learn: 0.4869152	total: 39.8ms	remaining: 28.8ms
# 58:	learn: 0.4846103	total: 40.4ms	remaining: 28.1ms
# 59:	learn: 0.4823235	total: 41.1ms	remaining: 27.4ms
# 60:	learn: 0.4806470	total: 41.8ms	remaining: 26.7ms
# 61:	learn: 0.4788680	total: 42.5ms	remaining: 26.1ms
# 62:	learn: 0.4769173	total: 43.2ms	remaining: 25.4ms
# 63:	learn: 0.4754990	total: 43.8ms	remaining: 24.7ms
# 64:	learn: 0.4739170	total: 44.5ms	remaining: 24ms
# 65:	learn: 0.4722958	total: 45.2ms	remaining: 23.3ms
# 66:	learn: 0.4705583	total: 45.8ms	remaining: 22.6ms
# 67:	learn: 0.4692728	total: 46.5ms	remaining: 21.9ms
# 68:	learn: 0.4676432	total: 47.1ms	remaining: 21.2ms
# 69:	learn: 0.4661660	total: 47.7ms	remaining: 20.5ms
# 70:	learn: 0.4643539	total: 48.5ms	remaining: 19.8ms
# 71:	learn: 0.4629842	total: 49.2ms	remaining: 19.1ms
# 72:	learn: 0.4615986	total: 49.9ms	remaining: 18.4ms
# 73:	learn: 0.4602064	total: 50.5ms	remaining: 17.8ms
# 74:	learn: 0.4588958	total: 51.2ms	remaining: 17.1ms
# 75:	learn: 0.4579056	total: 51.8ms	remaining: 16.4ms
# 76:	learn: 0.4561636	total: 52.5ms	remaining: 15.7ms
# 77:	learn: 0.4550493	total: 53.2ms	remaining: 15ms
# 78:	learn: 0.4536592	total: 53.8ms	remaining: 14.3ms
# 79:	learn: 0.4524551	total: 54.4ms	remaining: 13.6ms
# 80:	learn: 0.4507393	total: 55.2ms	remaining: 12.9ms
# 81:	learn: 0.4491614	total: 55.8ms	remaining: 12.3ms
# 82:	learn: 0.4477903	total: 56.7ms	remaining: 11.6ms
# 83:	learn: 0.4461839	total: 57.4ms	remaining: 10.9ms
# 84:	learn: 0.4452156	total: 58.2ms	remaining: 10.3ms
# 85:	learn: 0.4438329	total: 58.9ms	remaining: 9.59ms
# 86:	learn: 0.4425104	total: 59.5ms	remaining: 8.9ms
# 87:	learn: 0.4413613	total: 60.3ms	remaining: 8.22ms
# 88:	learn: 0.4403856	total: 60.9ms	remaining: 7.53ms
# 89:	learn: 0.4390246	total: 61.5ms	remaining: 6.83ms
# 90:	learn: 0.4382190	total: 62.1ms	remaining: 6.14ms
# 91:	learn: 0.4369667	total: 62.7ms	remaining: 5.46ms
# 92:	learn: 0.4359441	total: 63.4ms	remaining: 4.77ms
# 93:	learn: 0.4347952	total: 64.1ms	remaining: 4.09ms
# 94:	learn: 0.4338611	total: 64.7ms	remaining: 3.41ms
# 95:	learn: 0.4329095	total: 65.4ms	remaining: 2.72ms
# 96:	learn: 0.4317551	total: 66ms	remaining: 2.04ms
# 97:	learn: 0.4309700	total: 66.6ms	remaining: 1.36ms
# 98:	learn: 0.4299161	total: 67.2ms	remaining: 679us
# 99:	learn: 0.4292105	total: 67.9ms	remaining: 0us
# 0:	learn: 0.6872832	total: 720us	remaining: 71.3ms
# 1:	learn: 0.6827018	total: 1.42ms	remaining: 69.6ms
# 2:	learn: 0.6766752	total: 2.11ms	remaining: 68.3ms
# 3:	learn: 0.6722427	total: 2.82ms	remaining: 67.6ms
# 4:	learn: 0.6665229	total: 3.56ms	remaining: 67.6ms
# 5:	learn: 0.6615718	total: 4.19ms	remaining: 65.6ms
# 6:	learn: 0.6567447	total: 4.83ms	remaining: 64.1ms
# 7:	learn: 0.6514536	total: 5.53ms	remaining: 63.6ms
# 8:	learn: 0.6467036	total: 6.3ms	remaining: 63.7ms
# 9:	learn: 0.6430548	total: 7.03ms	remaining: 63.3ms
# 10:	learn: 0.6391431	total: 7.75ms	remaining: 62.7ms
# 11:	learn: 0.6344705	total: 8.43ms	remaining: 61.8ms
# 12:	learn: 0.6304817	total: 9.09ms	remaining: 60.9ms
# 13:	learn: 0.6261376	total: 9.78ms	remaining: 60.1ms
# 14:	learn: 0.6218138	total: 10.5ms	remaining: 59.5ms
# 15:	learn: 0.6179495	total: 11.1ms	remaining: 58.5ms
# 16:	learn: 0.6140262	total: 11.8ms	remaining: 57.8ms
# 17:	learn: 0.6101008	total: 12.5ms	remaining: 56.9ms
# 18:	learn: 0.6060107	total: 13.2ms	remaining: 56.2ms
# 19:	learn: 0.6027312	total: 13.9ms	remaining: 55.6ms
# 20:	learn: 0.5982573	total: 14.6ms	remaining: 54.9ms
# 21:	learn: 0.5948340	total: 15.2ms	remaining: 54ms
# 22:	learn: 0.5912495	total: 15.9ms	remaining: 53.2ms
# 23:	learn: 0.5871486	total: 16.5ms	remaining: 52.3ms
# 24:	learn: 0.5836297	total: 17.2ms	remaining: 51.5ms
# ...
# 186:	learn: 0.0275948	total: 2s	remaining: 139ms
# 187:	learn: 0.0275782	total: 2.01s	remaining: 128ms
# 188:	learn: 0.0275675	total: 2.02s	remaining: 117ms
# 189:	learn: 0.0275550	total: 2.03s	remaining: 107ms
# 190:	learn: 0.0275373	total: 2.04s	remaining: 96.1ms
# 191:	learn: 0.0275215	total: 2.05s	remaining: 85.4ms
# 192:	learn: 0.0275212	total: 2.06s	remaining: 74.7ms
# 193:	learn: 0.0275212	total: 2.07s	remaining: 64ms
# 194:	learn: 0.0275167	total: 2.08s	remaining: 53.3ms
# 195:	learn: 0.0275010	total: 2.09s	remaining: 42.7ms
# 196:	learn: 0.0274999	total: 2.1s	remaining: 32ms
# 197:	learn: 0.0274997	total: 2.12s	remaining: 21.4ms
# 198:	learn: 0.0274848	total: 2.13s	remaining: 10.7ms
# 199:	learn: 0.0274847	total: 2.14s	remaining: 0us
# 0:	learn: 0.4301799	total: 13.2ms	remaining: 2.63s
# 1:	learn: 0.2969953	total: 25.3ms	remaining: 2.51s
# 2:	learn: 0.2420788	total: 36.7ms	remaining: 2.41s
# 3:	learn: 0.1944280	total: 48ms	remaining: 2.35s
# 4:	learn: 0.1610833	total: 61ms	remaining: 2.38s
# 5:	learn: 0.1436471	total: 71.8ms	remaining: 2.32s
# 6:	learn: 0.1384983	total: 72.7ms	remaining: 2s
# 7:	learn: 0.1197067	total: 83.4ms	remaining: 2s
# 8:	learn: 0.1070366	total: 93.5ms	remaining: 1.98s
# 9:	learn: 0.1009470	total: 104ms	remaining: 1.98s
# 10:	learn: 0.0928341	total: 116ms	remaining: 1.99s
# 11:	learn: 0.0855174	total: 129ms	remaining: 2.02s
# 12:	learn: 0.0772447	total: 140ms	remaining: 2.01s
# 13:	learn: 0.0737147	total: 152ms	remaining: 2.02s
# 14:	learn: 0.0690331	total: 164ms	remaining: 2.02s
# 15:	learn: 0.0639638	total: 177ms	remaining: 2.03s
# 16:	learn: 0.0604384	total: 188ms	remaining: 2.02s
# 17:	learn: 0.0578913	total: 200ms	remaining: 2.02s
# 18:	learn: 0.0551069	total: 210ms	remaining: 2s
# 19:	learn: 0.0532207	total: 221ms	remaining: 1.98s
# 20:	learn: 0.0512702	total: 231ms	remaining: 1.97s
# 21:	learn: 0.0497255	total: 242ms	remaining: 1.96s
# 22:	learn: 0.0484836	total: 255ms	remaining: 1.96s
# 23:	learn: 0.0473282	total: 265ms	remaining: 1.95s
# 24:	learn: 0.0458951	total: 278ms	remaining: 1.94s
# 25:	learn: 0.0451336	total: 290ms	remaining: 1.94s
# 26:	learn: 0.0442222	total: 301ms	remaining: 1.93s
# 27:	learn: 0.0435993	total: 311ms	remaining: 1.91s
# 28:	learn: 0.0427369	total: 322ms	remaining: 1.9s
# 29:	learn: 0.0419663	total: 332ms	remaining: 1.88s
# 30:	learn: 0.0414341	total: 345ms	remaining: 1.88s
# 31:	learn: 0.0407672	total: 355ms	remaining: 1.86s
# 32:	learn: 0.0402836	total: 365ms	remaining: 1.85s
# 33:	learn: 0.0397437	total: 375ms	remaining: 1.83s
# 34:	learn: 0.0392534	total: 385ms	remaining: 1.81s
# 35:	learn: 0.0388062	total: 395ms	remaining: 1.8s
# 36:	learn: 0.0384980	total: 407ms	remaining: 1.79s
# 37:	learn: 0.0381036	total: 419ms	remaining: 1.78s
# 38:	learn: 0.0377153	total: 429ms	remaining: 1.77s
# 39:	learn: 0.0373758	total: 439ms	remaining: 1.75s
# 40:	learn: 0.0370322	total: 449ms	remaining: 1.74s
# 41:	learn: 0.0367550	total: 459ms	remaining: 1.73s
# 42:	learn: 0.0364680	total: 469ms	remaining: 1.71s
# 43:	learn: 0.0362342	total: 479ms	remaining: 1.7s
# 44:	learn: 0.0360837	total: 491ms	remaining: 1.69s
# 45:	learn: 0.0358442	total: 503ms	remaining: 1.68s
# 46:	learn: 0.0356201	total: 513ms	remaining: 1.67s
# 47:	learn: 0.0353863	total: 525ms	remaining: 1.66s
# 48:	learn: 0.0352052	total: 534ms	remaining: 1.65s
# 49:	learn: 0.0350048	total: 544ms	remaining: 1.63s
# 50:	learn: 0.0348049	total: 555ms	remaining: 1.62s
# 51:	learn: 0.0346144	total: 566ms	remaining: 1.61s
# 52:	learn: 0.0344313	total: 578ms	remaining: 1.6s
# 53:	learn: 0.0342590	total: 589ms	remaining: 1.59s
# 54:	learn: 0.0341156	total: 599ms	remaining: 1.58s
# 55:	learn: 0.0339678	total: 610ms	remaining: 1.57s
# 56:	learn: 0.0338171	total: 621ms	remaining: 1.56s
# 57:	learn: 0.0336983	total: 631ms	remaining: 1.54s
# 58:	learn: 0.0335560	total: 641ms	remaining: 1.53s
# 59:	learn: 0.0334280	total: 652ms	remaining: 1.52s
# 60:	learn: 0.0333313	total: 662ms	remaining: 1.51s
# 61:	learn: 0.0332078	total: 673ms	remaining: 1.5s
# 62:	learn: 0.0331152	total: 685ms	remaining: 1.49s
# 63:	learn: 0.0330033	total: 695ms	remaining: 1.48s
# 64:	learn: 0.0328973	total: 705ms	remaining: 1.47s
# 65:	learn: 0.0327907	total: 717ms	remaining: 1.46s
# 66:	learn: 0.0326788	total: 727ms	remaining: 1.44s
# 67:	learn: 0.0325773	total: 738ms	remaining: 1.43s
# 68:	learn: 0.0324891	total: 749ms	remaining: 1.42s
# 69:	learn: 0.0324073	total: 760ms	remaining: 1.41s
# 70:	learn: 0.0323153	total: 772ms	remaining: 1.4s
# 71:	learn: 0.0322204	total: 785ms	remaining: 1.39s
# 72:	learn: 0.0321461	total: 795ms	remaining: 1.38s
# 73:	learn: 0.0320522	total: 807ms	remaining: 1.37s
# 74:	learn: 0.0319811	total: 819ms	remaining: 1.36s
# 75:	learn: 0.0319087	total: 830ms	remaining: 1.35s
# 76:	learn: 0.0318325	total: 844ms	remaining: 1.35s
# 77:	learn: 0.0317728	total: 854ms	remaining: 1.34s
# 78:	learn: 0.0317131	total: 865ms	remaining: 1.32s
# 79:	learn: 0.0316402	total: 875ms	remaining: 1.31s
# 80:	learn: 0.0315620	total: 886ms	remaining: 1.3s
# 81:	learn: 0.0314973	total: 896ms	remaining: 1.29s
# 82:	learn: 0.0314479	total: 908ms	remaining: 1.28s
# 83:	learn: 0.0313828	total: 921ms	remaining: 1.27s
# 84:	learn: 0.0313236	total: 934ms	remaining: 1.26s
# 85:	learn: 0.0312755	total: 957ms	remaining: 1.27s
# 86:	learn: 0.0312132	total: 968ms	remaining: 1.26s
# 87:	learn: 0.0311681	total: 980ms	remaining: 1.25s
# 88:	learn: 0.0311118	total: 991ms	remaining: 1.24s
# 89:	learn: 0.0310652	total: 1s	remaining: 1.22s
# 90:	learn: 0.0310159	total: 1.01s	remaining: 1.21s
# 91:	learn: 0.0309635	total: 1.03s	remaining: 1.2s
# 92:	learn: 0.0309254	total: 1.04s	remaining: 1.19s
# 93:	learn: 0.0308741	total: 1.05s	remaining: 1.18s
# 94:	learn: 0.0308381	total: 1.06s	remaining: 1.18s
# 95:	learn: 0.0307955	total: 1.08s	remaining: 1.17s
# 96:	learn: 0.0307559	total: 1.09s	remaining: 1.16s
# 97:	learn: 0.0307150	total: 1.11s	remaining: 1.15s
# 98:	learn: 0.0306711	total: 1.13s	remaining: 1.15s
# 99:	learn: 0.0306257	total: 1.15s	remaining: 1.15s
# 100:	learn: 0.0305845	total: 1.16s	remaining: 1.13s
# 101:	learn: 0.0305386	total: 1.17s	remaining: 1.12s
# 102:	learn: 0.0304947	total: 1.18s	remaining: 1.11s
# 103:	learn: 0.0304513	total: 1.19s	remaining: 1.1s
# 104:	learn: 0.0304060	total: 1.2s	remaining: 1.09s
# 105:	learn: 0.0303689	total: 1.21s	remaining: 1.07s
# 106:	learn: 0.0303373	total: 1.22s	remaining: 1.06s
# 107:	learn: 0.0303031	total: 1.23s	remaining: 1.05s
# 108:	learn: 0.0302714	total: 1.24s	remaining: 1.04s
# 109:	learn: 0.0302327	total: 1.25s	remaining: 1.02s
# 110:	learn: 0.0302011	total: 1.26s	remaining: 1.01s
# 111:	learn: 0.0301723	total: 1.27s	remaining: 1s
# 112:	learn: 0.0301430	total: 1.28s	remaining: 989ms
# 113:	learn: 0.0301145	total: 1.3s	remaining: 978ms
# 114:	learn: 0.0300819	total: 1.31s	remaining: 966ms
# 115:	learn: 0.0300423	total: 1.32s	remaining: 956ms
# 116:	learn: 0.0300168	total: 1.33s	remaining: 946ms
# 117:	learn: 0.0299869	total: 1.34s	remaining: 934ms
# 118:	learn: 0.0299589	total: 1.36s	remaining: 924ms
# 119:	learn: 0.0299365	total: 1.37s	remaining: 915ms
# 120:	learn: 0.0299072	total: 1.39s	remaining: 905ms
# 121:	learn: 0.0298789	total: 1.4s	remaining: 896ms
# 122:	learn: 0.0298524	total: 1.41s	remaining: 885ms
# 123:	learn: 0.0298281	total: 1.42s	remaining: 873ms
# 124:	learn: 0.0298023	total: 1.44s	remaining: 861ms
# 125:	learn: 0.0297833	total: 1.45s	remaining: 849ms
# 126:	learn: 0.0297591	total: 1.46s	remaining: 837ms
# 127:	learn: 0.0297370	total: 1.47s	remaining: 825ms
# 128:	learn: 0.0297122	total: 1.48s	remaining: 812ms
# 129:	learn: 0.0296871	total: 1.49s	remaining: 800ms
# 130:	learn: 0.0296663	total: 1.5s	remaining: 788ms
# 131:	learn: 0.0296423	total: 1.51s	remaining: 776ms
# 132:	learn: 0.0296187	total: 1.52s	remaining: 766ms
# 133:	learn: 0.0295964	total: 1.53s	remaining: 755ms
# 134:	learn: 0.0295819	total: 1.55s	remaining: 745ms
# 135:	learn: 0.0295605	total: 1.56s	remaining: 732ms
# 136:	learn: 0.0295361	total: 1.57s	remaining: 721ms
# 137:	learn: 0.0295161	total: 1.58s	remaining: 709ms
# 138:	learn: 0.0294952	total: 1.59s	remaining: 698ms
# 139:	learn: 0.0294791	total: 1.6s	remaining: 686ms
# 140:	learn: 0.0294587	total: 1.61s	remaining: 675ms
# 141:	learn: 0.0294391	total: 1.62s	remaining: 663ms
# 142:	learn: 0.0294200	total: 1.63s	remaining: 651ms
# 143:	learn: 0.0294031	total: 1.65s	remaining: 640ms
# 144:	learn: 0.0293852	total: 1.66s	remaining: 629ms
# 145:	learn: 0.0293678	total: 1.67s	remaining: 618ms
# 146:	learn: 0.0293537	total: 1.68s	remaining: 606ms
# 147:	learn: 0.0293359	total: 1.69s	remaining: 594ms
# 148:	learn: 0.0293187	total: 1.7s	remaining: 582ms
# 149:	learn: 0.0293025	total: 1.71s	remaining: 570ms
# 150:	learn: 0.0292863	total: 1.72s	remaining: 558ms
# 151:	learn: 0.0292733	total: 1.73s	remaining: 546ms
# 152:	learn: 0.0292581	total: 1.74s	remaining: 534ms
# 153:	learn: 0.0292451	total: 1.75s	remaining: 523ms
# 154:	learn: 0.0292303	total: 1.76s	remaining: 512ms
# 155:	learn: 0.0292148	total: 1.77s	remaining: 500ms
# 156:	learn: 0.0291963	total: 1.78s	remaining: 488ms
# 157:	learn: 0.0291906	total: 1.79s	remaining: 476ms
# 158:	learn: 0.0291723	total: 1.8s	remaining: 465ms
# 159:	learn: 0.0291568	total: 1.81s	remaining: 453ms
# 160:	learn: 0.0291424	total: 1.82s	remaining: 441ms
# 161:	learn: 0.0291275	total: 1.83s	remaining: 430ms
# 162:	learn: 0.0291118	total: 1.84s	remaining: 419ms
# 163:	learn: 0.0290980	total: 1.85s	remaining: 407ms
# 164:	learn: 0.0290857	total: 1.87s	remaining: 396ms
# 165:	learn: 0.0290848	total: 1.88s	remaining: 385ms
# 166:	learn: 0.0290768	total: 1.89s	remaining: 374ms
# 167:	learn: 0.0290627	total: 1.9s	remaining: 362ms
# 168:	learn: 0.0290492	total: 1.91s	remaining: 351ms
# 169:	learn: 0.0290385	total: 1.92s	remaining: 340ms
# 170:	learn: 0.0290384	total: 1.94s	remaining: 329ms
# 171:	learn: 0.0290271	total: 1.95s	remaining: 317ms
# 172:	learn: 0.0290135	total: 1.96s	remaining: 306ms
# 173:	learn: 0.0290021	total: 1.98s	remaining: 295ms
# 174:	learn: 0.0289888	total: 1.99s	remaining: 284ms
# 175:	learn: 0.0289758	total: 2s	remaining: 272ms
# 176:	learn: 0.0289662	total: 2.01s	remaining: 261ms
# 177:	learn: 0.0289659	total: 2.02s	remaining: 250ms
# 178:	learn: 0.0289609	total: 2.03s	remaining: 238ms
# 179:	learn: 0.0289485	total: 2.04s	remaining: 227ms
# 180:	learn: 0.0289389	total: 2.05s	remaining: 215ms
# 181:	learn: 0.0289297	total: 2.06s	remaining: 204ms
# 182:	learn: 0.0289172	total: 2.07s	remaining: 193ms
# 183:	learn: 0.0289085	total: 2.09s	remaining: 181ms
# 184:	learn: 0.0288994	total: 2.1s	remaining: 170ms
# 185:	learn: 0.0288879	total: 2.11s	remaining: 159ms
# 186:	learn: 0.0288760	total: 2.12s	remaining: 147ms
# 187:	learn: 0.0288673	total: 2.13s	remaining: 136ms
# 188:	learn: 0.0288673	total: 2.14s	remaining: 125ms
# 189:	learn: 0.0288571	total: 2.15s	remaining: 113ms
# 190:	learn: 0.0288450	total: 2.17s	remaining: 102ms
# 191:	learn: 0.0288348	total: 2.18s	remaining: 90.7ms
# 192:	learn: 0.0288233	total: 2.2s	remaining: 79.7ms
# 193:	learn: 0.0288114	total: 2.21s	remaining: 68.2ms
# 194:	learn: 0.0288114	total: 2.22s	remaining: 56.9ms
# 195:	learn: 0.0288114	total: 2.23s	remaining: 45.5ms
# 196:	learn: 0.0288006	total: 2.24s	remaining: 34.1ms
# 197:	learn: 0.0287883	total: 2.25s	remaining: 22.7ms
# 198:	learn: 0.0287882	total: 2.26s	remaining: 11.3ms
# 199:	learn: 0.0287866	total: 2.27s	remaining: 0us
# 0:	learn: 0.6190186	total: 10.9ms	remaining: 532ms
# 1:	learn: 0.5576193	total: 21ms	remaining: 503ms
# 2:	learn: 0.5083644	total: 31.1ms	remaining: 488ms
# 3:	learn: 0.4654048	total: 41.1ms	remaining: 473ms
# 4:	learn: 0.4290283	total: 46.8ms	remaining: 421ms
# 5:	learn: 0.3990635	total: 59.1ms	remaining: 433ms
# 6:	learn: 0.3762378	total: 70.7ms	remaining: 434ms
# 7:	learn: 0.3510063	total: 80.9ms	remaining: 425ms
# 8:	learn: 0.3293127	total: 91.5ms	remaining: 417ms
# 9:	learn: 0.3125933	total: 101ms	remaining: 405ms
# 10:	learn: 0.2946532	total: 112ms	remaining: 396ms
# 11:	learn: 0.2819383	total: 124ms	remaining: 391ms
# 12:	learn: 0.2692606	total: 133ms	remaining: 379ms
# 13:	learn: 0.2567921	total: 143ms	remaining: 367ms
# 14:	learn: 0.2467202	total: 153ms	remaining: 357ms
# 15:	learn: 0.2346286	total: 164ms	remaining: 349ms
# 16:	learn: 0.2264383	total: 176ms	remaining: 342ms
# 17:	learn: 0.2182334	total: 187ms	remaining: 333ms
# 18:	learn: 0.2093219	total: 197ms	remaining: 322ms
# 19:	learn: 0.2068444	total: 198ms	remaining: 297ms
# 20:	learn: 0.1994215	total: 208ms	remaining: 287ms
# 21:	learn: 0.1930716	total: 218ms	remaining: 277ms
# 22:	learn: 0.1895746	total: 224ms	remaining: 263ms
# 23:	learn: 0.1848663	total: 233ms	remaining: 253ms
# 24:	learn: 0.1791170	total: 246ms	remaining: 246ms
# 25:	learn: 0.1744854	total: 258ms	remaining: 238ms
# 26:	learn: 0.1692940	total: 268ms	remaining: 228ms
# 27:	learn: 0.1638579	total: 278ms	remaining: 218ms
# 28:	learn: 0.1614355	total: 290ms	remaining: 210ms
# 29:	learn: 0.1581731	total: 301ms	remaining: 201ms
# 30:	learn: 0.1546178	total: 314ms	remaining: 192ms
# 31:	learn: 0.1538040	total: 314ms	remaining: 177ms
# 32:	learn: 0.1495018	total: 326ms	remaining: 168ms
# 33:	learn: 0.1491350	total: 327ms	remaining: 154ms
# 34:	learn: 0.1455037	total: 337ms	remaining: 145ms
# 35:	learn: 0.1419848	total: 349ms	remaining: 136ms
# 36:	learn: 0.1391216	total: 360ms	remaining: 126ms
# 37:	learn: 0.1365134	total: 372ms	remaining: 117ms
# 38:	learn: 0.1341387	total: 382ms	remaining: 108ms
# 39:	learn: 0.1309072	total: 392ms	remaining: 97.9ms
# 40:	learn: 0.1290343	total: 402ms	remaining: 88.2ms
# 41:	learn: 0.1263754	total: 412ms	remaining: 78.4ms
# 42:	learn: 0.1258236	total: 413ms	remaining: 67.3ms
# 43:	learn: 0.1240701	total: 423ms	remaining: 57.7ms
# 44:	learn: 0.1236145	total: 424ms	remaining: 47.1ms
# 45:	learn: 0.1203397	total: 434ms	remaining: 37.7ms
# 46:	learn: 0.1181875	total: 444ms	remaining: 28.4ms
# 47:	learn: 0.1160492	total: 455ms	remaining: 19ms
# 48:	learn: 0.1138572	total: 465ms	remaining: 9.49ms
# 49:	learn: 0.1124299	total: 475ms	remaining: 0us
# Best Parameters for CatBoostClassifier: {'catboostclassifier__learning_rate': 0.1, 'catboostclassifier__max_depth': 10, 'catboostclassifier__n_estimators': 50}
# CatBoostClassifier Classifier:
# Best Parameters: {'catboostclassifier__learning_rate': 0.1, 'catboostclassifier__max_depth': 10, 'catboostclassifier__n_estimators': 50}
# Accuracy: 0.79
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.74      0.77        69
#  Public University       0.79      0.84      0.81        79
#
#           accuracy                           0.79       148
#          macro avg       0.79      0.79      0.79       148
#       weighted avg       0.79      0.79      0.79       148
#
# ========================================
# Best Parameters for ExtraTreesClassifier: {'extratreesclassifier__max_depth': 20, 'extratreesclassifier__min_samples_leaf': 1, 'extratreesclassifier__min_samples_split': 2, 'extratreesclassifier__n_estimators': 50}
# ExtraTreesClassifier Classifier:
# Best Parameters: {'extratreesclassifier__max_depth': 20, 'extratreesclassifier__min_samples_leaf': 1, 'extratreesclassifier__min_samples_split': 2, 'extratreesclassifier__n_estimators': 50}
# Accuracy: 0.75
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.75      0.70      0.72        69
#  Public University       0.75      0.80      0.77        79
#
#           accuracy                           0.75       148
#          macro avg       0.75      0.75      0.75       148
#       weighted avg       0.75      0.75      0.75       148
#
# ========================================
# Best Parameters for BaggingClassifier: {'baggingclassifier__max_features': 0.5, 'baggingclassifier__max_samples': 0.5, 'baggingclassifier__n_estimators': 100}
# BaggingClassifier Classifier:
# Best Parameters: {'baggingclassifier__max_features': 0.5, 'baggingclassifier__max_samples': 0.5, 'baggingclassifier__n_estimators': 100}
# Accuracy: 0.80
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.77      0.78        69
#  Public University       0.80      0.82      0.81        79
#
#           accuracy                           0.80       148
#          macro avg       0.80      0.80      0.80       148
#       weighted avg       0.80      0.80      0.80       148
#
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Assuming the last column is the target variable
target_column = 'Name of your current institution? '

# Remove leading and trailing spaces from the target column
df[target_column] = df[target_column].str.strip()

# Oversample both Public University and Private University to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=X.select_dtypes(include=['object']).columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a more complex ANN model with Dropout and BatchNormalization
ann_model = Sequential()
ann_model.add(Dense(units=128, activation='relu', input_dim=X_train_scaled.shape[1]))
ann_model.add(Dropout(0.5))  # Increase dropout rate
ann_model.add(Dense(units=64, activation='relu'))
ann_model.add(BatchNormalization())
ann_model.add(Dense(units=32, activation='relu'))
ann_model.add(Dropout(0.3))  # Add another dropout layer
ann_model.add(Dense(units=1, activation='sigmoid'))

# Compile the model with a lower learning rate
ann_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the ANN model and get history
history = ann_model.fit(X_train_scaled, y_train, epochs=70, batch_size=16, validation_data=(X_test_scaled, y_test), verbose=1)

# Predictions using the ANN
y_pred_ann = (ann_model.predict(X_test_scaled) > 0.5).astype("int32").flatten()

# Evaluate the ANN
accuracy = accuracy_score(y_test, y_pred_ann)
print('For ANN, the accuracy is= ', accuracy)
# Out:
# Epoch 1/70
# 37/37 [==============================] - 3s 10ms/step - loss: 1.0489 - accuracy: 0.5186 - val_loss: 0.7403 - val_accuracy: 0.5000
# Epoch 2/70
# 37/37 [==============================] - 0s 5ms/step - loss: 1.0532 - accuracy: 0.5085 - val_loss: 0.7349 - val_accuracy: 0.4730
# Epoch 3/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.9329 - accuracy: 0.5525 - val_loss: 0.7304 - val_accuracy: 0.4730
# Epoch 4/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.9558 - accuracy: 0.5186 - val_loss: 0.7250 - val_accuracy: 0.4865
# Epoch 5/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.8737 - accuracy: 0.5373 - val_loss: 0.7206 - val_accuracy: 0.4932
# Epoch 6/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.8235 - accuracy: 0.5559 - val_loss: 0.7104 - val_accuracy: 0.4932
# Epoch 7/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.8404 - accuracy: 0.5424 - val_loss: 0.7003 - val_accuracy: 0.5203
# Epoch 8/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.8008 - accuracy: 0.5678 - val_loss: 0.6906 - val_accuracy: 0.5405
# Epoch 9/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.7969 - accuracy: 0.5797 - val_loss: 0.6774 - val_accuracy: 0.5541
# Epoch 10/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.7388 - accuracy: 0.5915 - val_loss: 0.6660 - val_accuracy: 0.5946
# Epoch 11/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.7647 - accuracy: 0.6017 - val_loss: 0.6512 - val_accuracy: 0.6216
# Epoch 12/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.7522 - accuracy: 0.5949 - val_loss: 0.6369 - val_accuracy: 0.6554
# Epoch 13/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.7473 - accuracy: 0.5932 - val_loss: 0.6269 - val_accuracy: 0.6622
# Epoch 14/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6660 - accuracy: 0.6237 - val_loss: 0.6153 - val_accuracy: 0.6824
# Epoch 15/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.7228 - accuracy: 0.6017 - val_loss: 0.6046 - val_accuracy: 0.7095
# Epoch 16/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6535 - accuracy: 0.6373 - val_loss: 0.5991 - val_accuracy: 0.7162
# Epoch 17/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6669 - accuracy: 0.6475 - val_loss: 0.5919 - val_accuracy: 0.7027
# Epoch 18/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.6644 - val_loss: 0.5867 - val_accuracy: 0.7095
# Epoch 19/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6994 - accuracy: 0.6254 - val_loss: 0.5799 - val_accuracy: 0.7162
# Epoch 20/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6685 - accuracy: 0.6441 - val_loss: 0.5744 - val_accuracy: 0.6959
# Epoch 21/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6816 - accuracy: 0.6390 - val_loss: 0.5683 - val_accuracy: 0.6892
# Epoch 22/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.6339 - val_loss: 0.5624 - val_accuracy: 0.7095
# Epoch 23/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6319 - accuracy: 0.6661 - val_loss: 0.5572 - val_accuracy: 0.7095
# Epoch 24/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6588 - accuracy: 0.6525 - val_loss: 0.5543 - val_accuracy: 0.7095
# Epoch 25/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6269 - accuracy: 0.6864 - val_loss: 0.5513 - val_accuracy: 0.7162
# Epoch 26/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6212 - accuracy: 0.6661 - val_loss: 0.5478 - val_accuracy: 0.7230
# Epoch 27/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6236 - accuracy: 0.6814 - val_loss: 0.5465 - val_accuracy: 0.7230
# Epoch 28/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6053 - accuracy: 0.6780 - val_loss: 0.5432 - val_accuracy: 0.7230
# Epoch 29/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5800 - accuracy: 0.7068 - val_loss: 0.5418 - val_accuracy: 0.7365
# Epoch 30/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5792 - accuracy: 0.7000 - val_loss: 0.5402 - val_accuracy: 0.7432
# Epoch 31/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6105 - accuracy: 0.6746 - val_loss: 0.5376 - val_accuracy: 0.7365
# Epoch 32/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.6013 - accuracy: 0.6864 - val_loss: 0.5341 - val_accuracy: 0.7432
# Epoch 33/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5735 - accuracy: 0.6932 - val_loss: 0.5309 - val_accuracy: 0.7500
# Epoch 34/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5750 - accuracy: 0.7169 - val_loss: 0.5280 - val_accuracy: 0.7500
# Epoch 35/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5788 - accuracy: 0.6898 - val_loss: 0.5255 - val_accuracy: 0.7500
# Epoch 36/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5886 - accuracy: 0.6898 - val_loss: 0.5241 - val_accuracy: 0.7500
# Epoch 37/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5613 - accuracy: 0.7136 - val_loss: 0.5239 - val_accuracy: 0.7432
# Epoch 38/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5394 - accuracy: 0.7339 - val_loss: 0.5229 - val_accuracy: 0.7432
# Epoch 39/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5837 - accuracy: 0.6814 - val_loss: 0.5217 - val_accuracy: 0.7432
# Epoch 40/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5349 - accuracy: 0.7356 - val_loss: 0.5181 - val_accuracy: 0.7500
# Epoch 41/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5431 - accuracy: 0.7356 - val_loss: 0.5173 - val_accuracy: 0.7432
# Epoch 42/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5445 - accuracy: 0.7169 - val_loss: 0.5159 - val_accuracy: 0.7365
# Epoch 43/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5218 - accuracy: 0.7492 - val_loss: 0.5154 - val_accuracy: 0.7297
# Epoch 44/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5421 - accuracy: 0.6966 - val_loss: 0.5154 - val_accuracy: 0.7230
# Epoch 45/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5202 - accuracy: 0.7424 - val_loss: 0.5127 - val_accuracy: 0.7365
# Epoch 46/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5668 - accuracy: 0.7203 - val_loss: 0.5126 - val_accuracy: 0.7365
# Epoch 47/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5162 - accuracy: 0.7593 - val_loss: 0.5109 - val_accuracy: 0.7365
# Epoch 48/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5198 - accuracy: 0.7203 - val_loss: 0.5095 - val_accuracy: 0.7365
# Epoch 49/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5291 - accuracy: 0.7339 - val_loss: 0.5066 - val_accuracy: 0.7365
# Epoch 50/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4812 - accuracy: 0.7610 - val_loss: 0.5050 - val_accuracy: 0.7432
# Epoch 51/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5253 - accuracy: 0.7237 - val_loss: 0.5028 - val_accuracy: 0.7432
# Epoch 52/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5226 - accuracy: 0.7508 - val_loss: 0.5019 - val_accuracy: 0.7500
# Epoch 53/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4986 - accuracy: 0.7373 - val_loss: 0.5008 - val_accuracy: 0.7432
# Epoch 54/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5209 - accuracy: 0.7492 - val_loss: 0.4987 - val_accuracy: 0.7500
# Epoch 55/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4781 - accuracy: 0.7881 - val_loss: 0.4968 - val_accuracy: 0.7635
# Epoch 56/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5158 - accuracy: 0.7441 - val_loss: 0.4968 - val_accuracy: 0.7568
# Epoch 57/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5444 - accuracy: 0.7593 - val_loss: 0.4943 - val_accuracy: 0.7568
# Epoch 58/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5237 - accuracy: 0.7610 - val_loss: 0.4922 - val_accuracy: 0.7568
# Epoch 59/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5449 - accuracy: 0.7237 - val_loss: 0.4911 - val_accuracy: 0.7635
# Epoch 60/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5041 - accuracy: 0.7712 - val_loss: 0.4908 - val_accuracy: 0.7635
# Epoch 61/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5117 - accuracy: 0.7542 - val_loss: 0.4912 - val_accuracy: 0.7635
# Epoch 62/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5171 - accuracy: 0.7424 - val_loss: 0.4917 - val_accuracy: 0.7703
# Epoch 63/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5100 - accuracy: 0.7525 - val_loss: 0.4906 - val_accuracy: 0.7703
# Epoch 64/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4705 - accuracy: 0.7932 - val_loss: 0.4886 - val_accuracy: 0.7703
# Epoch 65/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5201 - accuracy: 0.7322 - val_loss: 0.4877 - val_accuracy: 0.7703
# Epoch 66/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4955 - accuracy: 0.7729 - val_loss: 0.4876 - val_accuracy: 0.7703
# Epoch 67/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4966 - accuracy: 0.7525 - val_loss: 0.4869 - val_accuracy: 0.7703
# Epoch 68/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4923 - accuracy: 0.7525 - val_loss: 0.4857 - val_accuracy: 0.7770
# Epoch 69/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4985 - accuracy: 0.7644 - val_loss: 0.4850 - val_accuracy: 0.7770
# Epoch 70/70
# 37/37 [==============================] - 0s 5ms/step - loss: 0.4803 - accuracy: 0.7746 - val_loss: 0.4852 - val_accuracy: 0.7770
# 5/5 [==============================] - 0s 2ms/step
# For ANN, the accuracy is=  0.777027027027027

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Oversample both Public University and Private University to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a more complex ANN model with Dropout and BatchNormalization
ann_model = Sequential()
ann_model.add(Dense(units=512, activation='relu', input_dim=X_train_scaled.shape[1]))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.5))
ann_model.add(Dense(units=256, activation='relu'))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.4))
ann_model.add(Dense(units=128, activation='relu'))
ann_model.add(Dropout(0.3))
ann_model.add(Dense(units=64, activation='relu'))
ann_model.add(Dropout(0.2))
ann_model.add(Dense(units=1, activation='sigmoid'))

# Implement learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,
    decay_steps=1000,
    decay_rate=0.9
)
ann_model.compile(optimizer=Adam(learning_rate=lr_schedule), loss='binary_crossentropy', metrics=['accuracy'])

# Train the ANN model and get history
history = ann_model.fit(X_train_scaled, y_train, epochs=70, batch_size=16, validation_data=(X_test_scaled, y_test))

# Predictions using the ANN
y_pred_ann = (ann_model.predict(X_test_scaled) > 0.5).astype("int32").flatten()

# Evaluate the ANN
print('For ANN:')
print('Accuracy:', accuracy_score(y_test, y_pred_ann))
print('Classification Report:')
print(classification_report(y_test, y_pred_ann))
# Out:
# Epoch 1/70
# 91/91 [==============================] - 4s 8ms/step - loss: 0.6867 - accuracy: 0.6326 - val_loss: 0.6246 - val_accuracy: 0.7845
# Epoch 2/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.5968 - accuracy: 0.6920 - val_loss: 0.5281 - val_accuracy: 0.8204
# Epoch 3/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.5017 - accuracy: 0.7479 - val_loss: 0.4316 - val_accuracy: 0.8619
# Epoch 4/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.4487 - accuracy: 0.7831 - val_loss: 0.3624 - val_accuracy: 0.8453
# Epoch 5/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.4270 - accuracy: 0.7997 - val_loss: 0.3242 - val_accuracy: 0.8453
# Epoch 6/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.4049 - accuracy: 0.8204 - val_loss: 0.3039 - val_accuracy: 0.8425
# Epoch 7/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3840 - accuracy: 0.8322 - val_loss: 0.2916 - val_accuracy: 0.8481
# Epoch 8/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3528 - accuracy: 0.8370 - val_loss: 0.2809 - val_accuracy: 0.8481
# Epoch 9/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3411 - accuracy: 0.8522 - val_loss: 0.2720 - val_accuracy: 0.8536
# Epoch 10/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3118 - accuracy: 0.8715 - val_loss: 0.2670 - val_accuracy: 0.8425
# Epoch 11/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3195 - accuracy: 0.8619 - val_loss: 0.2655 - val_accuracy: 0.8591
# Epoch 12/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3100 - accuracy: 0.8619 - val_loss: 0.2656 - val_accuracy: 0.8508
# Epoch 13/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.3198 - accuracy: 0.8674 - val_loss: 0.2625 - val_accuracy: 0.8591
# Epoch 14/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2855 - accuracy: 0.8729 - val_loss: 0.2618 - val_accuracy: 0.8646
# Epoch 15/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2885 - accuracy: 0.8819 - val_loss: 0.2595 - val_accuracy: 0.8785
# Epoch 16/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2936 - accuracy: 0.8854 - val_loss: 0.2582 - val_accuracy: 0.8674
# Epoch 17/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2485 - accuracy: 0.8978 - val_loss: 0.2563 - val_accuracy: 0.8729
# Epoch 18/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2906 - accuracy: 0.8854 - val_loss: 0.2538 - val_accuracy: 0.8840
# Epoch 19/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2554 - accuracy: 0.8957 - val_loss: 0.2571 - val_accuracy: 0.8840
# Epoch 20/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2743 - accuracy: 0.8833 - val_loss: 0.2530 - val_accuracy: 0.8757
# Epoch 21/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2472 - accuracy: 0.9116 - val_loss: 0.2507 - val_accuracy: 0.8785
# Epoch 22/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2604 - accuracy: 0.8964 - val_loss: 0.2479 - val_accuracy: 0.8785
# Epoch 23/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2440 - accuracy: 0.9033 - val_loss: 0.2506 - val_accuracy: 0.8812
# Epoch 24/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2712 - accuracy: 0.8943 - val_loss: 0.2525 - val_accuracy: 0.8812
# Epoch 25/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2513 - accuracy: 0.8999 - val_loss: 0.2510 - val_accuracy: 0.8785
# Epoch 26/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2580 - accuracy: 0.8957 - val_loss: 0.2484 - val_accuracy: 0.8840
# Epoch 27/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2679 - accuracy: 0.9033 - val_loss: 0.2449 - val_accuracy: 0.8867
# Epoch 28/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2203 - accuracy: 0.9081 - val_loss: 0.2430 - val_accuracy: 0.8895
# Epoch 29/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2600 - accuracy: 0.9047 - val_loss: 0.2415 - val_accuracy: 0.8867
# Epoch 30/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2190 - accuracy: 0.9178 - val_loss: 0.2412 - val_accuracy: 0.8867
# Epoch 31/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2350 - accuracy: 0.9137 - val_loss: 0.2393 - val_accuracy: 0.8840
# Epoch 32/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2368 - accuracy: 0.9026 - val_loss: 0.2383 - val_accuracy: 0.8867
# Epoch 33/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2130 - accuracy: 0.9151 - val_loss: 0.2416 - val_accuracy: 0.8840
# Epoch 34/70
# 91/91 [==============================] - 0s 5ms/step - loss: 0.2306 - accuracy: 0.9157 - val_loss: 0.2395 - val_accuracy: 0.8895
# Epoch 35/70
# 91/91 [==============================] - 0s 5ms/step - loss: 0.2196 - accuracy: 0.9130 - val_loss: 0.2399 - val_accuracy: 0.8923
# Epoch 36/70
# 91/91 [==============================] - 0s 5ms/step - loss: 0.2252 - accuracy: 0.9054 - val_loss: 0.2394 - val_accuracy: 0.8895
# Epoch 37/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2210 - accuracy: 0.9144 - val_loss: 0.2437 - val_accuracy: 0.8867
# Epoch 38/70
# 91/91 [==============================] - 1s 5ms/step - loss: 0.2383 - accuracy: 0.9012 - val_loss: 0.2426 - val_accuracy: 0.8840
# Epoch 39/70
# 91/91 [==============================] - 1s 5ms/step - loss: 0.2003 - accuracy: 0.9192 - val_loss: 0.2404 - val_accuracy: 0.8867
# Epoch 40/70
# 91/91 [==============================] - 0s 5ms/step - loss: 0.2104 - accuracy: 0.9164 - val_loss: 0.2394 - val_accuracy: 0.8895
# Epoch 41/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2164 - accuracy: 0.9164 - val_loss: 0.2383 - val_accuracy: 0.8923
# Epoch 42/70
# 91/91 [==============================] - 0s 5ms/step - loss: 0.1996 - accuracy: 0.9268 - val_loss: 0.2379 - val_accuracy: 0.8895
# Epoch 43/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1925 - accuracy: 0.9254 - val_loss: 0.2395 - val_accuracy: 0.8950
# Epoch 44/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2229 - accuracy: 0.9151 - val_loss: 0.2365 - val_accuracy: 0.8923
# Epoch 45/70
# 91/91 [==============================] - 1s 5ms/step - loss: 0.1920 - accuracy: 0.9275 - val_loss: 0.2376 - val_accuracy: 0.8895
# Epoch 46/70
# 91/91 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.9282 - val_loss: 0.2365 - val_accuracy: 0.8867
# Epoch 47/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2054 - accuracy: 0.9220 - val_loss: 0.2390 - val_accuracy: 0.8950
# Epoch 48/70
# 91/91 [==============================] - 1s 7ms/step - loss: 0.1878 - accuracy: 0.9282 - val_loss: 0.2394 - val_accuracy: 0.8978
# Epoch 49/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1965 - accuracy: 0.9296 - val_loss: 0.2383 - val_accuracy: 0.8978
# Epoch 50/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1975 - accuracy: 0.9123 - val_loss: 0.2374 - val_accuracy: 0.8978
# Epoch 51/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1811 - accuracy: 0.9309 - val_loss: 0.2389 - val_accuracy: 0.9033
# Epoch 52/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1954 - accuracy: 0.9185 - val_loss: 0.2389 - val_accuracy: 0.8978
# Epoch 53/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1888 - accuracy: 0.9220 - val_loss: 0.2387 - val_accuracy: 0.8978
# Epoch 54/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1702 - accuracy: 0.9358 - val_loss: 0.2376 - val_accuracy: 0.8978
# Epoch 55/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1625 - accuracy: 0.9344 - val_loss: 0.2394 - val_accuracy: 0.8978
# Epoch 56/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1818 - accuracy: 0.9289 - val_loss: 0.2379 - val_accuracy: 0.8950
# Epoch 57/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1872 - accuracy: 0.9289 - val_loss: 0.2393 - val_accuracy: 0.9006
# Epoch 58/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.2192 - accuracy: 0.9199 - val_loss: 0.2393 - val_accuracy: 0.8978
# Epoch 59/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1899 - accuracy: 0.9227 - val_loss: 0.2439 - val_accuracy: 0.8950
# Epoch 60/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1777 - accuracy: 0.9282 - val_loss: 0.2426 - val_accuracy: 0.8978
# Epoch 61/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1661 - accuracy: 0.9309 - val_loss: 0.2431 - val_accuracy: 0.8978
# Epoch 62/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1781 - accuracy: 0.9323 - val_loss: 0.2406 - val_accuracy: 0.8978
# Epoch 63/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1809 - accuracy: 0.9385 - val_loss: 0.2387 - val_accuracy: 0.8978
# Epoch 64/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1762 - accuracy: 0.9268 - val_loss: 0.2378 - val_accuracy: 0.9033
# Epoch 65/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1803 - accuracy: 0.9323 - val_loss: 0.2373 - val_accuracy: 0.9033
# Epoch 66/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1834 - accuracy: 0.9289 - val_loss: 0.2390 - val_accuracy: 0.9006
# Epoch 67/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1538 - accuracy: 0.9385 - val_loss: 0.2429 - val_accuracy: 0.8978
# Epoch 68/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1688 - accuracy: 0.9372 - val_loss: 0.2443 - val_accuracy: 0.8978
# Epoch 69/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1788 - accuracy: 0.9296 - val_loss: 0.2470 - val_accuracy: 0.8978
# Epoch 70/70
# 91/91 [==============================] - 1s 6ms/step - loss: 0.1712 - accuracy: 0.9282 - val_loss: 0.2451 - val_accuracy: 0.9061
# 12/12 [==============================] - 0s 2ms/step
# For ANN:
# Accuracy: 0.9060773480662984
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89       151
#            1       0.91      0.93      0.92       211
#
#     accuracy                           0.91       362
#    macro avg       0.90      0.90      0.90       362
# weighted avg       0.91      0.91      0.91       362

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the file path
file_path = "/kaggle/input/undergrad/Undergraduate.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)


# Convert the target column to numeric, handling errors by setting them to NaN
balanced_df['What was your SSC GPA?'] = pd.to_numeric(balanced_df['What was your SSC GPA?'], errors='coerce')

# Drop rows with NaN values in the target column
balanced_df = balanced_df.dropna(subset=['What was your SSC GPA?'])

# Separate features (X) and target variable (y)
target_column = 'What was your SSC GPA?'
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features (optional but recommended for linear regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the linear regression model
linear_model = LinearRegression()
linear_model.fit(X_train_scaled, y_train)

# Initialize and train the decision tree regressor model
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_scaled, y_train)

# Initialize and train the random forest regressor model
rf_model = RandomForestRegressor()
rf_model.fit(X_train_scaled, y_train)

# Initialize and train the gradient boosting regressor model
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train_scaled, y_train)

# Initialize and train the support vector regressor model
svr_model = SVR()
svr_model.fit(X_train_scaled, y_train)

# Initialize and train the k-nearest neighbors regressor model
knn_model = KNeighborsRegressor()
knn_model.fit(X_train_scaled, y_train)

# Initialize and train the lasso regression model
lasso_model = Lasso()
lasso_model.fit(X_train_scaled, y_train)

# Make predictions on the test set for each model
linear_pred = linear_model.predict(X_test_scaled)
dt_pred = dt_model.predict(X_test_scaled)
rf_pred = rf_model.predict(X_test_scaled)
gb_pred = gb_model.predict(X_test_scaled)
svr_pred = svr_model.predict(X_test_scaled)
knn_pred = knn_model.predict(X_test_scaled)
lasso_pred = lasso_model.predict(X_test_scaled)

# Evaluate each model
linear_mse = mean_squared_error(y_test, linear_pred)
linear_r2 = r2_score(y_test, linear_pred)

dt_mse = mean_squared_error(y_test, dt_pred)
dt_r2 = r2_score(y_test, dt_pred)

rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)

gb_mse = mean_squared_error(y_test, gb_pred)
gb_r2 = r2_score(y_test, gb_pred)

svr_mse = mean_squared_error(y_test, svr_pred)
svr_r2 = r2_score(y_test, svr_pred)

knn_mse = mean_squared_error(y_test, knn_pred)
knn_r2 = r2_score(y_test, knn_pred)

lasso_mse = mean_squared_error(y_test, lasso_pred)
lasso_r2 = r2_score(y_test, lasso_pred)

# Print the results
print(f'Linear Regression - Mean Squared Error: {linear_mse}, R-squared: {linear_r2}')
print(f'Decision Tree Regressor - Mean Squared Error: {dt_mse}, R-squared: {dt_r2}')
print(f'Random Forest Regressor - Mean Squared Error: {rf_mse}, R-squared: {rf_r2}')
print(f'Gradient Boosting Regressor - Mean Squared Error: {gb_mse}, R-squared: {gb_r2}')
print(f'Support Vector Regressor - Mean Squared Error: {svr_mse}, R-squared: {svr_r2}')
print(f'K-Nearest Neighbors Regressor - Mean Squared Error: {knn_mse}, R-squared: {knn_r2}')
print(f'Lasso Regression - Mean Squared Error: {lasso_mse}, R-squared: {lasso_r2}')
# Out:
# Linear Regression - Mean Squared Error: 0.029818181362078706, R-squared: 0.44099083243354176
# Decision Tree Regressor - Mean Squared Error: 0.020192610497237574, R-squared: 0.6214439020278467
# Random Forest Regressor - Mean Squared Error: 0.010336774810338824, R-squared: 0.8062138058695268
# Gradient Boosting Regressor - Mean Squared Error: 0.016326693365423757, R-squared: 0.6939192515971035
# Support Vector Regressor - Mean Squared Error: 0.017477589250600334, R-squared: 0.672343108407284
# K-Nearest Neighbors Regressor - Mean Squared Error: 0.021597116022099447, R-squared: 0.5951132732493252
# Lasso Regression - Mean Squared Error: 0.05334118635725406, R-squared: -1.0336142513001079e-06

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# Define the file path
file_path = "/kaggle/input/undergrad/Undergraduate.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Oversample both Public University and Private University to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Convert the target column to numeric, handling errors by setting them to NaN
balanced_df['What was your SSC GPA?'] = pd.to_numeric(balanced_df['What was your SSC GPA?'], errors='coerce')

# Drop rows with NaN values in the target column
balanced_df = balanced_df.dropna(subset=['What was your SSC GPA?'])

# Separate features (X) and target variable (y)
target_column = 'What was your SSC GPA?'
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features (optional but recommended for linear regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the linear regression model
linear_model = LinearRegression()
linear_model.fit(X_train_scaled, y_train)

# Initialize and train the decision tree regressor model
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_scaled, y_train)

# Initialize and train the random forest regressor model
rf_model = RandomForestRegressor()
rf_model.fit(X_train_scaled, y_train)

# Initialize and train the gradient boosting regressor model
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train_scaled, y_train)

# Initialize and train the support vector regressor model
svr_model = SVR()
svr_model.fit(X_train_scaled, y_train)

# Initialize and train the k-nearest neighbors regressor model
knn_model = KNeighborsRegressor()
knn_model.fit(X_train_scaled, y_train)

# Initialize and train the lasso regression model
lasso_model = Lasso()
lasso_model.fit(X_train_scaled, y_train)

# Make predictions on the test set for each model
linear_pred = linear_model.predict(X_test_scaled)
dt_pred = dt_model.predict(X_test_scaled)
rf_pred = rf_model.predict(X_test_scaled)
gb_pred = gb_model.predict(X_test_scaled)
svr_pred = svr_model.predict(X_test_scaled)
knn_pred = knn_model.predict(X_test_scaled)
lasso_pred = lasso_model.predict(X_test_scaled)

# Evaluate each model
linear_mse = mean_squared_error(y_test, linear_pred)
linear_r2 = r2_score(y_test, linear_pred)

dt_mse = mean_squared_error(y_test, dt_pred)
dt_r2 = r2_score(y_test, dt_pred)

rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)

gb_mse = mean_squared_error(y_test, gb_pred)
gb_r2 = r2_score(y_test, gb_pred)

svr_mse = mean_squared_error(y_test, svr_pred)
svr_r2 = r2_score(y_test, svr_pred)

knn_mse = mean_squared_error(y_test, knn_pred)
knn_r2 = r2_score(y_test, knn_pred)

lasso_mse = mean_squared_error(y_test, lasso_pred)
lasso_r2 = r2_score(y_test, lasso_pred)

# Print the results
print(f'Linear Regression - Mean Squared Error: {linear_mse}, R-squared: {linear_r2}')
print(f'Decision Tree Regressor - Mean Squared Error: {dt_mse}, R-squared: {dt_r2}')
print(f'Random Forest Regressor - Mean Squared Error: {rf_mse}, R-squared: {rf_r2}')
print(f'Gradient Boosting Regressor - Mean Squared Error: {gb_mse}, R-squared: {gb_r2}')
print(f'Support Vector Regressor - Mean Squared Error: {svr_mse}, R-squared: {svr_r2}')
print(f'K-Nearest Neighbors Regressor - Mean Squared Error: {knn_mse}, R-squared: {knn_r2}')
print(f'Lasso Regression - Mean Squared Error: {lasso_mse}, R-squared: {lasso_r2}')
# Out:
# Linear Regression - Mean Squared Error: 0.029818181362078706, R-squared: 0.44099083243354176
# Decision Tree Regressor - Mean Squared Error: 0.020312776243093928, R-squared: 0.6191911236727392
# Random Forest Regressor - Mean Squared Error: 0.010078814467764484, R-squared: 0.8110498552119267
# Gradient Boosting Regressor - Mean Squared Error: 0.01636828662950495, R-squared: 0.6931394919045835
# Support Vector Regressor - Mean Squared Error: 0.017477589250600334, R-squared: 0.672343108407284
# K-Nearest Neighbors Regressor - Mean Squared Error: 0.021597116022099447, R-squared: 0.5951132732493252
# Lasso Regression - Mean Squared Error: 0.05334118635725406, R-squared: -1.0336142513001079e-06

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from imblearn.over_sampling import RandomOverSampler

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Assuming the last column is the target variable
target_column = df.columns[-1]

# Remove leading and trailing spaces from the target column
df[target_column] = df[target_column].str.strip()

# Oversample both Public University and Private University to balance the classes
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=[target_column]), df[target_column])
balanced_df = pd.concat([X_resampled, y_resampled], axis=1)

# Separate features (X) and target variable (y) from the balanced dataset
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)  # Assuming y contains class labels 0 and 1

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Data preprocessing
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# ELM implementation
class ELMClassifierManual:
    def __init__(self, input_size, hidden_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.input_weights = np.random.rand(input_size, hidden_size)
        self.bias = np.random.rand(hidden_size)
        self.output_weights = None

    def train(self, X, y):
        hidden_layer_output = self.sigmoid(X.dot(self.input_weights) + self.bias)
        self.output_weights = np.linalg.pinv(hidden_layer_output).dot(y)

    def predict(self, X):
        hidden_layer_output = self.sigmoid(X.dot(self.input_weights) + self.bias)
        predictions = hidden_layer_output.dot(self.output_weights)
        return np.round(predictions).astype(int)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

# Initialize ELMClassifier
elm_classifier = ELMClassifierManual(input_size=X_train_scaled.shape[1], hidden_size=100)

# Train ELMClassifier
elm_classifier.train(X_train_scaled, y_train)

# Predictions
elm_predictions = elm_classifier.predict(X_test_scaled)

# Exclude instances where the true class is -1 during evaluation
valid_test_indices = (y_test != -1)
y_test_valid = y_test[valid_test_indices]
elm_predictions_valid = elm_predictions[valid_test_indices]

# Evaluate ELMClassifier
elm_accuracy = accuracy_score(y_test_valid, elm_predictions_valid)
elm_report = classification_report(y_test_valid, elm_predictions_valid)

print("ELM Classifier (Manual Implementation):")
print(f"Accuracy: {elm_accuracy:.2f}")
print(f"Classification Report:\n{elm_report}\n{'='*40}")
# Out:
# ELM Classifier (Manual Implementation):
# Accuracy: 0.76
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.68      0.72        69
#            1       0.75      0.82      0.78        79
#
#     accuracy                           0.76       148
#    macro avg       0.76      0.75      0.75       148
# weighted avg       0.76      0.76      0.76       148
#
# ========================================
