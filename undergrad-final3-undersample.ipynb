# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Define the file path
file_path = "/kaggle/input/undergrad/Undergraduate.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Artificial Neural Network (ANN) Classifier
ann_classifier = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=42)
ann_classifier.fit(X_train_scaled, y_train)
ann_predictions = ann_classifier.predict(X_test_scaled)

# Machine Learning Classifiers
classifiers = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'SVM': SVC(random_state=42)
}

for name, classifier in classifiers.items():
    classifier.fit(X_train_scaled, y_train)
    predictions = classifier.predict(X_test_scaled)
    
    # Evaluate the classifier
    accuracy = accuracy_score(y_test, predictions)
    report = classification_report(y_test, predictions, target_names=le.classes_)  # Set target names using label encoder classes_
    
    print(f"Classifier: {name}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Classification Report:\n{report}\n{'='*40}")
# Out:
# Classifier: Random Forest
# Accuracy: 0.88
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.85      0.94      0.89        49
#  Public University       0.92      0.81      0.86        42
#
#           accuracy                           0.88        91
#          macro avg       0.89      0.87      0.88        91
#       weighted avg       0.88      0.88      0.88        91
#
# ========================================
# Classifier: SVM
# Accuracy: 0.75
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.73      0.76        49
#  Public University       0.71      0.76      0.74        42
#
#           accuracy                           0.75        91
#          macro avg       0.75      0.75      0.75        91
#       weighted avg       0.75      0.75      0.75        91
#
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Map numerical labels back to class names
class_names = le.classes_

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Hyperparameter tuning for RandomForestClassifier
param_grid_rf = {
    'randomforestclassifier__n_estimators': [50, 100, 200],
    'randomforestclassifier__max_depth': [None, 10, 20],
    'randomforestclassifier__min_samples_split': [2, 5, 10],
    'randomforestclassifier__min_samples_leaf': [1, 2, 4]
}

# Create a pipeline for preprocessing and RandomForestClassifier
pipeline_rf = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    RandomForestClassifier(random_state=42)
)

grid_search_rf = GridSearchCV(pipeline_rf, param_grid_rf, cv=5, scoring='accuracy')
grid_search_rf.fit(X_train, y_train)

# Get the best parameters
best_params_rf = grid_search_rf.best_params_
print(f"Best Parameters for RandomForestClassifier: {best_params_rf}")

# Evaluate the RandomForestClassifier with the best parameters
best_rf_classifier = grid_search_rf.best_estimator_
best_rf_predictions = best_rf_classifier.predict(X_test)
best_rf_accuracy = accuracy_score(y_test, best_rf_predictions)
best_rf_report = classification_report(y_test, best_rf_predictions, target_names=class_names)

print("Random Forest Classifier:")
print(f"Accuracy: {best_rf_accuracy:.2f}")
print(f"Classification Report:\n{best_rf_report}\n{'='*40}")
# Out:
# Best Parameters for RandomForestClassifier: {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__min_samples_leaf': 1, 'randomforestclassifier__min_samples_split': 2, 'randomforestclassifier__n_estimators': 100}
# Random Forest Classifier:
# Accuracy: 0.90
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.88      0.94      0.91        49
#  Public University       0.92      0.86      0.89        42
#
#           accuracy                           0.90        91
#          macro avg       0.90      0.90      0.90        91
#       weighted avg       0.90      0.90      0.90        91
#
# ========================================

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Print the total number of samples for each class
class_counts = balanced_df['Name of your current institution? '].value_counts()
print("Total number of samples after downsampling:")
for class_name, count in class_counts.items():
    print(f"{class_name}: {count}")
# Out:
# Total number of samples after downsampling:
# Public University: 226
# Private University: 226

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)


# Hyperparameter tuning for SVM
param_grid_svm = {
    'svc__C': [0.1, 1, 10],
    'svc__kernel': ['linear', 'rbf', 'poly'],
    'svc__gamma': ['scale', 'auto']
}

# Hyperparameter tuning for MLPClassifier
param_grid_mlp = {
    'mlpclassifier__hidden_layer_sizes': [(50,), (100, 50), (100, 50, 20)],
    'mlpclassifier__max_iter': [200, 500, 1000],
    'mlpclassifier__alpha': [0.0001, 0.001, 0.01]
}

# Hyperparameter tuning for DecisionTreeClassifier
param_grid_dt = {
    'decisiontreeclassifier__max_depth': [None, 5, 10, 20],
    'decisiontreeclassifier__min_samples_split': [2, 5, 10],
    'decisiontreeclassifier__min_samples_leaf': [1, 2, 4]
}

# Hyperparameter tuning for LogisticRegression
param_grid_lr = {
    'logisticregression__C': [0.1, 1, 10],
    'logisticregression__max_iter': [50, 100, 200]
}

# Hyperparameter tuning for GaussianNB (No hyperparameters to tune)

# Hyperparameter tuning for KNeighborsClassifier
param_grid_knn = {
    'kneighborsclassifier__n_neighbors': [3, 5, 7],
    'kneighborsclassifier__weights': ['uniform', 'distance']
}

# Hyperparameter tuning for AdaBoostClassifier
param_grid_adaboost = {
    'adaboostclassifier__n_estimators': [50, 100, 200],
    'adaboostclassifier__learning_rate': [0.1, 0.5, 1]
}

# Hyperparameter tuning for GradientBoostingClassifier
param_grid_gb = {
    'gradientboostingclassifier__n_estimators': [50, 100, 200],
    'gradientboostingclassifier__learning_rate': [0.01, 0.1, 0.5],
    'gradientboostingclassifier__max_depth': [3, 5, 10]
}

# Create pipelines for each classifier

pipeline_svm = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    SVC(random_state=42)
)

pipeline_mlp = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    MLPClassifier(random_state=42)
)

pipeline_dt = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    DecisionTreeClassifier(random_state=42)
)

pipeline_lr = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    LogisticRegression(random_state=42)
)

pipeline_nb = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    GaussianNB()
)

pipeline_knn = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    KNeighborsClassifier()
)

pipeline_adaboost = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    AdaBoostClassifier(random_state=42)
)

pipeline_gb = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    GradientBoostingClassifier(random_state=42)
)

# Create dictionaries for classifiers and their respective hyperparameter grids
classifiers = {
    'SVM': (pipeline_svm, param_grid_svm),
    'MLPClassifier': (pipeline_mlp, param_grid_mlp),
    'Decision Tree': (pipeline_dt, param_grid_dt),
    'Logistic Regression': (pipeline_lr, param_grid_lr),
    'Naive Bayes': (pipeline_nb, {}),
    'K-Nearest Neighbors': (pipeline_knn, param_grid_knn),
    'AdaBoost': (pipeline_adaboost, param_grid_adaboost),
    'Gradient Boosting': (pipeline_gb, param_grid_gb)
}

# Loop through classifiers
for name, (pipeline, param_grid) in classifiers.items():
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)

    # Get the best parameters
    best_params = grid_search.best_params_
    print(f"Best Parameters for {name}: {best_params}")

    # Evaluate the classifier with the best parameters
    best_classifier = grid_search.best_estimator_
    best_predictions = best_classifier.predict(X_test)
    best_accuracy = accuracy_score(y_test, best_predictions)
    # Convert numeric labels back to class names
    class_names = le.classes_
    y_test_names = le.inverse_transform(y_test)
    best_predictions_names = le.inverse_transform(best_predictions)

    best_report = classification_report(y_test_names, best_predictions_names, target_names=class_names)

    print(f"{name} Classifier:")
    print(f"Best Parameters: {best_params}")
    print(f"Accuracy: {best_accuracy:.2f}")
    print(f"Classification Report:\n{best_report}\n{'='*40}")
# Out:
# Best Parameters for SVM: {'svc__C': 1, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# SVM Classifier:
# Best Parameters: {'svc__C': 1, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# Accuracy: 0.81
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.86      0.78      0.82        49
#  Public University       0.77      0.86      0.81        42
#
#           accuracy                           0.81        91
#          macro avg       0.81      0.82      0.81        91
#       weighted avg       0.82      0.81      0.81        91
#
# ========================================
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters for MLPClassifier: {'mlpclassifier__alpha': 0.0001, 'mlpclassifier__hidden_layer_sizes': (50,), 'mlpclassifier__max_iter': 200}
# MLPClassifier Classifier:
# Best Parameters: {'mlpclassifier__alpha': 0.0001, 'mlpclassifier__hidden_layer_sizes': (50,), 'mlpclassifier__max_iter': 200}
# Accuracy: 0.80
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.86      0.82        49
#  Public University       0.82      0.74      0.78        42
#
#           accuracy                           0.80        91
#          macro avg       0.80      0.80      0.80        91
#       weighted avg       0.80      0.80      0.80        91
#
# ========================================
# Best Parameters for Decision Tree: {'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__min_samples_leaf': 4, 'decisiontreeclassifier__min_samples_split': 10}
# Decision Tree Classifier:
# Best Parameters: {'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__min_samples_leaf': 4, 'decisiontreeclassifier__min_samples_split': 10}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.85      0.82      0.83        49
#  Public University       0.80      0.83      0.81        42
#
#           accuracy                           0.82        91
#          macro avg       0.82      0.82      0.82        91
#       weighted avg       0.83      0.82      0.82        91
#
# ========================================
# Best Parameters for Logistic Regression: {'logisticregression__C': 1, 'logisticregression__max_iter': 50}
# Logistic Regression Classifier:
# Best Parameters: {'logisticregression__C': 1, 'logisticregression__max_iter': 50}
# Accuracy: 0.75
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.76      0.78      0.77        49
#  Public University       0.73      0.71      0.72        42
#
#           accuracy                           0.75        91
#          macro avg       0.75      0.74      0.75        91
#       weighted avg       0.75      0.75      0.75        91
#
# ========================================
# Best Parameters for Naive Bayes: {}
# Naive Bayes Classifier:
# Best Parameters: {}
# Accuracy: 0.76
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.73      0.77        49
#  Public University       0.72      0.79      0.75        42
#
#           accuracy                           0.76        91
#          macro avg       0.76      0.76      0.76        91
#       weighted avg       0.76      0.76      0.76        91
#
# ========================================
# Best Parameters for K-Nearest Neighbors: {'kneighborsclassifier__n_neighbors': 3, 'kneighborsclassifier__weights': 'distance'}
# K-Nearest Neighbors Classifier:
# Best Parameters: {'kneighborsclassifier__n_neighbors': 3, 'kneighborsclassifier__weights': 'distance'}
# Accuracy: 0.77
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.80      0.79        49
#  Public University       0.76      0.74      0.75        42
#
#           accuracy                           0.77        91
#          macro avg       0.77      0.77      0.77        91
#       weighted avg       0.77      0.77      0.77        91
#
# ========================================
# Best Parameters for AdaBoost: {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# AdaBoost Classifier:
# Best Parameters: {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# Accuracy: 0.84
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.87      0.82      0.84        49
#  Public University       0.80      0.86      0.83        42
#
#           accuracy                           0.84        91
#          macro avg       0.83      0.84      0.83        91
#       weighted avg       0.84      0.84      0.84        91
#
# ========================================
# Best Parameters for Gradient Boosting: {'gradientboostingclassifier__learning_rate': 0.1, 'gradientboostingclassifier__max_depth': 5, 'gradientboostingclassifier__n_estimators': 50}
# Gradient Boosting Classifier:
# Best Parameters: {'gradientboostingclassifier__learning_rate': 0.1, 'gradientboostingclassifier__max_depth': 5, 'gradientboostingclassifier__n_estimators': 50}
# Accuracy: 0.87
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.85      0.92      0.88        49
#  Public University       0.89      0.81      0.85        42
#
#           accuracy                           0.87        91
#          macro avg       0.87      0.86      0.87        91
#       weighted avg       0.87      0.87      0.87        91
#
# ========================================

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier

# ... (previous code remains unchanged)

# Hyperparameter tuning for XGBClassifier
param_grid_xgb = {
    'xgbclassifier__n_estimators': [50, 100, 200],
    'xgbclassifier__learning_rate': [0.01, 0.1, 0.5],
    'xgbclassifier__max_depth': [3, 5, 10]
}

# Hyperparameter tuning for LGBMClassifier
param_grid_lgbm = {
    'lgbmclassifier__n_estimators': [50, 100, 200],
    'lgbmclassifier__learning_rate': [0.01, 0.1, 0.5],
    'lgbmclassifier__max_depth': [3, 5, 10]
}

# Hyperparameter tuning for CatBoostClassifier
param_grid_catboost = {
    'catboostclassifier__n_estimators': [50, 100, 200],
    'catboostclassifier__learning_rate': [0.01, 0.1, 0.5],
    'catboostclassifier__max_depth': [3, 5, 10]
}

# Hyperparameter tuning for ExtraTreesClassifier
param_grid_extra_trees = {
    'extratreesclassifier__n_estimators': [50, 100, 200],
    'extratreesclassifier__max_depth': [None, 5, 10, 20],
    'extratreesclassifier__min_samples_split': [2, 5, 10],
    'extratreesclassifier__min_samples_leaf': [1, 2, 4]
}

# Hyperparameter tuning for BaggingClassifier
param_grid_bagging = {
    'baggingclassifier__n_estimators': [50, 100, 200],
    'baggingclassifier__max_samples': [0.5, 0.7, 1.0],
    'baggingclassifier__max_features': [0.5, 0.7, 1.0]
}

# Create pipelines for each classifier

pipeline_xgb = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    XGBClassifier(random_state=42)
)

pipeline_lgbm = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    LGBMClassifier(random_state=42)
)

pipeline_catboost = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    CatBoostClassifier(random_state=42)
)

pipeline_extra_trees = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    ExtraTreesClassifier(random_state=42)
)

pipeline_bagging = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    BaggingClassifier(random_state=42)
)

# Create dictionaries for additional classifiers and their respective hyperparameter grids
additional_classifiers = {
    'XGBClassifier': (pipeline_xgb, param_grid_xgb),
    'LGBMClassifier': (pipeline_lgbm, param_grid_lgbm),
    'CatBoostClassifier': (pipeline_catboost, param_grid_catboost),
    'ExtraTreesClassifier': (pipeline_extra_trees, param_grid_extra_trees),
    'BaggingClassifier': (pipeline_bagging, param_grid_bagging)
}

# Combine the classifiers
all_classifiers = {**classifiers, **additional_classifiers}

# Loop through all classifiers
for name, (pipeline, param_grid) in all_classifiers.items():
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)

    # Get the best parameters
    best_params = grid_search.best_params_
    print(f"Best Parameters for {name}: {best_params}")

    # Evaluate the classifier with the best parameters
    best_classifier = grid_search.best_estimator_
    best_predictions = best_classifier.predict(X_test)
    best_accuracy = accuracy_score(y_test, best_predictions)
    # Convert numeric labels back to class names
    class_names = le.classes_
    y_test_names = le.inverse_transform(y_test)
    best_predictions_names = le.inverse_transform(best_predictions)

    best_report = classification_report(y_test_names, best_predictions_names, target_names=class_names)

    print(f"{name} Classifier:")
    print(f"Best Parameters: {best_params}")
    print(f"Accuracy: {best_accuracy:.2f}")
    print(f"Classification Report:\n{best_report}\n{'='*40}")
# Out:
# Best Parameters for SVM: {'svc__C': 1, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# SVM Classifier:
# Best Parameters: {'svc__C': 1, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# Accuracy: 0.81
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.86      0.78      0.82        49
#  Public University       0.77      0.86      0.81        42
#
#           accuracy                           0.81        91
#          macro avg       0.81      0.82      0.81        91
#       weighted avg       0.82      0.81      0.81        91
#
# ========================================
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters for MLPClassifier: {'mlpclassifier__alpha': 0.0001, 'mlpclassifier__hidden_layer_sizes': (50,), 'mlpclassifier__max_iter': 200}
# MLPClassifier Classifier:
# Best Parameters: {'mlpclassifier__alpha': 0.0001, 'mlpclassifier__hidden_layer_sizes': (50,), 'mlpclassifier__max_iter': 200}
# Accuracy: 0.80
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.86      0.82        49
#  Public University       0.82      0.74      0.78        42
#
#           accuracy                           0.80        91
#          macro avg       0.80      0.80      0.80        91
#       weighted avg       0.80      0.80      0.80        91
#
# ========================================
# Best Parameters for Decision Tree: {'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__min_samples_leaf': 4, 'decisiontreeclassifier__min_samples_split': 10}
# Decision Tree Classifier:
# Best Parameters: {'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__min_samples_leaf': 4, 'decisiontreeclassifier__min_samples_split': 10}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.85      0.82      0.83        49
#  Public University       0.80      0.83      0.81        42
#
#           accuracy                           0.82        91
#          macro avg       0.82      0.82      0.82        91
#       weighted avg       0.83      0.82      0.82        91
#
# ========================================
# Best Parameters for Logistic Regression: {'logisticregression__C': 1, 'logisticregression__max_iter': 50}
# Logistic Regression Classifier:
# Best Parameters: {'logisticregression__C': 1, 'logisticregression__max_iter': 50}
# Accuracy: 0.75
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.76      0.78      0.77        49
#  Public University       0.73      0.71      0.72        42
#
#           accuracy                           0.75        91
#          macro avg       0.75      0.74      0.75        91
#       weighted avg       0.75      0.75      0.75        91
#
# ========================================
# Best Parameters for Naive Bayes: {}
# Naive Bayes Classifier:
# Best Parameters: {}
# Accuracy: 0.76
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.80      0.73      0.77        49
#  Public University       0.72      0.79      0.75        42
#
#           accuracy                           0.76        91
#          macro avg       0.76      0.76      0.76        91
#       weighted avg       0.76      0.76      0.76        91
#
# ========================================
# Best Parameters for K-Nearest Neighbors: {'kneighborsclassifier__n_neighbors': 3, 'kneighborsclassifier__weights': 'distance'}
# K-Nearest Neighbors Classifier:
# Best Parameters: {'kneighborsclassifier__n_neighbors': 3, 'kneighborsclassifier__weights': 'distance'}
# Accuracy: 0.77
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.80      0.79        49
#  Public University       0.76      0.74      0.75        42
#
#           accuracy                           0.77        91
#          macro avg       0.77      0.77      0.77        91
#       weighted avg       0.77      0.77      0.77        91
#
# ========================================
# Best Parameters for AdaBoost: {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# AdaBoost Classifier:
# Best Parameters: {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 200}
# Accuracy: 0.84
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.87      0.82      0.84        49
#  Public University       0.80      0.86      0.83        42
#
#           accuracy                           0.84        91
#          macro avg       0.83      0.84      0.83        91
#       weighted avg       0.84      0.84      0.84        91
#
# ========================================
# Best Parameters for Gradient Boosting: {'gradientboostingclassifier__learning_rate': 0.1, 'gradientboostingclassifier__max_depth': 5, 'gradientboostingclassifier__n_estimators': 50}
# Gradient Boosting Classifier:
# Best Parameters: {'gradientboostingclassifier__learning_rate': 0.1, 'gradientboostingclassifier__max_depth': 5, 'gradientboostingclassifier__n_estimators': 50}
# Accuracy: 0.87
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.85      0.92      0.88        49
#  Public University       0.89      0.81      0.85        42
#
#           accuracy                           0.87        91
#          macro avg       0.87      0.86      0.87        91
#       weighted avg       0.87      0.87      0.87        91
#
# ========================================
# Best Parameters for XGBClassifier: {'xgbclassifier__learning_rate': 0.5, 'xgbclassifier__max_depth': 10, 'xgbclassifier__n_estimators': 50}
# XGBClassifier Classifier:
# Best Parameters: {'xgbclassifier__learning_rate': 0.5, 'xgbclassifier__max_depth': 10, 'xgbclassifier__n_estimators': 50}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.79      0.92      0.85        49
#  Public University       0.88      0.71      0.79        42
#
#           accuracy                           0.82        91
#          macro avg       0.84      0.82      0.82        91
#       weighted avg       0.83      0.82      0.82        91
#
# ========================================
# Best Parameters for LGBMClassifier: {'lgbmclassifier__learning_rate': 0.1, 'lgbmclassifier__max_depth': 5, 'lgbmclassifier__n_estimators': 100}
# LGBMClassifier Classifier:
# Best Parameters: {'lgbmclassifier__learning_rate': 0.1, 'lgbmclassifier__max_depth': 5, 'lgbmclassifier__n_estimators': 100}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.82      0.86      0.84        49
#  Public University       0.82      0.79      0.80        42
#
#           accuracy                           0.82        91
#          macro avg       0.82      0.82      0.82        91
#       weighted avg       0.82      0.82      0.82        91
#
# ========================================
# 0:	learn: 0.6880639	total: 52.7ms	remaining: 2.58s
# 1:	learn: 0.6832459	total: 53.4ms	remaining: 1.28s
# 2:	learn: 0.6777267	total: 54.1ms	remaining: 847ms
# 3:	learn: 0.6722945	total: 54.7ms	remaining: 629ms
# 4:	learn: 0.6673852	total: 55.3ms	remaining: 498ms
# 5:	learn: 0.6620104	total: 55.9ms	remaining: 410ms
# 6:	learn: 0.6563270	total: 56.7ms	remaining: 349ms
# 7:	learn: 0.6513081	total: 57.4ms	remaining: 301ms
# 8:	learn: 0.6462145	total: 58.1ms	remaining: 265ms
# 9:	learn: 0.6422124	total: 58.7ms	remaining: 235ms
# 10:	learn: 0.6380711	total: 59.3ms	remaining: 210ms
# 11:	learn: 0.6332610	total: 60.1ms	remaining: 190ms
# 12:	learn: 0.6285586	total: 60.8ms	remaining: 173ms
# 13:	learn: 0.6233198	total: 61.6ms	remaining: 158ms
# 14:	learn: 0.6187026	total: 62.3ms	remaining: 145ms
# 15:	learn: 0.6143152	total: 63.1ms	remaining: 134ms
# 16:	learn: 0.6103755	total: 63.8ms	remaining: 124ms
# 17:	learn: 0.6063166	total: 64.5ms	remaining: 115ms
# 18:	learn: 0.6023466	total: 65.2ms	remaining: 106ms
# 19:	learn: 0.5986599	total: 65.9ms	remaining: 98.8ms
# 20:	learn: 0.5945226	total: 66.5ms	remaining: 91.8ms
# 21:	learn: 0.5908145	total: 67.1ms	remaining: 85.4ms
# 22:	learn: 0.5878180	total: 67.7ms	remaining: 79.5ms
# 23:	learn: 0.5850692	total: 68.3ms	remaining: 74ms
# 24:	learn: 0.5812485	total: 69ms	remaining: 69ms
# 25:	learn: 0.5775044	total: 69.6ms	remaining: 64.2ms
# 26:	learn: 0.5745551	total: 70.2ms	remaining: 59.8ms
# 27:	learn: 0.5714704	total: 70.8ms	remaining: 55.6ms
# 28:	learn: 0.5680138	total: 71.4ms	remaining: 51.7ms
# 29:	learn: 0.5649558	total: 72ms	remaining: 48ms
# 30:	learn: 0.5623144	total: 72.6ms	remaining: 44.5ms
# 31:	learn: 0.5588171	total: 73.2ms	remaining: 41.2ms
# 32:	learn: 0.5551625	total: 73.8ms	remaining: 38ms
# 33:	learn: 0.5526180	total: 74.4ms	remaining: 35ms
# 34:	learn: 0.5493661	total: 75ms	remaining: 32.1ms
# 35:	learn: 0.5463243	total: 75.5ms	remaining: 29.4ms
# 36:	learn: 0.5429097	total: 76.1ms	remaining: 26.8ms
# 37:	learn: 0.5406828	total: 76.7ms	remaining: 24.2ms
# 38:	learn: 0.5381233	total: 77.3ms	remaining: 21.8ms
# 39:	learn: 0.5353443	total: 77.9ms	remaining: 19.5ms
# 40:	learn: 0.5334193	total: 78.5ms	remaining: 17.2ms
# 41:	learn: 0.5307116	total: 79.2ms	remaining: 15.1ms
# 42:	learn: 0.5285945	total: 79.8ms	remaining: 13ms
# 43:	learn: 0.5257771	total: 80.4ms	remaining: 11ms
# 44:	learn: 0.5229591	total: 81ms	remaining: 9ms
# 45:	learn: 0.5210685	total: 81.6ms	remaining: 7.09ms
# 46:	learn: 0.5185201	total: 82.2ms	remaining: 5.25ms
# 47:	learn: 0.5163207	total: 82.8ms	remaining: 3.45ms
# 48:	learn: 0.5141514	total: 83.4ms	remaining: 1.7ms
# 49:	learn: 0.5121481	total: 84ms	remaining: 0us
# 0:	learn: 0.6877448	total: 809us	remaining: 39.7ms
# 1:	learn: 0.6829840	total: 1.36ms	remaining: 32.8ms
# 2:	learn: 0.6777357	total: 1.88ms	remaining: 29.4ms
# 3:	learn: 0.6729931	total: 3.12ms	remaining: 35.9ms
# 4:	learn: 0.6676468	total: 3.66ms	remaining: 33ms
# 5:	learn: 0.6635566	total: 4.15ms	remaining: 30.4ms
# 6:	learn: 0.6596277	total: 4.68ms	remaining: 28.8ms
# 7:	learn: 0.6557816	total: 5.06ms	remaining: 26.6ms
# 8:	learn: 0.6520983	total: 5.82ms	remaining: 26.5ms
# 9:	learn: 0.6483114	total: 6.42ms	remaining: 25.7ms
# 10:	learn: 0.6440889	total: 6.98ms	remaining: 24.7ms
# 11:	learn: 0.6405571	total: 7.64ms	remaining: 24.2ms
# 12:	learn: 0.6364753	total: 8.26ms	remaining: 23.5ms
# 13:	learn: 0.6326395	total: 8.84ms	remaining: 22.7ms
# 14:	learn: 0.6284163	total: 9.39ms	remaining: 21.9ms
# 15:	learn: 0.6239878	total: 10ms	remaining: 21.3ms
# 16:	learn: 0.6203321	total: 10.6ms	remaining: 20.5ms
# 17:	learn: 0.6172297	total: 11.1ms	remaining: 19.8ms
# 18:	learn: 0.6135809	total: 11.8ms	remaining: 19.2ms
# 19:	learn: 0.6098729	total: 12.3ms	remaining: 18.5ms
# 20:	learn: 0.6062358	total: 12.9ms	remaining: 17.8ms
# 21:	learn: 0.6025969	total: 13.5ms	remaining: 17.2ms
# 22:	learn: 0.5988494	total: 14.1ms	remaining: 16.5ms
# 23:	learn: 0.5959713	total: 15.2ms	remaining: 16.5ms
# 24:	learn: 0.5925535	total: 16.7ms	remaining: 16.7ms
# 25:	learn: 0.5897408	total: 17.2ms	remaining: 15.9ms
# 26:	learn: 0.5869943	total: 17.8ms	remaining: 15.2ms
# 27:	learn: 0.5830996	total: 18.4ms	remaining: 14.4ms
# 28:	learn: 0.5802578	total: 18.9ms	remaining: 13.7ms
# 29:	learn: 0.5774313	total: 19.5ms	remaining: 13ms
# 30:	learn: 0.5750550	total: 20ms	remaining: 12.3ms
# 31:	learn: 0.5719800	total: 20.6ms	remaining: 11.6ms
# 32:	learn: 0.5695967	total: 21ms	remaining: 10.8ms
# 33:	learn: 0.5662682	total: 21.6ms	remaining: 10.2ms
# 34:	learn: 0.5631656	total: 22.1ms	remaining: 9.48ms
# 35:	learn: 0.5606814	total: 22.7ms	remaining: 8.81ms
# 36:	learn: 0.5577683	total: 23.2ms	remaining: 8.16ms
# 37:	learn: 0.5558685	total: 23.7ms	remaining: 7.5ms
# 38:	learn: 0.5528332	total: 24.3ms	remaining: 6.86ms
# 39:	learn: 0.5501416	total: 25ms	remaining: 6.26ms
# 40:	learn: 0.5476413	total: 25.7ms	remaining: 5.64ms
# 41:	learn: 0.5461013	total: 26.3ms	remaining: 5ms
# 42:	learn: 0.5440905	total: 27ms	remaining: 4.4ms
# 43:	learn: 0.5414508	total: 27.6ms	remaining: 3.77ms
# 44:	learn: 0.5395015	total: 28.1ms	remaining: 3.13ms
# 45:	learn: 0.5369063	total: 28.7ms	remaining: 2.49ms
# 46:	learn: 0.5345618	total: 29.2ms	remaining: 1.86ms
# 47:	learn: 0.5323764	total: 29.8ms	remaining: 1.24ms
# 48:	learn: 0.5304551	total: 30.3ms	remaining: 618us
# 49:	learn: 0.5284334	total: 31ms	remaining: 0us
# 0:	learn: 0.6871485	total: 579us	remaining: 28.4ms
# 1:	learn: 0.6818738	total: 1.14ms	remaining: 27.4ms
# 2:	learn: 0.6757356	total: 1.69ms	remaining: 26.6ms
# 3:	learn: 0.6699559	total: 2.25ms	remaining: 25.8ms
# 4:	learn: 0.6643742	total: 2.8ms	remaining: 25.2ms
# 5:	learn: 0.6582337	total: 3.4ms	remaining: 25ms
# 6:	learn: 0.6532148	total: 4.03ms	remaining: 24.8ms
# 7:	learn: 0.6474785	total: 4.6ms	remaining: 24.2ms
# 8:	learn: 0.6421873	total: 5.15ms	remaining: 23.5ms
# 9:	learn: 0.6366277	total: 5.71ms	remaining: 22.8ms
# 10:	learn: 0.6317549	total: 6.26ms	remaining: 22.2ms
# 11:	learn: 0.6272831	total: 6.77ms	remaining: 21.5ms
# 12:	learn: 0.6219195	total: 7.28ms	remaining: 20.7ms
# 13:	learn: 0.6175156	total: 7.92ms	remaining: 20.4ms
# 14:	learn: 0.6115475	total: 8.28ms	remaining: 19.3ms
# 15:	learn: 0.6065788	total: 8.84ms	remaining: 18.8ms
# 16:	learn: 0.6020709	total: 9.36ms	remaining: 18.2ms
# 17:	learn: 0.5972846	total: 9.89ms	remaining: 17.6ms
# 18:	learn: 0.5934413	total: 10.4ms	remaining: 17ms
# 19:	learn: 0.5896949	total: 11ms	remaining: 16.4ms
# 20:	learn: 0.5857131	total: 11.6ms	remaining: 16ms
# 21:	learn: 0.5815711	total: 12.1ms	remaining: 15.4ms
# 22:	learn: 0.5775481	total: 12.7ms	remaining: 14.9ms
# 23:	learn: 0.5741848	total: 13.2ms	remaining: 14.3ms
# 24:	learn: 0.5701816	total: 13.8ms	remaining: 13.8ms
# 25:	learn: 0.5665628	total: 14.3ms	remaining: 13.2ms
# 26:	learn: 0.5633633	total: 14.9ms	remaining: 12.7ms
# 27:	learn: 0.5594360	total: 15.4ms	remaining: 12.1ms
# 28:	learn: 0.5561850	total: 15.9ms	remaining: 11.5ms
# 29:	learn: 0.5529079	total: 16.5ms	remaining: 11ms
# 30:	learn: 0.5490767	total: 17ms	remaining: 10.4ms
# 31:	learn: 0.5451989	total: 17.6ms	remaining: 9.88ms
# 32:	learn: 0.5424823	total: 18.1ms	remaining: 9.32ms
# 33:	learn: 0.5396722	total: 18.6ms	remaining: 8.78ms
# 34:	learn: 0.5360615	total: 19.2ms	remaining: 8.21ms
# 35:	learn: 0.5330916	total: 19.7ms	remaining: 7.65ms
# 36:	learn: 0.5297697	total: 20.2ms	remaining: 7.1ms
# 37:	learn: 0.5265222	total: 20.7ms	remaining: 6.53ms
# 38:	learn: 0.5239422	total: 21.3ms	remaining: 6ms
# 39:	learn: 0.5211957	total: 21.8ms	remaining: 5.45ms
# 40:	learn: 0.5190173	total: 22.3ms	remaining: 4.9ms
# 41:	learn: 0.5155614	total: 22.9ms	remaining: 4.36ms
# 42:	learn: 0.5135810	total: 23.4ms	remaining: 3.81ms
# 43:	learn: 0.5105858	total: 23.9ms	remaining: 3.26ms
# 44:	learn: 0.5073207	total: 24.5ms	remaining: 2.72ms
# 45:	learn: 0.5048986	total: 25ms	remaining: 2.17ms
# 46:	learn: 0.5028465	total: 25.5ms	remaining: 1.63ms
# 47:	learn: 0.5008334	total: 26.1ms	remaining: 1.08ms
# 48:	learn: 0.4984138	total: 26.6ms	remaining: 542us
# 49:	learn: 0.4958858	total: 27.1ms	remaining: 0us
# 0:	learn: 0.6881123	total: 587us	remaining: 28.8ms
# 1:	learn: 0.6815996	total: 1.16ms	remaining: 27.8ms
# 2:	learn: 0.6745041	total: 1.71ms	remaining: 26.8ms
# 3:	learn: 0.6686475	total: 2.22ms	remaining: 25.6ms
# 4:	learn: 0.6637037	total: 2.78ms	remaining: 25ms
# 5:	learn: 0.6583836	total: 3.33ms	remaining: 24.4ms
# 6:	learn: 0.6541100	total: 3.86ms	remaining: 23.7ms
# 7:	learn: 0.6485101	total: 4.37ms	remaining: 22.9ms
# 8:	learn: 0.6445168	total: 4.89ms	remaining: 22.3ms
# 9:	learn: 0.6391996	total: 5.42ms	remaining: 21.7ms
# 10:	learn: 0.6344652	total: 5.97ms	remaining: 21.2ms
# 11:	learn: 0.6284412	total: 6.49ms	remaining: 20.5ms
# 12:	learn: 0.6233390	total: 7ms	remaining: 19.9ms
# 13:	learn: 0.6185608	total: 7.53ms	remaining: 19.4ms
# 14:	learn: 0.6133585	total: 8.05ms	remaining: 18.8ms
# 15:	learn: 0.6092988	total: 8.57ms	remaining: 18.2ms
# 16:	learn: 0.6044668	total: 9.09ms	remaining: 17.6ms
# 17:	learn: 0.6006236	total: 9.59ms	remaining: 17.1ms
# 18:	learn: 0.5965840	total: 10.1ms	remaining: 16.5ms
# 19:	learn: 0.5926988	total: 10.6ms	remaining: 16ms
# 20:	learn: 0.5892121	total: 11.2ms	remaining: 15.4ms
# 21:	learn: 0.5849392	total: 11.7ms	remaining: 14.9ms
# 22:	learn: 0.5810169	total: 12.3ms	remaining: 14.4ms
# 23:	learn: 0.5771158	total: 12.9ms	remaining: 14ms
# 24:	learn: 0.5734735	total: 13.4ms	remaining: 13.4ms
# 25:	learn: 0.5699593	total: 14ms	remaining: 12.9ms
# 26:	learn: 0.5661707	total: 14.6ms	remaining: 12.4ms
# 27:	learn: 0.5622051	total: 15.1ms	remaining: 11.9ms
# 28:	learn: 0.5591553	total: 15.6ms	remaining: 11.3ms
# 29:	learn: 0.5560566	total: 16.1ms	remaining: 10.8ms
# 30:	learn: 0.5534564	total: 16.6ms	remaining: 10.2ms
# 31:	learn: 0.5494603	total: 17.2ms	remaining: 9.65ms
# 32:	learn: 0.5462600	total: 17.7ms	remaining: 9.11ms
# 33:	learn: 0.5436456	total: 18.2ms	remaining: 8.57ms
# 34:	learn: 0.5396448	total: 18.7ms	remaining: 8.03ms
# 35:	learn: 0.5363537	total: 19.3ms	remaining: 7.49ms
# 36:	learn: 0.5333223	total: 19.8ms	remaining: 6.96ms
# 37:	learn: 0.5307178	total: 20.3ms	remaining: 6.42ms
# 38:	learn: 0.5279802	total: 20.9ms	remaining: 5.89ms
# 39:	learn: 0.5251969	total: 21.4ms	remaining: 5.35ms
# 40:	learn: 0.5229457	total: 21.9ms	remaining: 4.81ms
# 41:	learn: 0.5203080	total: 22.4ms	remaining: 4.27ms
# 42:	learn: 0.5171392	total: 23ms	remaining: 3.74ms
# 43:	learn: 0.5145068	total: 23.6ms	remaining: 3.21ms
# 44:	learn: 0.5116546	total: 24ms	remaining: 2.67ms
# 45:	learn: 0.5097733	total: 24.5ms	remaining: 2.13ms
# 46:	learn: 0.5071042	total: 25.1ms	remaining: 1.6ms
# 47:	learn: 0.5049477	total: 25.7ms	remaining: 1.07ms
# 48:	learn: 0.5025073	total: 26.3ms	remaining: 536us
# 49:	learn: 0.5000448	total: 26.9ms	remaining: 0us
# 0:	learn: 0.6867659	total: 568us	remaining: 27.9ms
# 1:	learn: 0.6812416	total: 1.16ms	remaining: 27.7ms
# 2:	learn: 0.6748762	total: 1.76ms	remaining: 27.6ms
# 3:	learn: 0.6690170	total: 2.33ms	remaining: 26.7ms
# 4:	learn: 0.6634372	total: 2.83ms	remaining: 25.4ms
# 5:	learn: 0.6570913	total: 3.37ms	remaining: 24.7ms
# 6:	learn: 0.6501653	total: 3.92ms	remaining: 24.1ms
# 7:	learn: 0.6448530	total: 4.46ms	remaining: 23.4ms
# 8:	learn: 0.6400604	total: 5.06ms	remaining: 23.1ms
# 9:	learn: 0.6352725	total: 5.64ms	remaining: 22.6ms
# 10:	learn: 0.6303861	total: 6.18ms	remaining: 21.9ms
# 11:	learn: 0.6260256	total: 6.72ms	remaining: 21.3ms
# 12:	learn: 0.6210372	total: 7.33ms	remaining: 20.9ms
# 13:	learn: 0.6163241	total: 7.87ms	remaining: 20.2ms
# 14:	learn: 0.6114158	total: 8.42ms	remaining: 19.6ms
# 15:	learn: 0.6071027	total: 8.95ms	remaining: 19ms
# 16:	learn: 0.6025042	total: 9.46ms	remaining: 18.4ms
# 17:	learn: 0.5977640	total: 10ms	remaining: 17.8ms
# 18:	learn: 0.5934146	total: 10.6ms	remaining: 17.3ms
# 19:	learn: 0.5891792	total: 11.2ms	remaining: 16.8ms
# 20:	learn: 0.5845628	total: 11.8ms	remaining: 16.2ms
# 21:	learn: 0.5806503	total: 12.3ms	remaining: 15.7ms
# 22:	learn: 0.5762165	total: 12.8ms	remaining: 15.1ms
# 23:	learn: 0.5727249	total: 13.4ms	remaining: 14.6ms
# 24:	learn: 0.5688176	total: 14ms	remaining: 14ms
# 25:	learn: 0.5650943	total: 14.6ms	remaining: 13.5ms
# 26:	learn: 0.5620387	total: 15.1ms	remaining: 12.9ms
# 27:	learn: 0.5578243	total: 15.7ms	remaining: 12.3ms
# 28:	learn: 0.5544292	total: 16.2ms	remaining: 11.7ms
# 29:	learn: 0.5505416	total: 17.2ms	remaining: 11.5ms
# 30:	learn: 0.5478211	total: 17.8ms	remaining: 10.9ms
# 31:	learn: 0.5432734	total: 18.4ms	remaining: 10.3ms
# 32:	learn: 0.5404459	total: 18.9ms	remaining: 9.74ms
# 33:	learn: 0.5374868	total: 19.5ms	remaining: 9.17ms
# 34:	learn: 0.5337851	total: 20ms	remaining: 8.59ms
# 35:	learn: 0.5307010	total: 20.5ms	remaining: 7.99ms
# 36:	learn: 0.5273473	total: 21.1ms	remaining: 7.41ms
# 37:	learn: 0.5244708	total: 21.6ms	remaining: 6.83ms
# 38:	learn: 0.5218611	total: 22.2ms	remaining: 6.25ms
# 39:	learn: 0.5195757	total: 22.7ms	remaining: 5.68ms
# 40:	learn: 0.5172084	total: 23.2ms	remaining: 5.1ms
# 41:	learn: 0.5140023	total: 23.8ms	remaining: 4.52ms
# 42:	learn: 0.5118870	total: 24.3ms	remaining: 3.95ms
# 43:	learn: 0.5090716	total: 24.8ms	remaining: 3.39ms
# 44:	learn: 0.5058892	total: 25.4ms	remaining: 2.82ms
# 45:	learn: 0.5036111	total: 25.9ms	remaining: 2.25ms
# 46:	learn: 0.5012811	total: 26.5ms	remaining: 1.69ms
# 47:	learn: 0.4987978	total: 27.1ms	remaining: 1.13ms
# 48:	learn: 0.4965614	total: 27.7ms	remaining: 564us
# 49:	learn: 0.4945668	total: 28.2ms	remaining: 0us
# 0:	learn: 0.6880639	total: 709us	remaining: 70.2ms
# 1:	learn: 0.6832459	total: 1.31ms	remaining: 64.4ms
# 2:	learn: 0.6777267	total: 1.96ms	remaining: 63.4ms
# 3:	learn: 0.6722945	total: 2.49ms	remaining: 59.7ms
# 4:	learn: 0.6673852	total: 3.06ms	remaining: 58.1ms
# 5:	learn: 0.6620104	total: 3.59ms	remaining: 56.3ms
# 6:	learn: 0.6563270	total: 4.15ms	remaining: 55.1ms
# 7:	learn: 0.6513081	total: 4.72ms	remaining: 54.3ms
# 8:	learn: 0.6462145	total: 5.26ms	remaining: 53.2ms
# 9:	learn: 0.6422124	total: 5.82ms	remaining: 52.4ms
# 10:	learn: 0.6380711	total: 6.36ms	remaining: 51.4ms
# 11:	learn: 0.6332610	total: 6.86ms	remaining: 50.3ms
# 12:	learn: 0.6285586	total: 7.41ms	remaining: 49.6ms
# 13:	learn: 0.6233198	total: 7.93ms	remaining: 48.7ms
# 14:	learn: 0.6187026	total: 8.46ms	remaining: 47.9ms
# 15:	learn: 0.6143152	total: 8.96ms	remaining: 47ms
# 16:	learn: 0.6103755	total: 9.48ms	remaining: 46.3ms
# 17:	learn: 0.6063166	total: 10.1ms	remaining: 45.8ms
# 18:	learn: 0.6023466	total: 10.6ms	remaining: 45.1ms
# 19:	learn: 0.5986599	total: 11.1ms	remaining: 44.3ms
# 20:	learn: 0.5945226	total: 11.6ms	remaining: 43.8ms
# 21:	learn: 0.5908145	total: 12.2ms	remaining: 43.2ms
# 22:	learn: 0.5878180	total: 12.8ms	remaining: 42.8ms
# 23:	learn: 0.5850692	total: 13.3ms	remaining: 42.2ms
# 24:	learn: 0.5812485	total: 13.9ms	remaining: 41.8ms
# 25:	learn: 0.5775044	total: 14.5ms	remaining: 41.3ms
# 26:	learn: 0.5745551	total: 15ms	remaining: 40.6ms
# 27:	learn: 0.5714704	total: 15.5ms	remaining: 40ms
# 28:	learn: 0.5680138	total: 16.1ms	remaining: 39.4ms
# 29:	learn: 0.5649558	total: 16.6ms	remaining: 38.8ms
# 30:	learn: 0.5623144	total: 17.2ms	remaining: 38.2ms
# 31:	learn: 0.5588171	total: 17.8ms	remaining: 37.7ms
# 32:	learn: 0.5551625	total: 18.3ms	remaining: 37.1ms
# 33:	learn: 0.5526180	total: 18.8ms	remaining: 36.6ms
# 34:	learn: 0.5493661	total: 19.4ms	remaining: 36ms
# 35:	learn: 0.5463243	total: 19.9ms	remaining: 35.4ms
# 36:	learn: 0.5429097	total: 20.4ms	remaining: 34.8ms
# 37:	learn: 0.5406828	total: 20.9ms	remaining: 34.2ms
# 38:	learn: 0.5381233	total: 21.5ms	remaining: 33.6ms
# 39:	learn: 0.5353443	total: 22ms	remaining: 33ms
# 40:	learn: 0.5334193	total: 22.6ms	remaining: 32.5ms
# 41:	learn: 0.5307116	total: 23.1ms	remaining: 31.9ms
# 42:	learn: 0.5285945	total: 23.7ms	remaining: 31.4ms
# 43:	learn: 0.5257771	total: 24.2ms	remaining: 30.8ms
# 44:	learn: 0.5229591	total: 24.7ms	remaining: 30.2ms
# 45:	learn: 0.5210685	total: 25.2ms	remaining: 29.6ms
# 46:	learn: 0.5185201	total: 25.8ms	remaining: 29.1ms
# 47:	learn: 0.5163207	total: 26.3ms	remaining: 28.5ms
# 48:	learn: 0.5141514	total: 26.8ms	remaining: 27.9ms
# 49:	learn: 0.5121481	total: 27.4ms	remaining: 27.4ms
# 50:	learn: 0.5098326	total: 27.9ms	remaining: 26.8ms
# 51:	learn: 0.5071608	total: 28.5ms	remaining: 26.3ms
# 52:	learn: 0.5047382	total: 29ms	remaining: 25.7ms
# 53:	learn: 0.5031952	total: 29.5ms	remaining: 25.1ms
# 54:	learn: 0.5014315	total: 30ms	remaining: 24.6ms
# 55:	learn: 0.4989742	total: 30.6ms	remaining: 24ms
# 56:	learn: 0.4970066	total: 31.2ms	remaining: 23.5ms
# 57:	learn: 0.4950591	total: 31.6ms	remaining: 22.9ms
# 58:	learn: 0.4932690	total: 32ms	remaining: 22.2ms
# 59:	learn: 0.4913897	total: 32.4ms	remaining: 21.6ms
# 60:	learn: 0.4894486	total: 32.8ms	remaining: 21ms
# 61:	learn: 0.4871330	total: 33.3ms	remaining: 20.4ms
# 62:	learn: 0.4852012	total: 33.9ms	remaining: 19.9ms
# 63:	learn: 0.4832144	total: 34.4ms	remaining: 19.4ms
# 64:	learn: 0.4816745	total: 35ms	remaining: 18.8ms
# 65:	learn: 0.4799423	total: 35.5ms	remaining: 18.3ms
# 66:	learn: 0.4780327	total: 36ms	remaining: 17.7ms
# 67:	learn: 0.4764782	total: 36.5ms	remaining: 17.2ms
# 68:	learn: 0.4746819	total: 37ms	remaining: 16.6ms
# 69:	learn: 0.4734089	total: 37.6ms	remaining: 16.1ms
# 70:	learn: 0.4718424	total: 38.1ms	remaining: 15.6ms
# 71:	learn: 0.4704968	total: 38.6ms	remaining: 15ms
# 72:	learn: 0.4686037	total: 39.2ms	remaining: 14.5ms
# 73:	learn: 0.4668421	total: 39.7ms	remaining: 14ms
# 74:	learn: 0.4653167	total: 40.3ms	remaining: 13.4ms
# 75:	learn: 0.4636931	total: 40.8ms	remaining: 12.9ms
# 76:	learn: 0.4625125	total: 41.4ms	remaining: 12.4ms
# 77:	learn: 0.4610135	total: 41.9ms	remaining: 11.8ms
# 78:	learn: 0.4597911	total: 42.5ms	remaining: 11.3ms
# 79:	learn: 0.4584727	total: 43ms	remaining: 10.8ms
# 80:	learn: 0.4573119	total: 43.6ms	remaining: 10.2ms
# 81:	learn: 0.4558809	total: 44.1ms	remaining: 9.68ms
# 82:	learn: 0.4547604	total: 44.6ms	remaining: 9.13ms
# 83:	learn: 0.4534123	total: 45.1ms	remaining: 8.59ms
# 84:	learn: 0.4523719	total: 45.6ms	remaining: 8.05ms
# 85:	learn: 0.4510502	total: 46.2ms	remaining: 7.52ms
# 86:	learn: 0.4497022	total: 46.8ms	remaining: 6.99ms
# 87:	learn: 0.4482517	total: 47.4ms	remaining: 6.46ms
# 88:	learn: 0.4473440	total: 47.9ms	remaining: 5.92ms
# 89:	learn: 0.4462814	total: 48.4ms	remaining: 5.38ms
# 90:	learn: 0.4446892	total: 49ms	remaining: 4.84ms
# 91:	learn: 0.4434969	total: 49.5ms	remaining: 4.31ms
# 92:	learn: 0.4423594	total: 50.1ms	remaining: 3.77ms
# 93:	learn: 0.4412291	total: 50.6ms	remaining: 3.23ms
# 94:	learn: 0.4405569	total: 51.1ms	remaining: 2.69ms
# 95:	learn: 0.4396035	total: 51.6ms	remaining: 2.15ms
# 96:	learn: 0.4392921	total: 52.2ms	remaining: 1.61ms
# 97:	learn: 0.4387857	total: 52.7ms	remaining: 1.07ms
# 98:	learn: 0.4375077	total: 53.2ms	remaining: 537us
# 99:	learn: 0.4364982	total: 53.8ms	remaining: 0us
# 0:	learn: 0.6877448	total: 575us	remaining: 57ms
# 1:	learn: 0.6829840	total: 1.12ms	remaining: 54.8ms
# 2:	learn: 0.6777357	total: 1.69ms	remaining: 54.5ms
# 3:	learn: 0.6729931	total: 2.23ms	remaining: 53.6ms
# 4:	learn: 0.6676468	total: 2.81ms	remaining: 53.4ms
# 5:	learn: 0.6635566	total: 3.36ms	remaining: 52.6ms
# 6:	learn: 0.6596277	total: 3.93ms	remaining: 52.2ms
# 7:	learn: 0.6557816	total: 4.53ms	remaining: 52.1ms
# 8:	learn: 0.6520983	total: 5.05ms	remaining: 51ms
# 9:	learn: 0.6483114	total: 5.59ms	remaining: 50.3ms
# 10:	learn: 0.6440889	total: 6.14ms	remaining: 49.7ms
# 11:	learn: 0.6405571	total: 6.68ms	remaining: 49ms
# 12:	learn: 0.6364753	total: 7.23ms	remaining: 48.4ms
# 13:	learn: 0.6326395	total: 7.75ms	remaining: 47.6ms
# 14:	learn: 0.6284163	total: 8.28ms	remaining: 46.9ms
# 15:	learn: 0.6239878	total: 9.27ms	remaining: 48.7ms
# 16:	learn: 0.6203321	total: 9.94ms	remaining: 48.5ms
# 17:	learn: 0.6172297	total: 10.5ms	remaining: 47.8ms
# 18:	learn: 0.6135809	total: 11.1ms	remaining: 47.1ms
# 19:	learn: 0.6098729	total: 11.6ms	remaining: 46.3ms
# 20:	learn: 0.6062358	total: 12.1ms	remaining: 45.7ms
# 21:	learn: 0.6025969	total: 12.7ms	remaining: 45.1ms
# 22:	learn: 0.5988494	total: 13.3ms	remaining: 44.4ms
# 23:	learn: 0.5959713	total: 13.8ms	remaining: 43.7ms
# 24:	learn: 0.5925535	total: 14.3ms	remaining: 43ms
# 25:	learn: 0.5897408	total: 14.9ms	remaining: 42.4ms
# 26:	learn: 0.5869943	total: 15.4ms	remaining: 41.7ms
# 27:	learn: 0.5830996	total: 16ms	remaining: 41.1ms
# 28:	learn: 0.5802578	total: 16.5ms	remaining: 40.5ms
# 29:	learn: 0.5774313	total: 17ms	remaining: 39.8ms
# 30:	learn: 0.5750550	total: 17.6ms	remaining: 39.2ms
# 31:	learn: 0.5719800	total: 18.2ms	remaining: 38.7ms
# 32:	learn: 0.5695967	total: 18.7ms	remaining: 38ms
# 33:	learn: 0.5662682	total: 19.3ms	remaining: 37.4ms
# 34:	learn: 0.5631656	total: 19.8ms	remaining: 36.8ms
# 35:	learn: 0.5606814	total: 20.4ms	remaining: 36.3ms
# 36:	learn: 0.5577683	total: 21ms	remaining: 35.8ms
# 37:	learn: 0.5558685	total: 21.5ms	remaining: 35.1ms
# 38:	learn: 0.5528332	total: 22.1ms	remaining: 34.6ms
# 39:	learn: 0.5501416	total: 22.7ms	remaining: 34.1ms
# 40:	learn: 0.5476413	total: 23.2ms	remaining: 33.4ms
# 41:	learn: 0.5461013	total: 23.8ms	remaining: 32.9ms
# 42:	learn: 0.5440905	total: 24.4ms	remaining: 32.3ms
# 43:	learn: 0.5414508	total: 24.9ms	remaining: 31.7ms
# 44:	learn: 0.5395015	total: 25.4ms	remaining: 31.1ms
# 45:	learn: 0.5369063	total: 26ms	remaining: 30.5ms
# 46:	learn: 0.5345618	total: 26.5ms	remaining: 29.9ms
# 47:	learn: 0.5323764	total: 27ms	remaining: 29.2ms
# 48:	learn: 0.5304551	total: 27.6ms	remaining: 28.7ms
# 49:	learn: 0.5284334	total: 28.1ms	remaining: 28.1ms
# 50:	learn: 0.5266907	total: 28.7ms	remaining: 27.5ms
# 51:	learn: 0.5250241	total: 29.2ms	remaining: 27ms
# 52:	learn: 0.5234026	total: 29.7ms	remaining: 26.4ms
# 53:	learn: 0.5212696	total: 30.3ms	remaining: 25.8ms
# 54:	learn: 0.5193307	total: 30.9ms	remaining: 25.2ms
# 55:	learn: 0.5172177	total: 31.4ms	remaining: 24.7ms
# 56:	learn: 0.5155964	total: 32ms	remaining: 24.1ms
# 57:	learn: 0.5143746	total: 32.5ms	remaining: 23.5ms
# 58:	learn: 0.5127239	total: 33ms	remaining: 23ms
# 59:	learn: 0.5110371	total: 33.6ms	remaining: 22.4ms
# 60:	learn: 0.5089516	total: 34.1ms	remaining: 21.8ms
# 61:	learn: 0.5072279	total: 34.6ms	remaining: 21.2ms
# 62:	learn: 0.5057066	total: 35.1ms	remaining: 20.6ms
# 63:	learn: 0.5042926	total: 35.7ms	remaining: 20.1ms
# 64:	learn: 0.5025797	total: 36.2ms	remaining: 19.5ms
# 65:	learn: 0.5007825	total: 36.8ms	remaining: 19ms
# 66:	learn: 0.4992922	total: 37.3ms	remaining: 18.4ms
# 67:	learn: 0.4980089	total: 37.9ms	remaining: 17.8ms
# 68:	learn: 0.4968343	total: 38.4ms	remaining: 17.3ms
# 69:	learn: 0.4953177	total: 39ms	remaining: 16.7ms
# 70:	learn: 0.4936009	total: 39.6ms	remaining: 16.2ms
# 71:	learn: 0.4923601	total: 40.1ms	remaining: 15.6ms
# 72:	learn: 0.4913007	total: 40.7ms	remaining: 15.1ms
# 73:	learn: 0.4896744	total: 41.3ms	remaining: 14.5ms
# 74:	learn: 0.4884347	total: 41.8ms	remaining: 13.9ms
# 75:	learn: 0.4870876	total: 42.4ms	remaining: 13.4ms
# 76:	learn: 0.4853756	total: 43ms	remaining: 12.8ms
# 77:	learn: 0.4843376	total: 43.6ms	remaining: 12.3ms
# 78:	learn: 0.4832403	total: 44.1ms	remaining: 11.7ms
# 79:	learn: 0.4820771	total: 44.7ms	remaining: 11.2ms
# 80:	learn: 0.4808593	total: 45.2ms	remaining: 10.6ms
# 81:	learn: 0.4797274	total: 45.8ms	remaining: 10ms
# 82:	learn: 0.4787386	total: 46.3ms	remaining: 9.49ms
# 83:	learn: 0.4775437	total: 46.8ms	remaining: 8.92ms
# 84:	learn: 0.4762338	total: 47.4ms	remaining: 8.36ms
# 85:	learn: 0.4748153	total: 48ms	remaining: 7.81ms
# 86:	learn: 0.4736302	total: 48.6ms	remaining: 7.25ms
# 87:	learn: 0.4729040	total: 49.1ms	remaining: 6.69ms
# 88:	learn: 0.4715459	total: 49.6ms	remaining: 6.13ms
# 89:	learn: 0.4704498	total: 50.1ms	remaining: 5.57ms
# 90:	learn: 0.4694506	total: 50.7ms	remaining: 5.01ms
# 91:	learn: 0.4685296	total: 51.2ms	remaining: 4.45ms
# 92:	learn: 0.4677157	total: 51.8ms	remaining: 3.9ms
# 93:	learn: 0.4664675	total: 52.3ms	remaining: 3.34ms
# 94:	learn: 0.4652889	total: 52.9ms	remaining: 2.78ms
# 95:	learn: 0.4640742	total: 53.4ms	remaining: 2.22ms
# 96:	learn: 0.4629143	total: 54ms	remaining: 1.67ms
# 97:	learn: 0.4617769	total: 54.5ms	remaining: 1.11ms
# 98:	learn: 0.4609078	total: 55.3ms	remaining: 558us
# 99:	learn: 0.4600108	total: 55.9ms	remaining: 0us
# 0:	learn: 0.6871485	total: 633us	remaining: 62.7ms
# 1:	learn: 0.6818738	total: 1.37ms	remaining: 67.2ms
# 2:	learn: 0.6757356	total: 1.97ms	remaining: 63.6ms
# 3:	learn: 0.6699559	total: 2.49ms	remaining: 59.8ms
# 4:	learn: 0.6643742	total: 3.03ms	remaining: 57.6ms
# 5:	learn: 0.6582337	total: 3.56ms	remaining: 55.7ms
# 6:	learn: 0.6532148	total: 4.06ms	remaining: 53.9ms
# 7:	learn: 0.6474785	total: 4.6ms	remaining: 52.9ms
# 8:	learn: 0.6421873	total: 5.12ms	remaining: 51.8ms
# 9:	learn: 0.6366277	total: 5.65ms	remaining: 50.8ms
# 10:	learn: 0.6317549	total: 6.14ms	remaining: 49.7ms
# 11:	learn: 0.6272831	total: 6.66ms	remaining: 48.8ms
# 12:	learn: 0.6219195	total: 7.19ms	remaining: 48.1ms
# 13:	learn: 0.6175156	total: 7.69ms	remaining: 47.2ms
# 14:	learn: 0.6115475	total: 8.21ms	remaining: 46.5ms
# 15:	learn: 0.6065788	total: 8.75ms	remaining: 45.9ms
# 16:	learn: 0.6020709	total: 9.35ms	remaining: 45.7ms
# 17:	learn: 0.5972846	total: 9.96ms	remaining: 45.4ms
# 18:	learn: 0.5934413	total: 10.4ms	remaining: 44.5ms
# 19:	learn: 0.5896949	total: 11ms	remaining: 44.1ms
# 20:	learn: 0.5857131	total: 11.5ms	remaining: 43.4ms
# 21:	learn: 0.5815711	total: 12.1ms	remaining: 42.9ms
# 22:	learn: 0.5775481	total: 12.6ms	remaining: 42.3ms
# 23:	learn: 0.5741848	total: 13.1ms	remaining: 41.6ms
# 24:	learn: 0.5701816	total: 13.7ms	remaining: 41.1ms
# 25:	learn: 0.5665628	total: 14.2ms	remaining: 40.5ms
# 26:	learn: 0.5633633	total: 14.7ms	remaining: 39.8ms
# 27:	learn: 0.5594360	total: 15.2ms	remaining: 39.2ms
# 28:	learn: 0.5561850	total: 15.8ms	remaining: 38.6ms
# 29:	learn: 0.5529079	total: 16.3ms	remaining: 37.9ms
# 30:	learn: 0.5490767	total: 16.8ms	remaining: 37.4ms
# 31:	learn: 0.5451989	total: 17.3ms	remaining: 36.8ms
# 32:	learn: 0.5424823	total: 17.8ms	remaining: 36.2ms
# 33:	learn: 0.5396722	total: 18.3ms	remaining: 35.6ms
# 34:	learn: 0.5360615	total: 18.9ms	remaining: 35.1ms
# 35:	learn: 0.5330916	total: 19.4ms	remaining: 34.6ms
# 36:	learn: 0.5297697	total: 20ms	remaining: 34ms
# 37:	learn: 0.5265222	total: 20.5ms	remaining: 33.4ms
# 38:	learn: 0.5239422	total: 21ms	remaining: 32.8ms
# 39:	learn: 0.5211957	total: 21.5ms	remaining: 32.2ms
# 40:	learn: 0.5190173	total: 22ms	remaining: 31.6ms
# 41:	learn: 0.5155614	total: 22.5ms	remaining: 31.1ms
# 42:	learn: 0.5135810	total: 23ms	remaining: 30.5ms
# 43:	learn: 0.5105858	total: 23.5ms	remaining: 29.9ms
# 44:	learn: 0.5073207	total: 24ms	remaining: 29.4ms
# 45:	learn: 0.5048986	total: 24.6ms	remaining: 28.9ms
# 46:	learn: 0.5028465	total: 25.2ms	remaining: 28.4ms
# 47:	learn: 0.5008334	total: 25.7ms	remaining: 27.8ms
# 48:	learn: 0.4984138	total: 26.1ms	remaining: 27.2ms
# 49:	learn: 0.4958858	total: 26.8ms	remaining: 26.8ms
# 50:	learn: 0.4937685	total: 27.3ms	remaining: 26.2ms
# 51:	learn: 0.4912522	total: 27.8ms	remaining: 25.7ms
# 52:	learn: 0.4893022	total: 28.4ms	remaining: 25.2ms
# 53:	learn: 0.4867089	total: 29ms	remaining: 24.7ms
# 54:	learn: 0.4844233	total: 29.5ms	remaining: 24.1ms
# 55:	learn: 0.4821222	total: 30ms	remaining: 23.6ms
# 56:	learn: 0.4796914	total: 30.5ms	remaining: 23ms
# 57:	learn: 0.4778262	total: 31.1ms	remaining: 22.5ms
# 58:	learn: 0.4759021	total: 31.6ms	remaining: 22ms
# 59:	learn: 0.4739787	total: 32.2ms	remaining: 21.4ms
# 60:	learn: 0.4720216	total: 32.7ms	remaining: 20.9ms
# 61:	learn: 0.4703172	total: 33.2ms	remaining: 20.3ms
# 62:	learn: 0.4683727	total: 33.7ms	remaining: 19.8ms
# 63:	learn: 0.4667884	total: 34.3ms	remaining: 19.3ms
# 64:	learn: 0.4652479	total: 34.8ms	remaining: 18.7ms
# 65:	learn: 0.4630465	total: 35.3ms	remaining: 18.2ms
# 66:	learn: 0.4613213	total: 35.8ms	remaining: 17.7ms
# 67:	learn: 0.4599201	total: 36.4ms	remaining: 17.1ms
# 68:	learn: 0.4582384	total: 36.9ms	remaining: 16.6ms
# 69:	learn: 0.4572505	total: 37.5ms	remaining: 16.1ms
# 70:	learn: 0.4559125	total: 38ms	remaining: 15.5ms
# 71:	learn: 0.4545899	total: 38.5ms	remaining: 15ms
# 72:	learn: 0.4535535	total: 39ms	remaining: 14.4ms
# 73:	learn: 0.4520685	total: 39.6ms	remaining: 13.9ms
# 74:	learn: 0.4503764	total: 40.1ms	remaining: 13.4ms
# 75:	learn: 0.4487451	total: 40.7ms	remaining: 12.9ms
# 76:	learn: 0.4472935	total: 41.2ms	remaining: 12.3ms
# 77:	learn: 0.4457361	total: 41.8ms	remaining: 11.8ms
# 78:	learn: 0.4442742	total: 42.3ms	remaining: 11.2ms
# 79:	learn: 0.4427948	total: 42.8ms	remaining: 10.7ms
# 80:	learn: 0.4414617	total: 43.4ms	remaining: 10.2ms
# 81:	learn: 0.4396721	total: 44ms	remaining: 9.65ms
# 82:	learn: 0.4381668	total: 44.6ms	remaining: 9.13ms
# 83:	learn: 0.4372121	total: 45.2ms	remaining: 8.61ms
# 84:	learn: 0.4367622	total: 45.7ms	remaining: 8.07ms
# 85:	learn: 0.4354739	total: 46.3ms	remaining: 7.54ms
# 86:	learn: 0.4345376	total: 46.8ms	remaining: 6.99ms
# 87:	learn: 0.4331708	total: 47.3ms	remaining: 6.45ms
# 88:	learn: 0.4319523	total: 47.8ms	remaining: 5.91ms
# 89:	learn: 0.4308115	total: 48.3ms	remaining: 5.37ms
# 90:	learn: 0.4300260	total: 48.9ms	remaining: 4.83ms
# 91:	learn: 0.4285985	total: 49.4ms	remaining: 4.3ms
# 92:	learn: 0.4274622	total: 49.9ms	remaining: 3.76ms
# 93:	learn: 0.4262084	total: 50.5ms	remaining: 3.22ms
# 94:	learn: 0.4250851	total: 51ms	remaining: 2.68ms
# 95:	learn: 0.4238430	total: 51.5ms	remaining: 2.15ms
# 96:	learn: 0.4228109	total: 52ms	remaining: 1.61ms
# 97:	learn: 0.4214698	total: 52.5ms	remaining: 1.07ms
# 98:	learn: 0.4206079	total: 53.1ms	remaining: 536us
# 99:	learn: 0.4199379	total: 53.6ms	remaining: 0us
# 0:	learn: 0.6881123	total: 655us	remaining: 64.9ms
# 1:	learn: 0.6815996	total: 1.26ms	remaining: 61.6ms
# 2:	learn: 0.6745041	total: 1.81ms	remaining: 58.5ms
# 3:	learn: 0.6686475	total: 2.36ms	remaining: 56.7ms
# 4:	learn: 0.6637037	total: 2.88ms	remaining: 54.7ms
# 5:	learn: 0.6583836	total: 3.36ms	remaining: 52.6ms
# 6:	learn: 0.6541100	total: 3.91ms	remaining: 51.9ms
# 7:	learn: 0.6485101	total: 4.43ms	remaining: 50.9ms
# 8:	learn: 0.6445168	total: 4.93ms	remaining: 49.9ms
# 9:	learn: 0.6391996	total: 5.48ms	remaining: 49.3ms
# 10:	learn: 0.6344652	total: 5.99ms	remaining: 48.5ms
# 11:	learn: 0.6284412	total: 6.51ms	remaining: 47.8ms
# 12:	learn: 0.6233390	total: 7.02ms	remaining: 47ms
# 13:	learn: 0.6185608	total: 7.54ms	remaining: 46.3ms
# 14:	learn: 0.6133585	total: 8.08ms	remaining: 45.8ms
# 15:	learn: 0.6092988	total: 8.59ms	remaining: 45.1ms
# 16:	learn: 0.6044668	total: 9.12ms	remaining: 44.5ms
# 17:	learn: 0.6006236	total: 9.64ms	remaining: 43.9ms
# 18:	learn: 0.5965840	total: 10.1ms	remaining: 43.3ms
# 19:	learn: 0.5926988	total: 10.7ms	remaining: 42.8ms
# 20:	learn: 0.5892121	total: 11.2ms	remaining: 42.1ms
# 21:	learn: 0.5849392	total: 11.8ms	remaining: 41.8ms
# 22:	learn: 0.5810169	total: 12.3ms	remaining: 41.3ms
# 23:	learn: 0.5771158	total: 12.9ms	remaining: 40.8ms
# 24:	learn: 0.5734735	total: 13.4ms	remaining: 40.2ms
# 25:	learn: 0.5699593	total: 13.9ms	remaining: 39.6ms
# 26:	learn: 0.5661707	total: 14.4ms	remaining: 39ms
# ...
# 186:	learn: 0.0086340	total: 1.94s	remaining: 135ms
# 187:	learn: 0.0086220	total: 1.94s	remaining: 124ms
# 188:	learn: 0.0086116	total: 1.96s	remaining: 114ms
# 189:	learn: 0.0086014	total: 1.97s	remaining: 104ms
# 190:	learn: 0.0085945	total: 1.98s	remaining: 93.2ms
# 191:	learn: 0.0085797	total: 1.99s	remaining: 82.8ms
# 192:	learn: 0.0085674	total: 2s	remaining: 72.5ms
# 193:	learn: 0.0085556	total: 2.01s	remaining: 62.1ms
# 194:	learn: 0.0085462	total: 2.02s	remaining: 51.7ms
# 195:	learn: 0.0085342	total: 2.03s	remaining: 41.4ms
# 196:	learn: 0.0085262	total: 2.04s	remaining: 31ms
# 197:	learn: 0.0085187	total: 2.05s	remaining: 20.7ms
# 198:	learn: 0.0085073	total: 2.06s	remaining: 10.3ms
# 199:	learn: 0.0084968	total: 2.07s	remaining: 0us
# 0:	learn: 0.4533998	total: 9.62ms	remaining: 1.91s
# 1:	learn: 0.3218999	total: 19.5ms	remaining: 1.93s
# 2:	learn: 0.2480185	total: 30.2ms	remaining: 1.99s
# 3:	learn: 0.1833930	total: 40ms	remaining: 1.96s
# 4:	learn: 0.1510915	total: 49.4ms	remaining: 1.93s
# 5:	learn: 0.1354961	total: 54.6ms	remaining: 1.76s
# 6:	learn: 0.1229018	total: 65.9ms	remaining: 1.82s
# 7:	learn: 0.1095377	total: 76.5ms	remaining: 1.83s
# 8:	learn: 0.0979384	total: 88.2ms	remaining: 1.87s
# 9:	learn: 0.0860459	total: 97.6ms	remaining: 1.85s
# 10:	learn: 0.0733917	total: 107ms	remaining: 1.84s
# 11:	learn: 0.0653832	total: 117ms	remaining: 1.83s
# 12:	learn: 0.0593359	total: 128ms	remaining: 1.83s
# 13:	learn: 0.0546936	total: 138ms	remaining: 1.84s
# 14:	learn: 0.0513479	total: 148ms	remaining: 1.82s
# 15:	learn: 0.0483468	total: 158ms	remaining: 1.82s
# 16:	learn: 0.0456997	total: 169ms	remaining: 1.82s
# 17:	learn: 0.0437936	total: 179ms	remaining: 1.8s
# 18:	learn: 0.0416897	total: 188ms	remaining: 1.79s
# 19:	learn: 0.0400074	total: 197ms	remaining: 1.77s
# 20:	learn: 0.0380478	total: 208ms	remaining: 1.77s
# 21:	learn: 0.0362217	total: 219ms	remaining: 1.77s
# 22:	learn: 0.0351217	total: 230ms	remaining: 1.77s
# 23:	learn: 0.0339418	total: 239ms	remaining: 1.75s
# 24:	learn: 0.0330422	total: 249ms	remaining: 1.74s
# 25:	learn: 0.0319086	total: 260ms	remaining: 1.74s
# 26:	learn: 0.0312393	total: 269ms	remaining: 1.72s
# 27:	learn: 0.0304489	total: 279ms	remaining: 1.71s
# 28:	learn: 0.0297875	total: 289ms	remaining: 1.7s
# 29:	learn: 0.0292293	total: 298ms	remaining: 1.69s
# 30:	learn: 0.0287340	total: 308ms	remaining: 1.68s
# 31:	learn: 0.0280959	total: 318ms	remaining: 1.67s
# 32:	learn: 0.0276919	total: 329ms	remaining: 1.66s
# 33:	learn: 0.0270742	total: 338ms	remaining: 1.65s
# 34:	learn: 0.0266744	total: 348ms	remaining: 1.64s
# 35:	learn: 0.0262727	total: 357ms	remaining: 1.63s
# 36:	learn: 0.0258997	total: 366ms	remaining: 1.61s
# 37:	learn: 0.0256004	total: 375ms	remaining: 1.6s
# 38:	learn: 0.0252141	total: 384ms	remaining: 1.59s
# 39:	learn: 0.0248898	total: 396ms	remaining: 1.58s
# 40:	learn: 0.0244470	total: 405ms	remaining: 1.57s
# 41:	learn: 0.0241898	total: 416ms	remaining: 1.56s
# 42:	learn: 0.0239975	total: 425ms	remaining: 1.55s
# 43:	learn: 0.0238004	total: 434ms	remaining: 1.54s
# 44:	learn: 0.0235150	total: 445ms	remaining: 1.53s
# 45:	learn: 0.0233577	total: 454ms	remaining: 1.52s
# 46:	learn: 0.0231083	total: 465ms	remaining: 1.51s
# 47:	learn: 0.0228848	total: 474ms	remaining: 1.5s
# 48:	learn: 0.0227494	total: 484ms	remaining: 1.49s
# 49:	learn: 0.0225120	total: 493ms	remaining: 1.48s
# 50:	learn: 0.0222832	total: 503ms	remaining: 1.47s
# 51:	learn: 0.0220674	total: 512ms	remaining: 1.46s
# 52:	learn: 0.0218716	total: 523ms	remaining: 1.45s
# 53:	learn: 0.0216769	total: 533ms	remaining: 1.44s
# 54:	learn: 0.0215201	total: 543ms	remaining: 1.43s
# 55:	learn: 0.0214156	total: 553ms	remaining: 1.42s
# 56:	learn: 0.0212823	total: 562ms	remaining: 1.41s
# 57:	learn: 0.0211670	total: 572ms	remaining: 1.4s
# 58:	learn: 0.0210745	total: 582ms	remaining: 1.39s
# 59:	learn: 0.0209311	total: 593ms	remaining: 1.38s
# 60:	learn: 0.0207942	total: 602ms	remaining: 1.37s
# 61:	learn: 0.0206770	total: 611ms	remaining: 1.36s
# 62:	learn: 0.0205697	total: 622ms	remaining: 1.35s
# 63:	learn: 0.0204544	total: 633ms	remaining: 1.34s
# 64:	learn: 0.0203709	total: 644ms	remaining: 1.34s
# 65:	learn: 0.0202468	total: 656ms	remaining: 1.33s
# 66:	learn: 0.0201010	total: 665ms	remaining: 1.32s
# 67:	learn: 0.0199710	total: 676ms	remaining: 1.31s
# 68:	learn: 0.0198764	total: 686ms	remaining: 1.3s
# 69:	learn: 0.0198008	total: 696ms	remaining: 1.29s
# 70:	learn: 0.0197303	total: 707ms	remaining: 1.28s
# 71:	learn: 0.0196356	total: 718ms	remaining: 1.28s
# 72:	learn: 0.0195550	total: 728ms	remaining: 1.26s
# 73:	learn: 0.0194745	total: 737ms	remaining: 1.25s
# 74:	learn: 0.0194140	total: 746ms	remaining: 1.24s
# 75:	learn: 0.0193524	total: 756ms	remaining: 1.23s
# 76:	learn: 0.0192961	total: 767ms	remaining: 1.22s
# 77:	learn: 0.0192348	total: 777ms	remaining: 1.22s
# 78:	learn: 0.0191837	total: 787ms	remaining: 1.21s
# 79:	learn: 0.0191180	total: 797ms	remaining: 1.2s
# 80:	learn: 0.0190466	total: 808ms	remaining: 1.19s
# 81:	learn: 0.0190003	total: 818ms	remaining: 1.18s
# 82:	learn: 0.0189305	total: 830ms	remaining: 1.17s
# 83:	learn: 0.0188373	total: 840ms	remaining: 1.16s
# 84:	learn: 0.0187794	total: 851ms	remaining: 1.15s
# 85:	learn: 0.0187241	total: 860ms	remaining: 1.14s
# 86:	learn: 0.0186595	total: 870ms	remaining: 1.13s
# 87:	learn: 0.0186140	total: 880ms	remaining: 1.12s
# 88:	learn: 0.0185456	total: 889ms	remaining: 1.11s
# 89:	learn: 0.0184814	total: 899ms	remaining: 1.1s
# 90:	learn: 0.0184343	total: 908ms	remaining: 1.09s
# 91:	learn: 0.0183860	total: 917ms	remaining: 1.08s
# 92:	learn: 0.0183386	total: 927ms	remaining: 1.07s
# 93:	learn: 0.0183007	total: 938ms	remaining: 1.06s
# 94:	learn: 0.0182575	total: 950ms	remaining: 1.05s
# 95:	learn: 0.0182092	total: 961ms	remaining: 1.04s
# 96:	learn: 0.0181552	total: 970ms	remaining: 1.03s
# 97:	learn: 0.0181156	total: 980ms	remaining: 1.02s
# 98:	learn: 0.0180727	total: 989ms	remaining: 1.01s
# 99:	learn: 0.0180291	total: 1s	remaining: 1s
# 100:	learn: 0.0179860	total: 1.01s	remaining: 992ms
# 101:	learn: 0.0179411	total: 1.02s	remaining: 981ms
# 102:	learn: 0.0179003	total: 1.03s	remaining: 971ms
# 103:	learn: 0.0178617	total: 1.04s	remaining: 962ms
# 104:	learn: 0.0178143	total: 1.05s	remaining: 952ms
# 105:	learn: 0.0177835	total: 1.06s	remaining: 941ms
# 106:	learn: 0.0177521	total: 1.07s	remaining: 931ms
# 107:	learn: 0.0177194	total: 1.08s	remaining: 921ms
# 108:	learn: 0.0176904	total: 1.09s	remaining: 911ms
# 109:	learn: 0.0176642	total: 1.1s	remaining: 900ms
# 110:	learn: 0.0176303	total: 1.11s	remaining: 890ms
# 111:	learn: 0.0176016	total: 1.12s	remaining: 879ms
# 112:	learn: 0.0175747	total: 1.13s	remaining: 869ms
# 113:	learn: 0.0175335	total: 1.14s	remaining: 859ms
# 114:	learn: 0.0175061	total: 1.15s	remaining: 849ms
# 115:	learn: 0.0174724	total: 1.16s	remaining: 840ms
# 116:	learn: 0.0174476	total: 1.17s	remaining: 831ms
# 117:	learn: 0.0174233	total: 1.18s	remaining: 822ms
# 118:	learn: 0.0173969	total: 1.19s	remaining: 812ms
# 119:	learn: 0.0173690	total: 1.2s	remaining: 802ms
# 120:	learn: 0.0173426	total: 1.21s	remaining: 792ms
# 121:	learn: 0.0173219	total: 1.22s	remaining: 782ms
# 122:	learn: 0.0172953	total: 1.23s	remaining: 772ms
# 123:	learn: 0.0172756	total: 1.25s	remaining: 764ms
# 124:	learn: 0.0172554	total: 1.25s	remaining: 753ms
# 125:	learn: 0.0172344	total: 1.26s	remaining: 743ms
# 126:	learn: 0.0172040	total: 1.27s	remaining: 733ms
# 127:	learn: 0.0171817	total: 1.29s	remaining: 724ms
# 128:	learn: 0.0171555	total: 1.3s	remaining: 715ms
# 129:	learn: 0.0171349	total: 1.31s	remaining: 705ms
# 130:	learn: 0.0171137	total: 1.32s	remaining: 694ms
# 131:	learn: 0.0170868	total: 1.33s	remaining: 685ms
# 132:	learn: 0.0170667	total: 1.34s	remaining: 674ms
# 133:	learn: 0.0170501	total: 1.35s	remaining: 664ms
# 134:	learn: 0.0170235	total: 1.36s	remaining: 655ms
# 135:	learn: 0.0170024	total: 1.37s	remaining: 644ms
# 136:	learn: 0.0169814	total: 1.38s	remaining: 634ms
# 137:	learn: 0.0169586	total: 1.39s	remaining: 624ms
# 138:	learn: 0.0169434	total: 1.4s	remaining: 614ms
# 139:	learn: 0.0169253	total: 1.41s	remaining: 604ms
# 140:	learn: 0.0169017	total: 1.42s	remaining: 594ms
# 141:	learn: 0.0168825	total: 1.43s	remaining: 584ms
# 142:	learn: 0.0168567	total: 1.44s	remaining: 574ms
# 143:	learn: 0.0168312	total: 1.45s	remaining: 564ms
# 144:	learn: 0.0168170	total: 1.46s	remaining: 553ms
# 145:	learn: 0.0167894	total: 1.47s	remaining: 544ms
# 146:	learn: 0.0167761	total: 1.48s	remaining: 534ms
# 147:	learn: 0.0167631	total: 1.49s	remaining: 524ms
# 148:	learn: 0.0167419	total: 1.5s	remaining: 514ms
# 149:	learn: 0.0167273	total: 1.51s	remaining: 504ms
# 150:	learn: 0.0167151	total: 1.52s	remaining: 494ms
# 151:	learn: 0.0166987	total: 1.53s	remaining: 484ms
# 152:	learn: 0.0166820	total: 1.54s	remaining: 474ms
# 153:	learn: 0.0166651	total: 1.55s	remaining: 463ms
# 154:	learn: 0.0166535	total: 1.56s	remaining: 453ms
# 155:	learn: 0.0166423	total: 1.57s	remaining: 443ms
# 156:	learn: 0.0166270	total: 1.58s	remaining: 433ms
# 157:	learn: 0.0166128	total: 1.59s	remaining: 423ms
# 158:	learn: 0.0165976	total: 1.6s	remaining: 413ms
# 159:	learn: 0.0165865	total: 1.61s	remaining: 403ms
# 160:	learn: 0.0165641	total: 1.62s	remaining: 393ms
# 161:	learn: 0.0165636	total: 1.63s	remaining: 383ms
# 162:	learn: 0.0165409	total: 1.64s	remaining: 373ms
# 163:	learn: 0.0165207	total: 1.66s	remaining: 363ms
# 164:	learn: 0.0165062	total: 1.67s	remaining: 353ms
# 165:	learn: 0.0164976	total: 1.68s	remaining: 344ms
# 166:	learn: 0.0164805	total: 1.69s	remaining: 333ms
# 167:	learn: 0.0164706	total: 1.7s	remaining: 323ms
# 168:	learn: 0.0164613	total: 1.71s	remaining: 313ms
# 169:	learn: 0.0164517	total: 1.72s	remaining: 303ms
# 170:	learn: 0.0164405	total: 1.73s	remaining: 294ms
# 171:	learn: 0.0164314	total: 1.74s	remaining: 283ms
# 172:	learn: 0.0164211	total: 1.75s	remaining: 273ms
# 173:	learn: 0.0164209	total: 1.76s	remaining: 263ms
# 174:	learn: 0.0164081	total: 1.77s	remaining: 253ms
# 175:	learn: 0.0163902	total: 1.78s	remaining: 243ms
# 176:	learn: 0.0163775	total: 1.79s	remaining: 233ms
# 177:	learn: 0.0163615	total: 1.8s	remaining: 223ms
# 178:	learn: 0.0163530	total: 1.82s	remaining: 213ms
# 179:	learn: 0.0163448	total: 1.83s	remaining: 203ms
# 180:	learn: 0.0163296	total: 1.84s	remaining: 193ms
# 181:	learn: 0.0163212	total: 1.85s	remaining: 183ms
# 182:	learn: 0.0163107	total: 1.86s	remaining: 173ms
# 183:	learn: 0.0162983	total: 1.87s	remaining: 163ms
# 184:	learn: 0.0162983	total: 1.88s	remaining: 152ms
# 185:	learn: 0.0162915	total: 1.89s	remaining: 142ms
# 186:	learn: 0.0162841	total: 1.9s	remaining: 132ms
# 187:	learn: 0.0162692	total: 1.91s	remaining: 122ms
# 188:	learn: 0.0162551	total: 1.92s	remaining: 112ms
# 189:	learn: 0.0162428	total: 1.93s	remaining: 102ms
# 190:	learn: 0.0162380	total: 1.94s	remaining: 91.5ms
# 191:	learn: 0.0162292	total: 1.95s	remaining: 81.3ms
# 192:	learn: 0.0162244	total: 1.96s	remaining: 71.1ms
# 193:	learn: 0.0162174	total: 1.97s	remaining: 60.9ms
# 194:	learn: 0.0162104	total: 1.98s	remaining: 50.8ms
# 195:	learn: 0.0162012	total: 1.99s	remaining: 40.6ms
# 196:	learn: 0.0161932	total: 2s	remaining: 30.5ms
# 197:	learn: 0.0161829	total: 2.01s	remaining: 20.3ms
# 198:	learn: 0.0161754	total: 2.02s	remaining: 10.1ms
# 199:	learn: 0.0161753	total: 2.03s	remaining: 0us
# 0:	learn: 0.6211829	total: 11.9ms	remaining: 584ms
# 1:	learn: 0.5583908	total: 23.8ms	remaining: 571ms
# 2:	learn: 0.5053183	total: 33.5ms	remaining: 525ms
# 3:	learn: 0.4602308	total: 44.3ms	remaining: 510ms
# 4:	learn: 0.4222979	total: 54.4ms	remaining: 490ms
# 5:	learn: 0.3948969	total: 59.7ms	remaining: 438ms
# 6:	learn: 0.3718058	total: 70.3ms	remaining: 432ms
# 7:	learn: 0.3465880	total: 79.5ms	remaining: 418ms
# 8:	learn: 0.3242234	total: 90.3ms	remaining: 411ms
# 9:	learn: 0.3088939	total: 101ms	remaining: 404ms
# 10:	learn: 0.2923852	total: 112ms	remaining: 397ms
# 11:	learn: 0.2789191	total: 124ms	remaining: 392ms
# 12:	learn: 0.2693736	total: 125ms	remaining: 355ms
# 13:	learn: 0.2601543	total: 134ms	remaining: 346ms
# 14:	learn: 0.2556347	total: 135ms	remaining: 315ms
# 15:	learn: 0.2392677	total: 145ms	remaining: 308ms
# 16:	learn: 0.2302003	total: 155ms	remaining: 300ms
# 17:	learn: 0.2250938	total: 155ms	remaining: 276ms
# 18:	learn: 0.2156249	total: 166ms	remaining: 270ms
# 19:	learn: 0.2126661	total: 168ms	remaining: 251ms
# 20:	learn: 0.2032523	total: 179ms	remaining: 247ms
# 21:	learn: 0.1966847	total: 182ms	remaining: 232ms
# 22:	learn: 0.1903897	total: 192ms	remaining: 225ms
# 23:	learn: 0.1850024	total: 202ms	remaining: 218ms
# 24:	learn: 0.1847870	total: 202ms	remaining: 202ms
# 25:	learn: 0.1778992	total: 214ms	remaining: 197ms
# 26:	learn: 0.1698653	total: 223ms	remaining: 190ms
# 27:	learn: 0.1656143	total: 225ms	remaining: 177ms
# 28:	learn: 0.1654811	total: 226ms	remaining: 164ms
# 29:	learn: 0.1596131	total: 238ms	remaining: 158ms
# 30:	learn: 0.1542969	total: 248ms	remaining: 152ms
# 31:	learn: 0.1488699	total: 259ms	remaining: 145ms
# 32:	learn: 0.1433543	total: 269ms	remaining: 138ms
# 33:	learn: 0.1384676	total: 279ms	remaining: 131ms
# 34:	learn: 0.1340309	total: 289ms	remaining: 124ms
# 35:	learn: 0.1301513	total: 299ms	remaining: 116ms
# 36:	learn: 0.1257348	total: 310ms	remaining: 109ms
# 37:	learn: 0.1222468	total: 320ms	remaining: 101ms
# 38:	learn: 0.1185615	total: 330ms	remaining: 93ms
# 39:	learn: 0.1143305	total: 339ms	remaining: 84.8ms
# 40:	learn: 0.1120818	total: 349ms	remaining: 76.6ms
# 41:	learn: 0.1098885	total: 359ms	remaining: 68.3ms
# 42:	learn: 0.1070226	total: 369ms	remaining: 60ms
# 43:	learn: 0.1062792	total: 370ms	remaining: 50.4ms
# 44:	learn: 0.1033653	total: 379ms	remaining: 42.1ms
# 45:	learn: 0.1011074	total: 390ms	remaining: 33.9ms
# 46:	learn: 0.0984093	total: 401ms	remaining: 25.6ms
# 47:	learn: 0.0959569	total: 410ms	remaining: 17.1ms
# 48:	learn: 0.0931890	total: 420ms	remaining: 8.57ms
# 49:	learn: 0.0916931	total: 426ms	remaining: 0us
# Best Parameters for CatBoostClassifier: {'catboostclassifier__learning_rate': 0.1, 'catboostclassifier__max_depth': 10, 'catboostclassifier__n_estimators': 50}
# CatBoostClassifier Classifier:
# Best Parameters: {'catboostclassifier__learning_rate': 0.1, 'catboostclassifier__max_depth': 10, 'catboostclassifier__n_estimators': 50}
# Accuracy: 0.89
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.87      0.94      0.90        49
#  Public University       0.92      0.83      0.88        42
#
#           accuracy                           0.89        91
#          macro avg       0.89      0.89      0.89        91
#       weighted avg       0.89      0.89      0.89        91
#
# ========================================
# Best Parameters for ExtraTreesClassifier: {'extratreesclassifier__max_depth': None, 'extratreesclassifier__min_samples_leaf': 1, 'extratreesclassifier__min_samples_split': 5, 'extratreesclassifier__n_estimators': 200}
# ExtraTreesClassifier Classifier:
# Best Parameters: {'extratreesclassifier__max_depth': None, 'extratreesclassifier__min_samples_leaf': 1, 'extratreesclassifier__min_samples_split': 5, 'extratreesclassifier__n_estimators': 200}
# Accuracy: 0.82
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.84      0.84      0.84        49
#  Public University       0.81      0.81      0.81        42
#
#           accuracy                           0.82        91
#          macro avg       0.82      0.82      0.82        91
#       weighted avg       0.82      0.82      0.82        91
#
# ========================================
# Best Parameters for BaggingClassifier: {'baggingclassifier__max_features': 0.7, 'baggingclassifier__max_samples': 0.7, 'baggingclassifier__n_estimators': 100}
# BaggingClassifier Classifier:
# Best Parameters: {'baggingclassifier__max_features': 0.7, 'baggingclassifier__max_samples': 0.7, 'baggingclassifier__n_estimators': 100}
# Accuracy: 0.85
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.81      0.94      0.87        49
#  Public University       0.91      0.74      0.82        42
#
#           accuracy                           0.85        91
#          macro avg       0.86      0.84      0.84        91
#       weighted avg       0.86      0.85      0.84        91
#
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Hyperparameter tuning for MLPClassifier
param_grid_mlp = {
    'mlpclassifier__hidden_layer_sizes': [(128,), (64,), (32,)],
    'mlpclassifier__activation': ['relu'],
    'mlpclassifier__alpha': [0.0001, 0.001, 0.01],
    'mlpclassifier__batch_size': [32, 64],
    'mlpclassifier__max_iter': [500],
    'mlpclassifier__early_stopping': [True],
    'mlpclassifier__n_iter_no_change': [10],
}

# Create a pipeline for preprocessing and MLPClassifier
pipeline_mlp = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    MLPClassifier(random_state=42)
)

grid_search_mlp = GridSearchCV(pipeline_mlp, param_grid_mlp, cv=5, scoring='accuracy')
grid_search_mlp.fit(X_train, y_train)

# Get the best parameters
best_params_mlp = grid_search_mlp.best_params_
print(f"Best Parameters for MLPClassifier: {best_params_mlp}")

# Evaluate the MLPClassifier with the best parameters
best_mlp_classifier = grid_search_mlp.best_estimator_
best_mlp_predictions = best_mlp_classifier.predict(X_test)
best_mlp_accuracy = accuracy_score(y_test, best_mlp_predictions)
# Convert numeric labels back to class names
class_names = le.classes_
y_test_names = le.inverse_transform(y_test)
best_mlp_predictions_names = le.inverse_transform(best_mlp_predictions)
best_mlp_report = classification_report(y_test_names, best_mlp_predictions_names, target_names=class_names)

print("MLP Classifier:")
print(f"Best Parameters: {best_params_mlp}")
print(f"Accuracy: {best_mlp_accuracy:.2f}")
print(f"Classification Report:\n{best_mlp_report}\n{'='*40}")
# Out:
# Best Parameters for MLPClassifier: {'mlpclassifier__activation': 'relu', 'mlpclassifier__alpha': 0.001, 'mlpclassifier__batch_size': 32, 'mlpclassifier__early_stopping': True, 'mlpclassifier__hidden_layer_sizes': (128,), 'mlpclassifier__max_iter': 500, 'mlpclassifier__n_iter_no_change': 10}
# MLP Classifier:
# Best Parameters: {'mlpclassifier__activation': 'relu', 'mlpclassifier__alpha': 0.001, 'mlpclassifier__batch_size': 32, 'mlpclassifier__early_stopping': True, 'mlpclassifier__hidden_layer_sizes': (128,), 'mlpclassifier__max_iter': 500, 'mlpclassifier__n_iter_no_change': 10}
# Accuracy: 0.77
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.78      0.80      0.79        49
#  Public University       0.76      0.74      0.75        42
#
#           accuracy                           0.77        91
#          macro avg       0.77      0.77      0.77        91
#       weighted avg       0.77      0.77      0.77        91
#
# ========================================

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a more complex ANN model with Dropout and BatchNormalization
ann_model = Sequential()
ann_model.add(Dense(units=128, activation='relu', input_dim=X_train_scaled.shape[1]))
ann_model.add(Dropout(0.5))  # Increase dropout rate
ann_model.add(Dense(units=64, activation='relu'))
ann_model.add(BatchNormalization())
ann_model.add(Dense(units=32, activation='relu'))
ann_model.add(Dropout(0.3))  # Add another dropout layer
ann_model.add(Dense(units=1, activation='sigmoid'))

# Compile the model with a lower learning rate
ann_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the ANN model and get history
history = ann_model.fit(X_train_scaled, y_train, epochs=70, batch_size=16, validation_data=(X_test_scaled, y_test), verbose=1)

# Predictions using the ANN
y_pred_ann = (ann_model.predict(X_test_scaled) > 0.5).astype("int32").flatten()

# Evaluate the ANN
accuracy = accuracy_score(y_test, y_pred_ann)
print('For ANN, the accuracy is= ', accuracy)
# Out:
# Epoch 1/70
# 23/23 [==============================] - 2s 13ms/step - loss: 0.8640 - accuracy: 0.4820 - val_loss: 0.7021 - val_accuracy: 0.4945
# Epoch 2/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8298 - accuracy: 0.5485 - val_loss: 0.6967 - val_accuracy: 0.5604
# Epoch 3/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.8047 - accuracy: 0.5485 - val_loss: 0.6919 - val_accuracy: 0.5495
# Epoch 4/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7785 - accuracy: 0.5402 - val_loss: 0.6872 - val_accuracy: 0.5055
# Epoch 5/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.8124 - accuracy: 0.5291 - val_loss: 0.6857 - val_accuracy: 0.5165
# Epoch 6/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7724 - accuracy: 0.5845 - val_loss: 0.6806 - val_accuracy: 0.5495
# Epoch 7/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7507 - accuracy: 0.6039 - val_loss: 0.6746 - val_accuracy: 0.5604
# Epoch 8/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5762 - val_loss: 0.6690 - val_accuracy: 0.6044
# Epoch 9/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7149 - accuracy: 0.5956 - val_loss: 0.6621 - val_accuracy: 0.5824
# Epoch 10/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7047 - accuracy: 0.5734 - val_loss: 0.6555 - val_accuracy: 0.5934
# Epoch 11/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7195 - accuracy: 0.5956 - val_loss: 0.6478 - val_accuracy: 0.5934
# Epoch 12/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.5706 - val_loss: 0.6403 - val_accuracy: 0.5934
# Epoch 13/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7097 - accuracy: 0.5900 - val_loss: 0.6356 - val_accuracy: 0.6044
# Epoch 14/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.7018 - accuracy: 0.6205 - val_loss: 0.6280 - val_accuracy: 0.6154
# Epoch 15/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6586 - accuracy: 0.6233 - val_loss: 0.6195 - val_accuracy: 0.6374
# Epoch 16/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6617 - accuracy: 0.6371 - val_loss: 0.6140 - val_accuracy: 0.6484
# Epoch 17/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6538 - accuracy: 0.6731 - val_loss: 0.6083 - val_accuracy: 0.6703
# Epoch 18/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6559 - accuracy: 0.6260 - val_loss: 0.6022 - val_accuracy: 0.6813
# Epoch 19/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.6648 - val_loss: 0.5962 - val_accuracy: 0.6813
# Epoch 20/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6503 - accuracy: 0.6260 - val_loss: 0.5919 - val_accuracy: 0.7033
# Epoch 21/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6411 - accuracy: 0.6593 - val_loss: 0.5888 - val_accuracy: 0.7033
# Epoch 22/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6486 - accuracy: 0.6704 - val_loss: 0.5854 - val_accuracy: 0.7033
# Epoch 23/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6433 - accuracy: 0.6427 - val_loss: 0.5819 - val_accuracy: 0.7033
# Epoch 24/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6354 - accuracy: 0.6593 - val_loss: 0.5792 - val_accuracy: 0.7143
# Epoch 25/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6245 - accuracy: 0.6593 - val_loss: 0.5746 - val_accuracy: 0.7253
# Epoch 26/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5949 - accuracy: 0.6787 - val_loss: 0.5706 - val_accuracy: 0.7473
# Epoch 27/70
# 23/23 [==============================] - 0s 8ms/step - loss: 0.6177 - accuracy: 0.6676 - val_loss: 0.5682 - val_accuracy: 0.7692
# Epoch 28/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6345 - accuracy: 0.7036 - val_loss: 0.5656 - val_accuracy: 0.7692
# Epoch 29/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6404 - accuracy: 0.6593 - val_loss: 0.5639 - val_accuracy: 0.7692
# Epoch 30/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5715 - accuracy: 0.7008 - val_loss: 0.5618 - val_accuracy: 0.7692
# Epoch 31/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6211 - accuracy: 0.6620 - val_loss: 0.5581 - val_accuracy: 0.7802
# Epoch 32/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6051 - accuracy: 0.6953 - val_loss: 0.5544 - val_accuracy: 0.7692
# Epoch 33/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6146 - accuracy: 0.6787 - val_loss: 0.5510 - val_accuracy: 0.7692
# Epoch 34/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6006 - accuracy: 0.6814 - val_loss: 0.5470 - val_accuracy: 0.7692
# Epoch 35/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5953 - accuracy: 0.6981 - val_loss: 0.5454 - val_accuracy: 0.7802
# Epoch 36/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6225 - accuracy: 0.6510 - val_loss: 0.5416 - val_accuracy: 0.7802
# Epoch 37/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5330 - accuracy: 0.7175 - val_loss: 0.5382 - val_accuracy: 0.7802
# Epoch 38/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6173 - accuracy: 0.6953 - val_loss: 0.5398 - val_accuracy: 0.7802
# Epoch 39/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6642 - accuracy: 0.6648 - val_loss: 0.5390 - val_accuracy: 0.7802
# Epoch 40/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6049 - accuracy: 0.6953 - val_loss: 0.5368 - val_accuracy: 0.7802
# Epoch 41/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5506 - accuracy: 0.7147 - val_loss: 0.5353 - val_accuracy: 0.7802
# Epoch 42/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5768 - accuracy: 0.7091 - val_loss: 0.5362 - val_accuracy: 0.7802
# Epoch 43/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5603 - accuracy: 0.7147 - val_loss: 0.5357 - val_accuracy: 0.7802
# Epoch 44/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5347 - accuracy: 0.7091 - val_loss: 0.5342 - val_accuracy: 0.7692
# Epoch 45/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5482 - accuracy: 0.7119 - val_loss: 0.5325 - val_accuracy: 0.7692
# Epoch 46/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5800 - accuracy: 0.7036 - val_loss: 0.5316 - val_accuracy: 0.7802
# Epoch 47/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5776 - accuracy: 0.7008 - val_loss: 0.5301 - val_accuracy: 0.7582
# Epoch 48/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5840 - accuracy: 0.7202 - val_loss: 0.5292 - val_accuracy: 0.7582
# Epoch 49/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5833 - accuracy: 0.7008 - val_loss: 0.5302 - val_accuracy: 0.7582
# Epoch 50/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5709 - accuracy: 0.6925 - val_loss: 0.5285 - val_accuracy: 0.7582
# Epoch 51/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5689 - accuracy: 0.6925 - val_loss: 0.5245 - val_accuracy: 0.7582
# Epoch 52/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5233 - accuracy: 0.7285 - val_loss: 0.5219 - val_accuracy: 0.7692
# Epoch 53/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5284 - accuracy: 0.7396 - val_loss: 0.5210 - val_accuracy: 0.7582
# Epoch 54/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5505 - accuracy: 0.7008 - val_loss: 0.5190 - val_accuracy: 0.7582
# Epoch 55/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5605 - accuracy: 0.6925 - val_loss: 0.5166 - val_accuracy: 0.7473
# Epoch 56/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5737 - accuracy: 0.7175 - val_loss: 0.5155 - val_accuracy: 0.7473
# Epoch 57/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6027 - accuracy: 0.7202 - val_loss: 0.5139 - val_accuracy: 0.7473
# Epoch 58/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5483 - accuracy: 0.7258 - val_loss: 0.5119 - val_accuracy: 0.7473
# Epoch 59/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5321 - accuracy: 0.7479 - val_loss: 0.5105 - val_accuracy: 0.7692
# Epoch 60/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5548 - accuracy: 0.7313 - val_loss: 0.5083 - val_accuracy: 0.7582
# Epoch 61/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5333 - accuracy: 0.7452 - val_loss: 0.5069 - val_accuracy: 0.7582
# Epoch 62/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5334 - accuracy: 0.7396 - val_loss: 0.5066 - val_accuracy: 0.7582
# Epoch 63/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.7202 - val_loss: 0.5059 - val_accuracy: 0.7692
# Epoch 64/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5428 - accuracy: 0.7313 - val_loss: 0.5044 - val_accuracy: 0.7692
# Epoch 65/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5374 - accuracy: 0.7341 - val_loss: 0.5027 - val_accuracy: 0.7692
# Epoch 66/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5114 - accuracy: 0.7479 - val_loss: 0.5019 - val_accuracy: 0.7692
# Epoch 67/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5143 - accuracy: 0.7396 - val_loss: 0.5000 - val_accuracy: 0.7692
# Epoch 68/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5021 - accuracy: 0.7729 - val_loss: 0.4989 - val_accuracy: 0.7692
# Epoch 69/70
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5192 - accuracy: 0.7230 - val_loss: 0.4963 - val_accuracy: 0.7802
# Epoch 70/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5322 - accuracy: 0.7341 - val_loss: 0.4949 - val_accuracy: 0.7802
# 3/3 [==============================] - 0s 2ms/step
# For ANN, the accuracy is=  0.7802197802197802

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a more complex ANN model with Dropout and BatchNormalization
ann_model = Sequential()
ann_model.add(Dense(units=512, activation='relu', input_dim=X_train_scaled.shape[1]))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.5))
ann_model.add(Dense(units=256, activation='relu'))
ann_model.add(BatchNormalization())
ann_model.add(Dropout(0.4))
ann_model.add(Dense(units=128, activation='relu'))
ann_model.add(Dropout(0.3))
ann_model.add(Dense(units=64, activation='relu'))
ann_model.add(Dropout(0.2))
ann_model.add(Dense(units=1, activation='sigmoid'))

# Implement learning rate scheduling
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,
    decay_steps=1000,
    decay_rate=0.9
)
ann_model.compile(optimizer=Adam(learning_rate=lr_schedule), loss='binary_crossentropy', metrics=['accuracy'])

# Train the ANN model and get history
history = ann_model.fit(X_train_scaled, y_train, epochs=70, batch_size=16, validation_data=(X_test_scaled, y_test))

# Predictions using the ANN
y_pred_ann = (ann_model.predict(X_test_scaled) > 0.5).astype("int32").flatten()

# Evaluate the ANN
print('For ANN:')
print('Accuracy:', accuracy_score(y_test, y_pred_ann))
print('Classification Report:')
print(classification_report(y_test, y_pred_ann))
# Out:
# Epoch 1/70
# 23/23 [==============================] - 4s 16ms/step - loss: 0.7790 - accuracy: 0.5734 - val_loss: 0.6831 - val_accuracy: 0.5165
# Epoch 2/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7229 - accuracy: 0.6011 - val_loss: 0.6782 - val_accuracy: 0.5934
# Epoch 3/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7252 - accuracy: 0.5873 - val_loss: 0.6723 - val_accuracy: 0.5934
# Epoch 4/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7372 - accuracy: 0.5845 - val_loss: 0.6656 - val_accuracy: 0.6374
# Epoch 5/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6815 - accuracy: 0.6066 - val_loss: 0.6564 - val_accuracy: 0.6593
# Epoch 6/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6958 - accuracy: 0.6150 - val_loss: 0.6466 - val_accuracy: 0.6703
# Epoch 7/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6655 - accuracy: 0.6371 - val_loss: 0.6357 - val_accuracy: 0.6923
# Epoch 8/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6547 - accuracy: 0.6343 - val_loss: 0.6249 - val_accuracy: 0.6813
# Epoch 9/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6417 - accuracy: 0.6620 - val_loss: 0.6129 - val_accuracy: 0.6813
# Epoch 10/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6225 - accuracy: 0.6648 - val_loss: 0.5990 - val_accuracy: 0.7033
# Epoch 11/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6668 - accuracy: 0.6510 - val_loss: 0.5859 - val_accuracy: 0.7143
# Epoch 12/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6190 - accuracy: 0.6731 - val_loss: 0.5733 - val_accuracy: 0.7473
# Epoch 13/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5565 - accuracy: 0.7008 - val_loss: 0.5605 - val_accuracy: 0.7473
# Epoch 14/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5600 - accuracy: 0.7147 - val_loss: 0.5465 - val_accuracy: 0.7473
# Epoch 15/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5137 - accuracy: 0.7479 - val_loss: 0.5326 - val_accuracy: 0.7692
# Epoch 16/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5779 - accuracy: 0.7230 - val_loss: 0.5202 - val_accuracy: 0.7692
# Epoch 17/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5304 - accuracy: 0.7507 - val_loss: 0.5090 - val_accuracy: 0.7692
# Epoch 18/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5695 - accuracy: 0.7424 - val_loss: 0.4963 - val_accuracy: 0.7473
# Epoch 19/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5429 - accuracy: 0.7729 - val_loss: 0.4841 - val_accuracy: 0.7582
# Epoch 20/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5377 - accuracy: 0.7590 - val_loss: 0.4781 - val_accuracy: 0.7802
# Epoch 21/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5317 - accuracy: 0.7341 - val_loss: 0.4717 - val_accuracy: 0.7802
# Epoch 22/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5083 - accuracy: 0.7673 - val_loss: 0.4676 - val_accuracy: 0.7912
# Epoch 23/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5045 - accuracy: 0.7673 - val_loss: 0.4620 - val_accuracy: 0.7912
# Epoch 24/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5131 - accuracy: 0.7479 - val_loss: 0.4593 - val_accuracy: 0.7912
# Epoch 25/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5069 - accuracy: 0.7645 - val_loss: 0.4575 - val_accuracy: 0.7912
# Epoch 26/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5116 - accuracy: 0.7368 - val_loss: 0.4578 - val_accuracy: 0.7912
# Epoch 27/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4898 - accuracy: 0.7867 - val_loss: 0.4545 - val_accuracy: 0.7912
# Epoch 28/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4598 - accuracy: 0.7895 - val_loss: 0.4514 - val_accuracy: 0.7912
# Epoch 29/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4230 - accuracy: 0.7895 - val_loss: 0.4474 - val_accuracy: 0.7912
# Epoch 30/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4925 - accuracy: 0.7535 - val_loss: 0.4443 - val_accuracy: 0.8022
# Epoch 31/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4339 - accuracy: 0.8089 - val_loss: 0.4438 - val_accuracy: 0.8022
# Epoch 32/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4635 - accuracy: 0.7673 - val_loss: 0.4425 - val_accuracy: 0.7802
# Epoch 33/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4654 - accuracy: 0.8061 - val_loss: 0.4392 - val_accuracy: 0.7802
# Epoch 34/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4816 - accuracy: 0.7922 - val_loss: 0.4351 - val_accuracy: 0.7802
# Epoch 35/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4803 - accuracy: 0.7839 - val_loss: 0.4324 - val_accuracy: 0.7802
# Epoch 36/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4888 - accuracy: 0.7673 - val_loss: 0.4330 - val_accuracy: 0.7802
# Epoch 37/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4738 - accuracy: 0.7701 - val_loss: 0.4309 - val_accuracy: 0.7802
# Epoch 38/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4678 - accuracy: 0.7812 - val_loss: 0.4306 - val_accuracy: 0.7912
# Epoch 39/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4585 - accuracy: 0.7812 - val_loss: 0.4316 - val_accuracy: 0.7802
# Epoch 40/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4735 - accuracy: 0.8061 - val_loss: 0.4324 - val_accuracy: 0.7802
# Epoch 41/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4398 - accuracy: 0.8144 - val_loss: 0.4307 - val_accuracy: 0.7802
# Epoch 42/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4510 - accuracy: 0.8199 - val_loss: 0.4316 - val_accuracy: 0.7912
# Epoch 43/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4238 - accuracy: 0.7978 - val_loss: 0.4316 - val_accuracy: 0.7802
# Epoch 44/70
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4855 - accuracy: 0.7895 - val_loss: 0.4325 - val_accuracy: 0.7912
# Epoch 45/70
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4254 - accuracy: 0.8199 - val_loss: 0.4324 - val_accuracy: 0.7912
# Epoch 46/70
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4229 - accuracy: 0.7978 - val_loss: 0.4333 - val_accuracy: 0.7912
# Epoch 47/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4042 - accuracy: 0.8116 - val_loss: 0.4337 - val_accuracy: 0.7912
# Epoch 48/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4090 - accuracy: 0.8089 - val_loss: 0.4333 - val_accuracy: 0.7912
# Epoch 49/70
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4099 - accuracy: 0.8089 - val_loss: 0.4328 - val_accuracy: 0.8022
# Epoch 50/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3887 - accuracy: 0.8393 - val_loss: 0.4335 - val_accuracy: 0.8022
# Epoch 51/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4161 - accuracy: 0.8199 - val_loss: 0.4367 - val_accuracy: 0.8022
# Epoch 52/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4100 - accuracy: 0.8006 - val_loss: 0.4355 - val_accuracy: 0.8022
# Epoch 53/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3826 - accuracy: 0.8227 - val_loss: 0.4392 - val_accuracy: 0.8022
# Epoch 54/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3646 - accuracy: 0.8504 - val_loss: 0.4379 - val_accuracy: 0.7912
# Epoch 55/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3856 - accuracy: 0.8310 - val_loss: 0.4363 - val_accuracy: 0.8022
# Epoch 56/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3813 - accuracy: 0.8255 - val_loss: 0.4376 - val_accuracy: 0.7912
# Epoch 57/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3911 - accuracy: 0.8172 - val_loss: 0.4417 - val_accuracy: 0.7912
# Epoch 58/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3657 - accuracy: 0.8338 - val_loss: 0.4415 - val_accuracy: 0.7802
# Epoch 59/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3775 - accuracy: 0.8227 - val_loss: 0.4452 - val_accuracy: 0.7802
# Epoch 60/70
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3769 - accuracy: 0.8587 - val_loss: 0.4519 - val_accuracy: 0.7692
# Epoch 61/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4162 - accuracy: 0.8338 - val_loss: 0.4520 - val_accuracy: 0.7692
# Epoch 62/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4003 - accuracy: 0.8199 - val_loss: 0.4517 - val_accuracy: 0.7692
# Epoch 63/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3563 - accuracy: 0.8560 - val_loss: 0.4486 - val_accuracy: 0.7802
# Epoch 64/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4044 - accuracy: 0.8310 - val_loss: 0.4423 - val_accuracy: 0.7912
# Epoch 65/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3846 - accuracy: 0.8310 - val_loss: 0.4452 - val_accuracy: 0.7802
# Epoch 66/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3575 - accuracy: 0.8670 - val_loss: 0.4444 - val_accuracy: 0.7802
# Epoch 67/70
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3528 - accuracy: 0.8366 - val_loss: 0.4479 - val_accuracy: 0.7802
# Epoch 68/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.8199 - val_loss: 0.4500 - val_accuracy: 0.7802
# Epoch 69/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3574 - accuracy: 0.8532 - val_loss: 0.4517 - val_accuracy: 0.7802
# Epoch 70/70
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3797 - accuracy: 0.8144 - val_loss: 0.4539 - val_accuracy: 0.7802
# 3/3 [==============================] - 0s 2ms/step
# For ANN:
# Accuracy: 0.7802197802197802
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        49
#            1       0.76      0.76      0.76        42
#
#     accuracy                           0.78        91
#    macro avg       0.78      0.78      0.78        91
# weighted avg       0.78      0.78      0.78        91

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Define the file path
file_path = "/kaggle/input/undergrad/Undergraduate.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Convert the target column to numeric, handling errors by setting them to NaN
balanced_df['What was your SSC GPA?'] = pd.to_numeric(balanced_df['What was your SSC GPA?'], errors='coerce')

# Drop rows with NaN values in the target column
balanced_df = balanced_df.dropna(subset=['What was your SSC GPA?'])

# Separate features (X) and target variable (y)
target_column = 'What was your SSC GPA?'
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Standardize the features (optional but recommended for linear regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the linear regression model
linear_model = LinearRegression()
linear_model.fit(X_train_scaled, y_train)

# Initialize and train the decision tree regressor model
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_scaled, y_train)

# Initialize and train the random forest regressor model
rf_model = RandomForestRegressor()
rf_model.fit(X_train_scaled, y_train)

# Initialize and train the gradient boosting regressor model
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train_scaled, y_train)

# Initialize and train the support vector regressor model
svr_model = SVR()
svr_model.fit(X_train_scaled, y_train)

# Initialize and train the k-nearest neighbors regressor model
knn_model = KNeighborsRegressor()
knn_model.fit(X_train_scaled, y_train)

# Initialize and train the lasso regression model
lasso_model = Lasso()
lasso_model.fit(X_train_scaled, y_train)

# Make predictions on the test set for each model
linear_pred = linear_model.predict(X_test_scaled)
dt_pred = dt_model.predict(X_test_scaled)
rf_pred = rf_model.predict(X_test_scaled)
gb_pred = gb_model.predict(X_test_scaled)
svr_pred = svr_model.predict(X_test_scaled)
knn_pred = knn_model.predict(X_test_scaled)
lasso_pred = lasso_model.predict(X_test_scaled)

# Evaluate each model
linear_mse = mean_squared_error(y_test, linear_pred)
linear_r2 = r2_score(y_test, linear_pred)

dt_mse = mean_squared_error(y_test, dt_pred)
dt_r2 = r2_score(y_test, dt_pred)

rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)

gb_mse = mean_squared_error(y_test, gb_pred)
gb_r2 = r2_score(y_test, gb_pred)

svr_mse = mean_squared_error(y_test, svr_pred)
svr_r2 = r2_score(y_test, svr_pred)

knn_mse = mean_squared_error(y_test, knn_pred)
knn_r2 = r2_score(y_test, knn_pred)

lasso_mse = mean_squared_error(y_test, lasso_pred)
lasso_r2 = r2_score(y_test, lasso_pred)

# Print the results
print(f'Linear Regression - Mean Squared Error: {linear_mse}, R-squared: {linear_r2}')
print(f'Decision Tree Regressor - Mean Squared Error: {dt_mse}, R-squared: {dt_r2}')
print(f'Random Forest Regressor - Mean Squared Error: {rf_mse}, R-squared: {rf_r2}')
print(f'Gradient Boosting Regressor - Mean Squared Error: {gb_mse}, R-squared: {gb_r2}')
print(f'Support Vector Regressor - Mean Squared Error: {svr_mse}, R-squared: {svr_r2}')
print(f'K-Nearest Neighbors Regressor - Mean Squared Error: {knn_mse}, R-squared: {knn_r2}')
print(f'Lasso Regression - Mean Squared Error: {lasso_mse}, R-squared: {lasso_r2}')
# Out:
# Linear Regression - Mean Squared Error: 0.056248060161887964, R-squared: -0.08982924603798303
# Decision Tree Regressor - Mean Squared Error: 0.04907582417582417, R-squared: 0.04913576919279339
# Random Forest Regressor - Mean Squared Error: 0.03486187879120865, R-squared: 0.3245367934620125
# Gradient Boosting Regressor - Mean Squared Error: 0.028810718909370165, R-squared: 0.4417804991595775
# Support Vector Regressor - Mean Squared Error: 0.033990545675827044, R-squared: 0.34141923010873765
# K-Nearest Neighbors Regressor - Mean Squared Error: 0.0535215824175824, R-squared: -0.03700262097991214
# Lasso Regression - Mean Squared Error: 0.051768541878544856, R-squared: -0.003036741206731808

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load the dataset
df = pd.read_csv("/kaggle/input/undergrad/Undergraduate.csv")

# Downsample both Public University and Private University to 226 instances each
public_university = df[df['Name of your current institution? '] == 'Public University'].sample(226, random_state=42)
private_university = df[df['Name of your current institution? '] == 'Private University'].sample(226, random_state=42, replace=True)
balanced_df = pd.concat([public_university, private_university])

# Assuming the last column is the target variable
target_column = balanced_df.columns[-1]

# Remove leading and trailing spaces from the target column
balanced_df[target_column] = balanced_df[target_column].str.strip()

# Separate features (X) and target variable (y)
X = balanced_df.drop(columns=[target_column])
y = balanced_df[target_column]

# Identify categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Label encode the target variable
le = LabelEncoder()
y = le.fit_transform(y)  # Assuming y contains class labels 0 and 1

# Perform train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Data preprocessing
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# ELM implementation
class ELMClassifierManual:
    def __init__(self, input_size, hidden_size):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.input_weights = np.random.rand(input_size, hidden_size)
        self.bias = np.random.rand(hidden_size)
        self.output_weights = None

    def train(self, X, y):
        hidden_layer_output = self.sigmoid(X.dot(self.input_weights) + self.bias)
        self.output_weights = np.linalg.pinv(hidden_layer_output).dot(y)

    def predict(self, X):
        hidden_layer_output = self.sigmoid(X.dot(self.input_weights) + self.bias)
        predictions = hidden_layer_output.dot(self.output_weights)
        return np.round(predictions).astype(int)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

# Initialize ELMClassifier
elm_classifier = ELMClassifierManual(input_size=X_train_scaled.shape[1], hidden_size=100)

# Train ELMClassifier
elm_classifier.train(X_train_scaled, y_train)

# Predictions
elm_predictions = elm_classifier.predict(X_test_scaled)

# Evaluate ELMClassifier
elm_accuracy = accuracy_score(y_test, elm_predictions)
elm_report = classification_report(y_test, elm_predictions)

print("ELM Classifier (Manual Implementation):")
print(f"Accuracy: {elm_accuracy:.2f}")
print(f"Classification Report:\n{elm_report}\n{'='*40}")
# Out:
# ELM Classifier (Manual Implementation):
# Accuracy: 0.78
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78        49
#            1       0.76      0.83      0.80        42
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.78        91
#    macro avg       0.53      0.52      0.53        91
# weighted avg       0.80      0.78      0.79        91
#
# ========================================
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.ensemble import VotingClassifier

# Define the best classifiers based on the results of hyperparameter tuning
best_svm = classifiers['SVM'][0]
best_svm_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('svc__')]
for key in best_svm_keys:
    setattr(best_svm.named_steps['svc'], key, grid_search.best_params_['svc__' + key])

best_mlp = classifiers['MLPClassifier'][0]
best_mlp_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('mlpclassifier__')]
for key in best_mlp_keys:
    setattr(best_mlp.named_steps['mlpclassifier'], key, grid_search.best_params_['mlpclassifier__' + key])

best_dt = classifiers['Decision Tree'][0]
best_dt_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('decisiontreeclassifier__')]
for key in best_dt_keys:
    setattr(best_dt.named_steps['decisiontreeclassifier'], key, grid_search.best_params_['decisiontreeclassifier__' + key])

best_lr = classifiers['Logistic Regression'][0]
best_lr_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('logisticregression__')]
for key in best_lr_keys:
    setattr(best_lr.named_steps['logisticregression'], key, grid_search.best_params_['logisticregression__' + key])

best_knn = classifiers['K-Nearest Neighbors'][0]
best_knn_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('kneighborsclassifier__')]
for key in best_knn_keys:
    setattr(best_knn.named_steps['kneighborsclassifier'], key, grid_search.best_params_['kneighborsclassifier__' + key])

best_adaboost = classifiers['AdaBoost'][0]
best_adaboost_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('adaboostclassifier__')]
for key in best_adaboost_keys:
    setattr(best_adaboost.named_steps['adaboostclassifier'], key, grid_search.best_params_['adaboostclassifier__' + key])

best_gb = classifiers['Gradient Boosting'][0]
best_gb_keys = [key.split('__')[1] for key in grid_search.best_params_.keys() if key.startswith('gradientboostingclassifier__')]
for key in best_gb_keys:
    setattr(best_gb.named_steps['gradientboostingclassifier'], key, grid_search.best_params_['gradientboostingclassifier__' + key])

# Create an ensemble classifier using a VotingClassifier
ensemble_classifier = VotingClassifier(
    estimators=[
        ('SVM', best_svm),
        ('MLPClassifier', best_mlp),
        ('Decision Tree', best_dt),
        ('Logistic Regression', best_lr),
        ('K-Nearest Neighbors', best_knn),
        ('AdaBoost', best_adaboost),
        ('Gradient Boosting', best_gb)
    ],
    voting='hard'  # You can change to 'soft' if classifiers provide probability estimates
)

# Train the ensemble classifier on the training data
ensemble_classifier.fit(X_train, y_train)


# Evaluate the ensemble classifier on the test data
ensemble_predictions = ensemble_classifier.predict(X_test)
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)

# Convert numeric labels back to class names
ensemble_predictions_names = le.inverse_transform(ensemble_predictions)
ensemble_report = classification_report(y_test_names, ensemble_predictions_names, target_names=class_names)

print("Ensemble Classifier:")
print(f"Accuracy: {ensemble_accuracy:.2f}")
print(f"Classification Report:\n{ensemble_report}")
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ensemble Classifier:
# Accuracy: 0.80
# Classification Report:
#                     precision    recall  f1-score   support
#
# Private University       0.82      0.82      0.82        49
#  Public University       0.79      0.79      0.79        42
#
#           accuracy                           0.80        91
#          macro avg       0.80      0.80      0.80        91
#       weighted avg       0.80      0.80      0.80        91
